# %%
import requests
import bs4

# %%
url_1 = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber=1"""

# %%
url_1
# Out:
# 'https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber=1'

# %%
soup_1 = bs4.BeautifulSoup(requests.get(url_1).text, 'html5lib')
review_general_1 = soup_1.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_1 = review_general_1.find_all('div', attrs={'class': 'a-section review'})
review_title_1 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_1]
review_body_1 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_1]
review_stars_1 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_1]
review_date_1 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_1]
review_title_1, review_body_1, review_stars_1, review_date_1
# Out:
# (["It isn't very bright but it's small and will easily fit in a pocket",
#   'Bright, but eats batteries',
#   "They work pretty good. Didn't blow me away",
#   'Four Stars',
#   'Five Stars',
#   'Works good on 1.2 volt Rechargeable Ni-Mh Batteries!',
#   'Five Stars',
#   'Dependable light',
#   'Four Stars',
#   'One worked fine, the other would not turn'],
#  ["It isn't very bright but it's small and will easily fit in a pocket. If you use and loose flash lights a lot these are perfect.",
#   'Very bright, I work in a run down steel mill and there are a lot of dark rooms to explore and shop in, but without light it’s impossible.  It comes with two lights, one clips into my hard hat clip and the other is handy in my pocket at all times..z must have for the price',
#   "They work pretty good. Didn't blow me away, and they seem fragile (although it is fair to say that I have NOT tested how tough they are).",
#   'I will only say for now so far so good, will see in a few months',
#   'Great little flashlight, very bright, will buy again.',
#   'Nice well made little flashlight, they work good on 1.2 volt rechargeable Ni-Mh batteries.',
#   "It's exactly as described and I received it quickly.",
#   'Very small and very bright. These fit easy into any pocket yet they are bright. They make a good every day carry light. Pair it with amazon rechargeable battery and you are ready to go.  The clip is sturdy and easy to clip onto the pocket.',
#   'Good flashlights at a good price.',
#   'Received 2 flashlights. One worked fine, the other would not turn on'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on April 17, 2018',
#   'on April 16, 2018',
#   'on April 16, 2018',
#   'on April 16, 2018',
#   'on April 16, 2018',
#   'on April 15, 2018',
#   'on April 15, 2018',
#   'on April 14, 2018',
#   'on April 14, 2018',
#   'on April 14, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_2 = url+str(2)
url_2
# Out:
# 'https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber=2'

# %%
soup_2 = bs4.BeautifulSoup(requests.get(url_2).text, 'html5lib')
review_general_2 = soup_2.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_2 = review_general_2.find_all('div', attrs={'class': 'a-section review'})
review_title_2 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_2]
review_body_2 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_2]
review_stars_2 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_2]
review_date_2 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_2]
review_title_2, review_body_2, review_stars_2, review_date_2
# Out:
# (['Five Stars',
#   'Well made, solid aluminum',
#   'When you zoom in it doesnt even look like the LED shape',
#   'Do not waste your money',
#   'Five Stars',
#   'Five Stars',
#   'Flash lights',
#   'Perfect for camping',
#   'Five Stars',
#   'A GREAT BUY'],
#  ['These lights are alot nicer than I expected for the price',
#   'Well made, solid aluminum.  Was tough to figure out how to unscrew it to put batteries in.  Its the little cap on the end where the push button on switch is.',
#   "Not what i got as advertised. When you zoom in it doesnt even look like the LED shape, it is blurry and week. Quality wasn't the greatest when i took the flashlight apart. Electronics were not well put together and weren't held in place.",
#   'Junk junk junk sums it up',
#   'Really good for the price.',
#   'They both work great. Can adjust beam very easily.  Fast shipping',
#   'The 1st flashlight I used at work fell apart in my pocket.The barrel that focuses the light  stripped out the inner threads.I will try the 2nd light this week.',
#   "I ordered these to put in our camper for a light that didn't require a lot of room.  These are perfect and give off light  exactly what as  I wanted.  I would buy them again.",
#   'This flashlight is exactly what I wanted.',
#   'Really great flashlights. Well made, bright light! A great buy!'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 14, 2018',
#   'on April 14, 2018',
#   'on April 13, 2018',
#   'on April 13, 2018',
#   'on April 13, 2018',
#   'on April 12, 2018',
#   'on April 12, 2018',
#   'on April 12, 2018',
#   'on April 12, 2018',
#   'on April 12, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_3 = url+str(3)
soup_3 = bs4.BeautifulSoup(requests.get(url_3).text, 'html5lib')
review_general_3 = soup_3.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_3 = review_general_3.find_all('div', attrs={'class': 'a-section review'})
review_title_3 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_3]
review_body_3 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_3]
review_stars_3 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_3]
review_date_3 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_3]
review_title_3, review_body_3, review_stars_3, review_date_3
# Out:
# (['Five Stars',
#   'Good Quality',
#   'Not worth a 3star review.',
#   'I loaded each flashlight with a with an AA 2 ...',
#   'Great range for a small package',
#   'Five Stars',
#   'Sturdy little lights',
#   'Five Stars',
#   'Love this product',
#   'Light but bright'],
#  ['This is great of camping, cycling.',
#   "Good little well made flashlight. Can't beat them for the price. They make nice gifts.",
#   'Because they were $4 each that got them one star. Because they worked they got another. Because they did not work properly two stars is all they are worth.',
#   "I loaded each flashlight with a with an AA 2,800 mAHr rechargeable battery. They are well-constructed and function well. Beam width adjust is smooth and provides a reasonable range of pinpoint and dispersed. The only con is the three-cycle on/off function to move between high-beam, low-beam and flashing. This is the kind of small and cheap flashlight that one would leave in a backpack or car glove box and know that it will function when it's called upon. In this application ensure that you understand the self-discharge rate of the type of batteries employed and change them accordingly. -Cheers",
#   "We were looking for a decent flashlight for outdoor use - primary in the back yard to spot the pets or other critters.  I took a shot at these since they were on sale. They arrived and we kinda laughed thinking they wouldn't do the job.We were wrong.  Our back yard goes back 80 feet or so.  This thing lights it up in spot mode or the more open mode.  It's great.  I'll be picking up a couple more.",
#   'Very nice, works great',
#   'These are sturdy little flashlights that we plan to use in our kayaks in case we need a light. They are a lot sturdier than I would have thought for the price, and they have the flashing lights that would be of use if we find ourselves stranded out at night.',
#   'EXCELLENT FLASHLIGHT ! Not sure exactly what people ,who wrote a 2 paragraph review, were expecting from a $5 flashlight !?',
#   'This is the 2nd set of RockBirds I have purchased! Love this product! Sturdy, powerful beam, lightweight an compact!',
#   'It is small but mighty. This little flashlight is very bright. It also is light so I can carry in my pocket, purse, or on my belt loop.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 11, 2018',
#   'on April 11, 2018',
#   'on April 11, 2018',
#   'on April 11, 2018',
#   'on April 11, 2018',
#   'on April 11, 2018',
#   'on April 11, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_4 = url+str(4)
soup_4 = bs4.BeautifulSoup(requests.get(url_4).text, 'html5lib')
review_general_4 = soup_4.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_4 = review_general_4.find_all('div', attrs={'class': 'a-section review'})
review_title_4 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_4]
review_body_4 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_4]
review_stars_4 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_4]
review_date_4 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_4]
review_title_4, review_body_4, review_stars_4, review_date_4
# Out:
# (['You cant lose.',
#   'Love the daily dealz.',
#   'Love em',
#   'One Star',
#   'Sturdy little lights that work every time as',
#   'Well-made, bright, and good deal.',
#   'Nice flashlight, Good value',
#   "They work.  Inexpensive but don't feel cheap.",
#   'Great',
#   'Very bright'],
#  ["Just the right size for pocket, good light ,variable beam great to work with, bottom line for the price you can't lose",
#   'I purchased some larger flashlights recently but needed something that was easier to carry daily. I love the size and the build quality. Plus just one AA battery is nice. They are nice and bright and have a cool zoom feature.',
#   "What a great price you just can't beat it.",
#   'These are very cheaply made. Once of these broke after 2 uses.',
#   'Sturdy little lights that work every time as advertised',
#   'Wow.  Nicely made.  Work very well with Li Ion 14500 batteries as well as with AA alkaline (of course dimmer).  Not hard to get used to the (stupid) inclusion of Strobe Mode.  They automatically cycle from mode to mode each time you turn them off/on with the tail switch.  Hint to make your life easier (such as it is): When (not if) it turns on automatically (every third time) in strobe mode, just gently push down slightly once or twice on the switch to make it cycle between modes to get what you want.  Instead of "jumping up and down, screaming and shouting", just think ZEN thoughts (Ooooommmm.  All is beauty) and gently depress the switch.And think of the amazingness of this: A bright (and cheap and well-made) LED flashlight that operates on one lousy battery at 1 1/2 volts (yes, even cheap light "heavy duty" non-alkalines) or an NiMH rechargeable at 1.35 volts and yet is still not destroyed by 3.7 volt Li Ion\'s.  Would I be as enthusiastic if I\'d not got them on sale at 6.99?  Well, maybe a little less because the competition in quantity goes for about $3 to $4 per, and if I buy 5 or 6, I\'d be giving away a few to friends and that would be even more fun.One little nit-picky thing: the "Two Fluorescent Rings Which Shine in the Dark Night" (not fluorescent but phosphorescent) the "rings" seem to be just those (cheap) little silicone rubber bands sold in handi-craft stores that are woven together (mainly by younger people, it seems) to make rings and bracelets.  Yeah, some of those are sold as glow-in-the-dark.  My point is that after a few minutes in the dark, I\'ve seen matches brighter than these -yeah UNLIT matches!One more thing - if you use 14500 Li Ion batteries:\xa0EBL 14500 Li-ion Rechargeable Batteries 3.7V 800mAh for LED Flashlight Torch, 8 Packs\xa0most of these are what is called "unprotected".  In this case, it means if their voltage goes down in the flashlight, they are probably going to be damaged and may never again be able to be charged to full capacity - or at all.  So this is my suggestion: if the "bulb" starts dimming or shuts off by itself: immediately open the flashlight and take out the battery.  That way the flashlight cannot draw down its voltage any more.  Since there\'s no circuit to protect your battery, you have to do it.  This should help you protect your investment and continue to give you the nice bright light these batteries give with these flashlights.',
#   'Nice flashlight, Good value',
#   'Bright little flashlights that feel very substantial for such a low cost.',
#   'Small and powerful',
#   'Wow, I just popped an AA battery in, and this thing is bright.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 10, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_5 = url+str(5)
soup_5 = bs4.BeautifulSoup(requests.get(url_5).text, 'html5lib')
review_general_5 = soup_5.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_5 = review_general_5.find_all('div', attrs={'class': 'a-section review'})
review_title_5 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_5]
review_body_5 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_5]
review_stars_5 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_5]
review_date_5 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_5]
review_title_5, review_body_5, review_stars_5, review_date_5
# Out:
# (['Five Stars',
#   'This product came quickly and in perfect condition. Easy to use',
#   'Solid heavy duty flashlight.',
#   'Four Stars',
#   'So far great light. Only time will tell how durable and ...',
#   'One Star',
#   'The one that does is mediocre at best.',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars'],
#  ['Love these flashlights! It does everything it said it would do!',
#   'This product came quickly and in perfect condition. Easy to use, accurate, durable, and very useful in our camping night. Great buy.',
#   'Solid product. Works as well as flashlights 3 or 4 times the cost of this one, at least. I will buy another pair, soon.',
#   'Great product for the price!  Arrived as stated. Good packaging. Would recommend',
#   'Small compact light that you carry every day.  So far great light. Only time will tell how durable and dependable it is.',
#   'Ridiculously small. You are mislead by the picture on the site.',
#   'Only one works. The one that does is mediocre at best.',
#   'Most: size, uses 2A battery, adjustable light beam. Least: the method used to change the light mode.',
#   'Awesome little light, highly recommend',
#   'Durable, lightweight and very bright'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_6 = url+str(6)
soup_6 = bs4.BeautifulSoup(requests.get(url_6).text, 'html5lib')
review_general_6 = soup_6.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_6 = review_general_6.find_all('div', attrs={'class': 'a-section review'})
review_title_6 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_6]
review_body_6 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_6]
review_stars_6 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_6]
review_date_6 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_6]
review_title_6, review_body_6, review_stars_6, review_date_6
# Out:
# (['Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Compact and useful',
#   'Very small which was awesome and it was doing what I bought it for ...',
#   'Arrived very quickly and seem to be a good product. I admit they were smaller than I ...',
#   'Inexpensive lighting.',
#   'Arrived fast and in perfect condition. Using 2 in motorhome for camping and ...',
#   'Poor quality'],
#  ['Very good quality lights for the size of flashlight',
#   'They work great. Flashlights are small but do a great job of lighting up the area.',
#   'Great little bright light!',
#   'Great product..',
#   'These are compact size flashlights, fit in palm.  3 light levels with click of button at the end of flash light. It is good for daily use to keep in the pocket for emergencies or just for walking the dog at night. Recommended',
#   'Very small which was awesome and it was doing what I bought it for until the light stopped turning on. Flashlights seem to have a mind of there own. These would work good for around the house and emergency use but not for any type of work/long periods of off and on usage.',
#   "Arrived very quickly and seem to be a good product. I admit they were smaller than I expected, but that worked out okay because they're a good size to carry in  a pocket.",
#   'Lite lighting lasting longer liberally.',
#   'Arrived fast and in perfect condition.  Using 2 in motorhome for camping and 2 for home.  Tried one out at it has a very bright light for its size.  Am going to love carrying a smaller, lighter flashlight around.  Has a clip to hang on belt or purse.  Thanks for a great product.',
#   "The button doesn't seem to have an actuation point so you seem to have to press rather firmly to change light settings but some times it actuates with little pressure. Edges on the frame feel uncomfortable."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018',
#   'on April 9, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_7 = url+str(7)
soup_7 = bs4.BeautifulSoup(requests.get(url_7).text, 'html5lib')
review_general_7 = soup_7.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_7 = review_general_7.find_all('div', attrs={'class': 'a-section review'})
review_title_7 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_7]
review_body_7 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_7]
review_stars_7 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_7]
review_date_7 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_7]
review_title_7, review_body_7, review_stars_7, review_date_7
# Out:
# (['Comes in handy',
#   "Obnoxious strobe/flashing mode you can't avoid, but decent flashlight.",
#   'A Golden Pair of Mini Flashlights - YOU HAVE TO CHECK THESE OUT!!!',
#   'Five Stars',
#   'Smaller than they look',
#   'Five Stars',
#   'One Star',
#   'Love this flashlight!',
#   'the quality is also very good, the light is very bright',
#   'Five Stars'],
#  ['These flashlights are small but very powerful! I love them and are easy to have anywhere. I recommend this product.',
#   "FYI, to get it to switch modes, you turn it of then on again and it switches.  It goes from (1) bright --> (2) Dimmer --> (3) Flashing.The flashing is obnoxious.  I wish I could get rid of that.  I see no need for that in my life or 99% of anyone who buys this thing.  It just threatens you with a seizure as you try to quickly switch it off and on to a different mode.But the light is fairly bright.  No big complaints with how it works when it's just on and working.",
#   "I absolutely LOVE these mini flashlights. They illuminate so much more than one might expect from a device this size and fit cozily in your pocket, in a desk organizer, etc. You never know when you're going to need to light up under your bed, behind a large appliance or the sidewalk out to your garbage cans early in the morning. The monetary trade off is ridiculous with regards to what you get for your hard earned cash. They rest comfortably in the palm of your hand with intuitive motions to light up. Only thing I can't for the life of me figure out is why there's a strobe setting,  but that's just me maybe needing a clue as to a real world application. That said, I am in no way affiliated with this company nor do I foresee any financial compensation for a glowing review. I would have been stoked receiving just one of these flashlights but getting two? i say see for yourself, you won't be disappointed!!",
#   'Excellent led , portable',
#   "They are quite bright and seem to be solidly constructed, but the picture made them seem a bit larger than they really are. They can only hold one AA battery, so if you're expecting the larger kind with the caddy that holds three AAA batteries, you will be a bit disappointed. That said, even as small as they are, the price is very good.",
#   'When I click the button it shines brightly',
#   'i have to buy batteries  china junk',
#   'Arrived on time and product is as depicted.  Great mini flashlights for the price.  Bought these for my husband who uses them at work.  Would definitely buy again',
#   'This is a small iron flashlight, it is very convenient to carry, the quality is also very good, the light is very bright, the lamp head part can also adjust the length of the light, and it is two equipment, cheap and affordable, I like it!',
#   'Awesome flashlight for the price!'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 9, 2018',
#   'on April 8, 2018',
#   'on April 8, 2018',
#   'on April 8, 2018',
#   'on April 8, 2018',
#   'on April 8, 2018',
#   'on April 8, 2018',
#   'on April 7, 2018',
#   'on April 7, 2018',
#   'on April 7, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_8 = url+str(8)
soup_8 = bs4.BeautifulSoup(requests.get(url_8).text, 'html5lib')
review_general_8 = soup_8.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_8 = review_general_8.find_all('div', attrs={'class': 'a-section review'})
review_title_8 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_8]
review_body_8 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_8]
review_stars_8 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_8]
review_date_8 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_8]
review_title_8, review_body_8, review_stars_8, review_date_8
# Out:
# (['Multi purpose in a compact format',
#   'But I hated the fact that I had to cyclce through the ...',
#   'Cute and bright flashlight',
#   'Better than I was expecting for the price and super ...',
#   'under closet repair and kids love it for haunted house',
#   'Three Stars',
#   'Five Stars',
#   'One Star',
#   'One of mine had a bad switch.',
#   'Total waste of money'],
#  ["Got these two flashlights on sale and well worth the price. Like the small compact size with a lot of light emanating from the bulbs. Great feature of bright, less bright, and a flasher. One is next to the bed, the other in the car for those emergencies. Also, like the ability to focus the beam when necessary. This is the kind of thing that you don't need until you get it. Highly recommend.",
#   'Decent enough light. But I hated the fact that I had to cyclce through the modes every time i turned it on.',
#   'It’s tiny cute flashlight.  As of luminous flux , this little flashlight generates amazing light intensity that can be light up a spot 50 yards, even 100 yards away. There are two light modes, the continuous one and the twinkling one.',
#   'Better than I was expecting for the price and super bright for how tiny they are. If you put a good AA battery in them you will be stoked. I like that the light can focus in on small spaces. Good for exploring tight spaces. I would imagine they would be good in the mechanic industry. I mostly bought them for walking at night so people dont run me over. And for going into tunnels and sewage drains to look for clowns and stuff.',
#   'This is one of the must haves for each and every family. We used it for night time outdoor exploration, under closet repair and kids love it for haunted house.',
#   'One of the flashlights switch does not work.',
#   'They are working good. I love it!',
#   'DOA and this item is not eligible for return!',
#   "They aren't bad lights, Really bright, lightly depress the switch and release to change the operating mode, I Just happened to get one with a bad switch, It pops loudly, occasionally doesn't work or won't turn off. The other flashlight is fine. Oh, the fluorescent lines? Those are silicone/rubber bands that glow in the dark.",
#   'Can’t even get a battery in it. And it’s not bright at all once I finally got the top open. It just kept spinning and spinning. Now I can’t get the batteries out'],
#  ['5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on April 7, 2018',
#   'on April 7, 2018',
#   'on April 6, 2018',
#   'on April 6, 2018',
#   'on April 6, 2018',
#   'on April 6, 2018',
#   'on April 6, 2018',
#   'on April 5, 2018',
#   'on April 5, 2018',
#   'on April 5, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_9 = url+str(9)
soup_9 = bs4.BeautifulSoup(requests.get(url_9).text, 'html5lib')
review_general_9 = soup_9.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_9 = review_general_9.find_all('div', attrs={'class': 'a-section review'})
review_title_9 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_9]
review_body_9 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_9]
review_stars_9 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_9]
review_date_9 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_9]
review_title_9, review_body_9, review_stars_9, review_date_9
# Out:
# (['Waste of my money',
#   'Five Stars',
#   'Five Stars',
#   'Ity bitty',
#   'Two Stars',
#   'Muy bueno.',
#   'Hit and Miss',
#   'One of the two lights I received does not work ...',
#   'Flashlight cop material',
#   'Five Stars'],
#  ['1 of the 2 flashlights work. but not as advertised.  Did not find the "nonreturnable" part until after receiving the items.  Rechecked the original page for the order and nowhere does it say "nonreturnable".  Waste of my money!',
#   "It's compact, lightweight, focusable, and bright - exactly what I was looking for.",
#   'Really bright for the size one aa battery a plus',
#   "They're very small, but work well for a 4 inch flashlight",
#   "It's okay.",
#   'Muy bueno.',
#   'Of the two, one worked perfectly, the other would only switch on in dim mode, and needed to be switched to bright mode. They are build solidly and the working one does a good job. Amazon customer service is perfect as always and resolved the issue to my satisfaction. I would try them again,  my guess is I just got a bad one.',
#   'One of the two lights I received does not work.  I didnt know it was not returnable before receiving it.',
#   'Ok for  a kid',
#   'Good little flash light.'],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 5, 2018',
#   'on April 5, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018',
#   'on April 4, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_10 = url+str(10)
soup_10 = bs4.BeautifulSoup(requests.get(url_10).text, 'html5lib')
review_general_10 = soup_10.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_10 = review_general_10.find_all('div', attrs={'class': 'a-section review'})
review_title_10 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_10]
review_body_10 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_10]
review_stars_10 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_10]
review_date_10 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_10]
review_title_10, review_body_10, review_stars_10, review_date_10
# Out:
# (['0/2 working flashlights.  complete garbage.',
#   'Five Stars',
#   'Five Stars',
#   'NOT 300 LUMENS',
#   'brite lite',
#   '2 items. So very very cheap.',
#   "One of the two flashlights works, one doesn't.",
#   'Great little gadget',
#   'good quality, bright enough',
#   'I do not recommend this flashlight'],
#  ["So the one I could open to put a battery works ok, but the other one doesn't unscrew so its useless.  Not a great deal.update (5 minutes later) After taking the battery out and trying to reassemble the one that worked, the housing which holds the lens over the LED came off, so 100% garbage.  stay away.",
#   'Very small and very good quality, there are three kinds of adjustment brightness',
#   'Very great LED flashlights for last minute emergencies I definitely recommend this.',
#   'Overall it is well built for the price however the max output is probably not even 150 lumens. To call this 300 lumens is such false advertisement. It is bright enough to do the job and AA batteries are easy to find and they are cheap enough to loose or keep around.',
#   'awesome  little  lights',
#   'Retry??? Great product offers need great reviews  POSTED,  eh?',
#   "One of the two works fine, the other one does not work at all. It doesn't click, it seems all empty inside the orange ball, where it is supposed to click on and off. Cheap stuff, not worth to send back.",
#   'Very practical flashlight. Comes in handy  for this nurse!',
#   'small in size, good quality, bright enough. The reason I purchased this is because the hook that coming with it. Before this, I lost many of the flashlight. Love the hooks, no need to worry that I gonna lost it again.',
#   'The zoom does not work on any of the flashlights I received. I do not recommend this flashlight.'],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on April 4, 2018',
#   'on April 4, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018',
#   'on April 3, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_11 = url+str(11)
soup_11 = bs4.BeautifulSoup(requests.get(url_11).text, 'html5lib')
review_general_11 = soup_11.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_11 = review_general_11.find_all('div', attrs={'class': 'a-section review'})
review_title_11 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_11]
review_body_11 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_11]
review_stars_11 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_11]
review_date_11 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_11]
review_title_11, review_body_11, review_stars_11, review_date_11
# Out:
# (['Five Stars',
#   'This is a great mini flashlights',
#   'Love it. Small',
#   'Great value',
#   'Get rechargeable batteries with high mah.',
#   'Great flashlight, runs on AA batteries',
#   'Great product!!!!!!',
#   'Good on batteries',
#   'This flashlight is super bright. I can have my bathroom light off',
#   'easy to carry around'],
#  ['These were great and worth every penny.',
#   'This is a great mini flashlights! The size is small and fits so comfortable in my hand or put in my pocket. Also they are so bright than i expect. Very reasonable price for two, five stars!',
#   'Little cute flesh lights! Love it. Small , handy and great quality.',
#   'This is a small compact flashlight with a bright light, I have found it to be handy for lots of little things and big ones like flipping the fuse box. The only downside is I hate the strobe light because it hurts my eyes and you have to see the strobe in order to turn the flashlight off. The other downside is the flashlight has a lot of blue.',
#   "They're great little ones! Very bright and has 3 modes on them. dim, really bright and strobe. I'm using it with the regular standard batteries just to try them out.  But I'll be buying the high mah batteries.  The higher mah rechargeable  batteries are bit bigger then standard ones.  But no worries these little flashlights have space in them for that bit of over size battery.  And once you turn it on all you have to do is just press it slightly to get your 3 modes. every slight press is different mode.",
#   'The flashlights are great for the price. It fits the pocket and easy to carry around. It runs on one AA battery and bright enough for most of the tasks.',
#   'Love it. So useful when I trying to fix my pipe. Strong light with amazing size. All I can say is fantastic',
#   'These came in handy during Hurricane Irma. We live in Orlando, we lost power around midnight. These got us through that night. We eventually had to leave our home, No power for 7 days.But these little suckers were Very illuminating, Good on batteries, small but mighty. I bought one for each of my kids. It kept them entertained as the storm passed over us. We were able to play board games & cards games all night with these as our light.',
#   'This flashlight is super bright. I can have my bathroom light off, which is in the middle of the house so very dark, and this light will light the whole room up. you can see just like the light was on. This light is amazing!',
#   'Small and exquisite, easy to carry around.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 2, 2018',
#   'on March 31, 2018',
#   'on March 31, 2018',
#   'on March 30, 2018',
#   'on March 29, 2018',
#   'on March 28, 2018',
#   'on March 28, 2018',
#   'on March 28, 2018',
#   'on March 28, 2018',
#   'on March 27, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_12 = url+str(12)
soup_12 = bs4.BeautifulSoup(requests.get(url_12).text, 'html5lib')
review_general_12 = soup_12.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_12 = review_general_12.find_all('div', attrs={'class': 'a-section review'})
review_title_12 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_12]
review_body_12 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_12]
review_stars_12 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_12]
review_date_12 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_12]
review_title_12, review_body_12, review_stars_12, review_date_12
# Out:
# (['super easy to carry',
#   'A perfect flashlight, it’s easy to carry',
#   'Four Stars',
#   'Zoom feature is great!',
#   'Heavy duty',
#   'Does what is expected',
#   'Five Stars',
#   'Bright lights',
#   'Small and bright!',
#   'Five Stars'],
#  ['Ultra-convenient and compact flashlight and a group of two, super easy to carry, do not have to fear the dark place',
#   "A perfect flashlight,it’s easy to carry .The light is very bright and I don't have to worry about keeping spare batteries around for it. I bought this for my daughter  dand she  loves it.",
#   'you get what pay for',
#   "I own several smaller Cree LED flashlights and I'm very impressed by the performance for the size. This is a step up from the smaller lights and puts out some serious light. Brightest flashlight I've ever owned. Zoom feature is great!",
#   'This thing are small but have the power of a heavy duty flashlight',
#   "Nice flash lights. The are bright, I wish they were just on and off with no strob, but that's not what the description said. Also had one on a rival that would not turn on at all, had to mess with the button on the back before it would come on. After that it turns on fine.",
#   'These small LED flashlights are wonderful!  Small enough to carry inconspicuously, yet still extremely bright when needed!!',
#   'Nice bright lights. You get what you paid for, nothing special. I would recommend them.',
#   'Very bright, and works great. I took off 1 star as I hate the blinking light! (WHY is that needed??!!) Very small, it sits on my desk without taking up room (use it for my trackball that always gets clogged).',
#   'These are great for work. Get the upgraded batteries'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on March 26, 2018',
#   'on March 25, 2018',
#   'on March 25, 2018',
#   'on March 21, 2018',
#   'on March 21, 2018',
#   'on March 20, 2018',
#   'on March 20, 2018',
#   'on March 19, 2018',
#   'on March 18, 2018',
#   'on March 18, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_13 = url+str(13)
soup_13 = bs4.BeautifulSoup(requests.get(url_13).text, 'html5lib')
review_general_13 = soup_13.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_13 = review_general_13.find_all('div', attrs={'class': 'a-section review'})
review_title_13 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_13]
review_body_13 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_13]
review_stars_13 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_13]
review_date_13 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_13]
review_title_13, review_body_13, review_stars_13, review_date_13
# Out:
# (['These flashlights are so valuable and they are very easy to carry',
#   'one works the ot doesnt',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'One Star',
#   'Five Stars',
#   'I bought 2 and they worked great for 2-3 weeks then they quit working'],
#  ['These flashlights are so valuable and they are very easy to carry, also they are very bright, i think i spent 10 dollars very worthy that hard to find another place!',
#   '1 works fine .  the other blinks intermittently',
#   'Works great.',
#   'Great product',
#   'GREAt, compact flashlight. Nice quality',
#   'Excellent deal for a pair of probably most efficient flashlights ever invented.',
#   'great little flashlights',
#   'Already no longer working after minimal use.',
#   'Great little flashlights.',
#   "I bought 2 and they worked great for 2-3 weeks then they quit working.  Was using in a hot, humid climate. ( New batteries didn't help)"],
#  ['5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on March 17, 2018',
#   'on March 17, 2018',
#   'on March 17, 2018',
#   'on March 15, 2018',
#   'on March 13, 2018',
#   'on March 12, 2018',
#   'on March 12, 2018',
#   'on March 11, 2018',
#   'on March 10, 2018',
#   'on March 9, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_14 = url+str(14)
soup_14 = bs4.BeautifulSoup(requests.get(url_14).text, 'html5lib')
review_general_14 = soup_14.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_14 = review_general_14.find_all('div', attrs={'class': 'a-section review'})
review_title_14 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_14]
review_body_14 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_14]
review_stars_14 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_14]
review_date_14 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_14]
review_title_14, review_body_14, review_stars_14, review_date_14
# Out:
# (['I have a great relationship With the AMAZON store and the',
#   'Five Stars',
#   "I'm happy (even surprised) with these",
#   'Cree LED makes all other flashlights obselete...',
#   'Good flashlights for the price',
#   'good',
#   'Five Stars',
#   'Five Stars',
#   'Very bright and tough',
#   'Five Stars'],
#  ["It was a 5🌟. Until I found out that the 2  flashlight didn't work. I have a great relationship With the AMAZON store.  And the price of the flashlights so good that I just let it go...Even AMAZON has a bad day!!!  GET OVER IT!!!!",
#   'Very bright. I can see most of the back yard with this.',
#   'I don\'t have a lot of experience with LED flashlights (other than tiny cheapo ones with no replaceable or rechargeable battery), but these seem well worth it.I think i got them at one of Amazon\'s "lightning" specials, so only compared that price, which makes them cheaper than a pair would be of what i thought was an equivalent i picked up at Ace hardware. These are sturdy, seem surprisingly solid & well-made for today\'s typical plastic crap most everything i order ends up, & are both far brighter than the one about the same size that i got at Ace & are adjustable in focus & have a convenient clip. It\'s also nice to have 2 intensities & a strobe function. Only disadvantage i can think of is that they\'re noticeably heavier than the Ace one, so backpackers might want to look for something lighter.BTW, while there may be an advantage to multiple batteries (the Ace requires 3 AAA\'s!), i like that these require only 1 AA each.So, while i haven\'t given them a work-out, so far i\'m very pleased with these, & surprised at how solid & well-made they seem to be.',
#   'Typical nice flashlights for a great price. Very bright in a small footprint. Works best with a lipo aa or a 14500',
#   'Very bright flashlight.  Used at the beach walking at night looking fir shells. Decent battery life',
#   'works good, I used this during hurricane irma',
#   "Better quality than I was expecting...didn't  use yet",
#   'nice',
#   "These give amazing light and are very sturdy. A bit heavy for a compact light, but the clip makes it easy to carry. I ordered them for our hurricane supply kit after Irma hit us. We've used them several times and were so pleased that I got them  for my brother too.",
#   'I just bought 4 more!'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on March 8, 2018',
#   'on March 7, 2018',
#   'on March 7, 2018',
#   'on March 4, 2018',
#   'on March 4, 2018',
#   'on February 27, 2018',
#   'on February 23, 2018',
#   'on February 19, 2018',
#   'on February 18, 2018',
#   'on February 18, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_15 = url+str(15)
soup_15 = bs4.BeautifulSoup(requests.get(url_15).text, 'html5lib')
review_general_15 = soup_15.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_15 = review_general_15.find_all('div', attrs={'class': 'a-section review'})
review_title_15 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_15]
review_body_15 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_15]
review_stars_15 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_15]
review_date_15 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_15]
review_title_15, review_body_15, review_stars_15, review_date_15
# Out:
# (['Faulty, low quality',
#   'great, small but powerful',
#   'Five Stars',
#   'Five Stars',
#   'Great deal!',
#   'Five Stars',
#   'Small, Bright, Durable Flashlight',
#   'Miniature in size & price, but big on light output!',
#   "It's a great personal LED flashlight that easily fits into a pocket.",
#   'One battery and it lights up like a police helicopter'],
#  ['Price is too good to be true. Don’t expect them to last. One of mine just died and the other only flashes?!?! It’s been 2 months so I can’t return. Not happy! Good luck!',
#   'great ,  small but powerful .',
#   'They are great for reading a menu in a dark restaurant',
#   'Small and powerful!',
#   'Buy many, keep them everywhere. AA battery is a major advantage, some have.shelf-lives of decades, means always ready in boat, car or outhouse.',
#   'GReat Product!',
#   "I liked these so well that I gave them out as stocking stuffers to out family. They're built well, look nice, are plenty bright and small enough to have on hand or carry wherever you go. If you need a great little, durable flashlight, you can't go wrong with these. Highly recommended for sportsman and women of all activities, kids and folks in general looking for a small, bright, portable flashlight.",
#   'Given my many prior, poor experiences with several of the low-price/knockoff CREE type LED, zoomable style flashlights I\'ve bought of this design, these lights are a surprisingly good purchase.  I\'ve left off 1 of the 5 stars for 2 main reasons detailed in PRO\'s/CON\'s list below:CONS:1- Without (very) fresh batteries, the luminosity quoted in the product description isn\'t consistently provided by these lights- except on full, fresh batteries, the light is much dimmer than it can be when the light has fully powered batteries in it, so you\'ll end up going through batteries faster than normal (thankfully, the "Amazon Basics" AA batteries are very good quality & are very cheap compared to name-brands, so this is a solveable issue, just wasteful, seeing as you end up tossing batteries which still hold some charge- I\'ve ended up using the 1/2 dead flashlight batteries in my cable box remotes in an effort not to waste them).2- Like many of the economical flashlights being sold of this design type, sometimes the power-button press to cycle between modes happens without your input, turning on the strobe setting or the lower light output setting without my intending to do so by pressing the power button.PROS:1- These lights are very compact, yet with fully charged batteries, they have a high light output for their size. Given the amount of light they provide when fully powered, they do a good job to the point that my wife always keeps one in her purse & her car for being about at night &/or walking our dog after dark.2- Unlike many of the other flashlights I\'ve bought of this design/type, these lights have held up quality-wise over a decent amount of use- working just as they well as they did when they\'d 1st arrived.3- The price asked would be inexpensive for 1 CREE-type LED light of this design & high quality, so very good value for a 2 pack!Overall I certainly recommend them if you\'re looking for a good, low-cost & compact CREE-type LED, zoomable flashlight which works well & is of good quality..',
#   'Tiny yet powerful and the battery charge seems to last a long time.',
#   "My husband is obsessed with this flashlight.  One battery and it lights up like a police helicopter.  Best flashlight ever. It can zoom or be diffuse.  It's heavy and wish it had a wrist strap but otherwise awesome."],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on February 17, 2018',
#   'on February 16, 2018',
#   'on February 15, 2018',
#   'on February 13, 2018',
#   'on February 12, 2018',
#   'on February 11, 2018',
#   'on February 11, 2018',
#   'on February 10, 2018',
#   'on February 10, 2018',
#   'on February 10, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_16 = url+str(16)
soup_16 = bs4.BeautifulSoup(requests.get(url_16).text, 'html5lib')
review_general_16 = soup_16.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_16 = review_general_16.find_all('div', attrs={'class': 'a-section review'})
review_title_16 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_16]
review_body_16 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_16]
review_stars_16 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_16]
review_date_16 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_16]
review_title_16, review_body_16, review_stars_16, review_date_16
# Out:
# (['Works great. Husband and Dad liked the flash lights and ...',
#   'Very good for the price!!',
#   'Great for the price, but not for your “main” light',
#   'Five Stars',
#   'Great flashlights for the price.',
#   'Excellent value, sturdy flashlight that can handle some abuse',
#   'I I did not like the flashlight because the on and off switch quit ...',
#   'Perfect size and very bright',
#   'This little lights are awesome!',
#   'One Star'],
#  ['Works great. Husband and Dad liked the flash lights and size is easy to take with you anywhere. Will buy again',
#   'Awesome value for the price!! Well build and powerful enough - the lenses are a smart way of defusing the light - it works well.',
#   'Considering how little it costs for two of them, they are well built and very bright.  The issue is with the switch logic.  There is a single switch that turns it on/off (hard press) and changes the mode (half press).  The problem is that each time you turn it on, it switches to the next mode.  So if you are using it in “high” and turn it off, you will get “strobe” next time.  Not a deal breaker, but annoying.Again, great buy to throw in a drawer, but look elsewhere for something to carry every day.',
#   'I bought these as christmas gifts for my employees, it went over very well',
#   'I loved these Rockbird flashlights. I already have these flashlights for over a year, and they still work wonderfully. I lived in Florida and they came in handy when we got hit with hurricane Irma.',
#   'Excellent value, sturdy flashlight that can handle some abuse.  We use them on overnight aircraft cleaning inspections in commercial airports.  Units we purchased over a year ago are still functioning, and they are used 365 days per year.',
#   "I I did not like the flashlight because the on and off switch quit working within the day. Both of them the switch quit working . Otherwise it's in the junk pile I did like how well it's through a beam of light out and you could do it but not working",
#   'Got it for my granddaughter camping trip. Small size which was great and very bright light.',
#   'These are my favorite! Very bright, compact, and zoomable. Plus they come in 2 pack. One for the car, and one for home. These are awesome for their price.',
#   'terrible！！！'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on February 10, 2018',
#   'on February 7, 2018',
#   'on February 6, 2018',
#   'on February 6, 2018',
#   'on February 6, 2018',
#   'on February 5, 2018',
#   'on February 5, 2018',
#   'on February 3, 2018',
#   'on February 3, 2018',
#   'on February 2, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_17 = url+str(17)
soup_17 = bs4.BeautifulSoup(requests.get(url_17).text, 'html5lib')
review_general_17 = soup_17.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_17 = review_general_17.find_all('div', attrs={'class': 'a-section review'})
review_title_17 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_17]
review_body_17 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_17]
review_stars_17 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_17]
review_date_17 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_17]
review_title_17, review_body_17, review_stars_17, review_date_17
# Out:
# (['Small size and great light output',
#   'Two Stars',
#   'Great small flashlight!',
#   'Five Stars',
#   'Two Stars',
#   'Uhh',
#   'Three Stars',
#   '... a long time of carrying these disappointments I am glad to say I can buy a new flash light',
#   'NO BATTERIES',
#   'love it!'],
#  ['Small size and great light output. Battery last long time. Only takes one AA.',
#   'they stop working!!!!',
#   "The best thing on this phone is that it is sturdy and operates on one AA battery.  I don't dislike anything about this phone.",
#   'BRIGHT! (and small)',
#   'Not as bright as i thought it would be',
#   'These lights seem to have issues after a little use but as to be expected from a low priced light. It’s good as a light for the kids or in a tool box but don’t plan on performance.',
#   'GREAT LITTLE FLASH LITE',
#   "After a long time of carrying these disappointments I am glad to say I can buy a new flash light. They are okay for throw away flash lights but they are very undependable and aren't really worth keeping for more than a week. I run a small business that requires me to constantly use a flash light and I bought these as a test run. After about a week they started going in and out. I replaced the batteries and still it only worked about 45% of the time. I'm not a picky person but these had a pretty bad short in their switch so I just kept them in a drawer and used them intermittently. Glad to say though they are finally dead as a door nail and I can replace them with something a lot better.",
#   "Guess I should have read closer. Doesn't come with a battery. Then I had to go back to the description to find out what size battery to use as there were no instructions in the box. This is the 1st time I have purchased flashlights from Amazon and they didn't come with the batteries.",
#   'Compact  & bright!! love it!'],
#  ['5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on January 30, 2018',
#   'on January 29, 2018',
#   'on January 27, 2018',
#   'on January 27, 2018',
#   'on January 26, 2018',
#   'on January 25, 2018',
#   'on January 20, 2018',
#   'on January 18, 2018',
#   'on January 18, 2018',
#   'on January 17, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_18 = url+str(18)
soup_18 = bs4.BeautifulSoup(requests.get(url_18).text, 'html5lib')
review_general_18 = soup_18.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_18 = review_general_18.find_all('div', attrs={'class': 'a-section review'})
review_title_18 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_18]
review_body_18 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_18]
review_stars_18 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_18]
review_date_18 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_18]
review_title_18, review_body_18, review_stars_18, review_date_18
# Out:
# (['Nice little lights cheap with adjustable beam',
#   'Just ok',
#   'Powerful, tough, inexpensive',
#   'I have had excellent service life from other LED merchants',
#   'Five Stars',
#   "won't turn off) but the other is just fine.",
#   'Three Stars',
#   'Five Stars',
#   'Small, cheap flashlights but thats what we paid for, right?',
#   'Five Stars'],
#  ['Nice little lights cheap with adjustable beam. Using standard AA battery. Fits in front pocket so u always have it. solid built',
#   'U get what u pay for',
#   'GREAT little flashlights!  Powerful, tough, inexpensive.  Strongly recommend!',
#   'BOTH flash lights stopped operating in less than a week!  I have had excellent service life from other LED merchants.  No excusefor such dismal performance.  Steven Belaus',
#   'Amazing flashlights. They need only one AA battery. Very bright.',
#   "one was broken (button turns on, selects through modes, won't turn off) but the other is just fine.",
#   'Good buy for the price but are not as bright as other flashlights on this site',
#   'Work great and worth the money.',
#   "Super cheap. These are kind of our tiny emergency flashlights so I wasn't expecting a big sturdy flashlight. These are barely bigger than chapstick and are not that easy to put batteries in. They work but I wouldn't buy again.",
#   'Great for hikes. Light. Easy to use'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on January 17, 2018',
#   'on January 17, 2018',
#   'on January 17, 2018',
#   'on January 16, 2018',
#   'on January 16, 2018',
#   'on January 16, 2018',
#   'on January 14, 2018',
#   'on January 14, 2018',
#   'on January 14, 2018',
#   'on January 13, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_19 = url+str(19)
soup_19 = bs4.BeautifulSoup(requests.get(url_19).text, 'html5lib')
review_general_19 = soup_19.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_19 = review_general_19.find_all('div', attrs={'class': 'a-section review'})
review_title_19 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_19]
review_body_19 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_19]
review_stars_19 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_19]
review_date_19 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_19]
review_title_19, review_body_19, review_stars_19, review_date_19
# Out:
# (['Five Stars',
#   'Four Stars',
#   'Works great and even survived a hand washing submerged in water',
#   'Five Stars',
#   'Uses focused beam rather than bright LEDs',
#   'One Star',
#   'Total JUNK!',
#   'You will not be disappointed with these flash lights',
#   'Four Stars',
#   'You get what you pay for.'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on January 13, 2018',
#   'on January 12, 2018',
#   'on January 12, 2018',
#   'on January 11, 2018',
#   'on January 10, 2018',
#   'on January 10, 2018',
#   'on January 9, 2018',
#   'on January 9, 2018',
#   'on January 9, 2018',
#   'on January 8, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_20 = url+str(20)
soup_20 = bs4.BeautifulSoup(requests.get(url_20).text, 'html5lib')
review_general_20 = soup_20.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_20 = review_general_20.find_all('div', attrs={'class': 'a-section review'})
review_title_20 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_20]
review_body_20 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_20]
review_stars_20 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_20]
review_date_20 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_20]
review_title_20, review_body_20, review_stars_20, review_date_20
# Out:
# (['Big light, little package',
#   'Dissapointed.  300lumen is not as bright at I would have liked.  Doesnt come with battery or lanyard.',
#   'Super bright!',
#   'Dropped it one time from about 3ft on to dirt ...',
#   'Five Stars',
#   'These flashlights are AWESOME!!',
#   'So good looking, durable and bright!!',
#   'Not bright at all',
#   'Work well -- Pretty good quality',
#   'They look nice but bad quality'],
#  ['Great bang for the buck. It provides a lot of light for a product so small.',
#   'Dissapointed.  300lumen is not as bright at I would have liked.  Doesnt come with battery or lanyard.',
#   'Nice quality build, adjustable hot Zone for the light, can zoom in and zoom out, they are bright for using 1 AA battery!I received this item on discount for my non bias opinion.',
#   'Dropped it one time from about 3ft on to dirt and the piece that focuses the light broke. Will not buy these ever again',
#   'pleased with purchase, just as described',
#   "These flashlights are AWESOME!!! They are very compact and do the job they need to do. They are great for around the house. Keep one in the car in case you break down. They have that neat flashing feature to warn other motorists. Take one with you while you are out walking or while you are out with your pets. The little pocket clip is a bonus. I think for the money and the size, this is the best flashlight I've ever bought.",
#   'I love them!! OMG they look so cool and are so bright!!! I was checking the tires a few days ago and suddenly the whole "neighborhood" went visible! lol..Awesome design and I love how durable they are!I\'ll definitely recommend to my everyone I know..',
#   'The low price is the only reason I am giving this flashlight a 2 star rating instead of a 1 star rating. This is not bright at all even on the "high" setting. The metal finish on the ones I received is spotty and not finished. Not impressed at all.',
#   'Very nice little flashlights. Good build quality. Still has a bit of a "won\'t last long" feeling to it, but what the heck -- they are reasonably priced and you get two of them. I\'d buy again.',
#   'They look nice but bad quality, they rarely come on when u push the button.  Have to twist the battery cover part to get it to work'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on January 8, 2018',
#   'on January 7, 2018',
#   'on January 7, 2018',
#   'on January 7, 2018',
#   'on January 7, 2018',
#   'on January 6, 2018',
#   'on January 6, 2018',
#   'on January 5, 2018',
#   'on January 5, 2018',
#   'on January 5, 2018'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_21 = url+str(21)
soup_21 = bs4.BeautifulSoup(requests.get(url_21).text, 'html5lib')
review_general_21 = soup_21.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_21 = review_general_21.find_all('div', attrs={'class': 'a-section review'})
review_title_21 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_21]
review_body_21 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_21]
review_stars_21 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_21]
review_date_21 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_21]
review_title_21, review_body_21, review_stars_21, review_date_21
# Out:
# (['overall they both work great and as described',
#   'Did not work',
#   'Nice product for a good price',
#   'NOT SUITABLE AS BIKE LIGHT!',
#   'Five Stars',
#   'Four Stars',
#   'Handy with the clip on side',
#   'These flashlights are amazing I have one in my car for emergencies and ...',
#   'One Star',
#   'Defective. Don’t buy'],
#  ["drains my battery quick even when of, COULD BE my personal rechargeable battery that isn't working as it should. overall they both work great and as described.",
#   "Did not work and wouldn't let me return the item.",
#   'Nice product for a good price. Wish it had a setting to remember the last light mode used instead of having to cycle through all the settings each time you turn the light off.',
#   "I bought these to use as a bike headlight. My commute to work is about 20min., which I do by bike after dark 3-4x/wk. I always used the strobe because it is more conspicuous and drains the battery less than a steady beam, and is legal for a bike headlight in Florida. At first I was very happy with the brightness, but after 2-3wks. the light would require many clicks of the switch to turn on. Then it would go dark during my trip, and afterwards it wouldn't come on at all. This started after a total use of less than 3hrs. in strobe function, and the battery still had plenty of charge. I tried the 2nd light, and had a similar experience. Not wanting to continue risking my life, I tried to return the item, but it was not eligable. I am very dis-satisfied.",
#   'Works well. Thank you.',
#   'Very bright and good made materials',
#   'These are good to have everywhere, especially like the clips on side so handy. Great when walking dog after dark, in car, bedside, to hold somewhere while hands busy repairing anything. Not tremendously bright but worth owning. Great  stocking stuffers. Affordable.',
#   'These flashlights are amazing I have one in my car for emergencies and I have another one to use when I walk my dog. The lighting is great for long distance As well as short.',
#   'Didn’t work even tried several batteries',
#   'I was VERY disappointed with these flashlights. The very first time I pushed the button to turn on the button collapsed in. Apparently they can’t be returned which is awesome.'],
#  ['5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on January 4, 2018',
#   'on January 4, 2018',
#   'on January 4, 2018',
#   'on January 3, 2018',
#   'on January 2, 2018',
#   'on January 2, 2018',
#   'on December 31, 2017',
#   'on December 30, 2017',
#   'on December 29, 2017',
#   'on December 29, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_22 = url+str(22)
soup_22 = bs4.BeautifulSoup(requests.get(url_22).text, 'html5lib')
review_general_22 = soup_22.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_22 = review_general_22.find_all('div', attrs={'class': 'a-section review'})
review_title_22 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).text.strip() for s in review_section_22]
review_body_22 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_22]
review_stars_22 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_22]
review_date_22 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_22]
review_title_22, review_body_22, review_stars_22, review_date_22
# Out:
# (["Betcha can't live with just one",
#   'Five Stars',
#   'Great Price! Horrible Square Light However..',
#   'very useful, I have these all around the house',
#   'Petite Flashlight',
#   'Five Stars',
#   'Only lasted 45 days.',
#   'Great, strong flashlight.',
#   'Five Stars',
#   'Rockbirds LED Flashlight - small but mighty'],
#  ['I am very happy with these. I had purchased other similar brands but this is my favorite due to craftsmanship and the switch not only gives three modes but also has a half click function my others did not have. Barrel focuses nicer than my other brands which are a little loose. A nice selection of colors. These have an attractive look and professional feel. They all worked right out of the box.',
#   "Didn't realize how much I'd be using these little flashlight but I use them nightly.",
#   'I had to get a flashlight that fitted my 1” light mount for an upcoming airsoft skirmish. Thought I might as well get a combo pack! These little things pack quite a punch, and they’re tough. There not fully water resistant but they lasted through some rainfall and condensation. The lens is also quite thick because I also drop them on a concrete floor and not even a slight scratch. I ended up using them periodically over a time span of 7 hours in below 26° F weather and haven’t notice them go dim. Would recommend them because of the great value!',
#   'Really nice high quality small flashlights. Out of the five I received, one did not work. I sent an email to the seller and they very nicely and quickly sent me a replacement. Glad I purchased these flashlights.',
#   "Small size for easy carry. Way smaller than the one you see at drug store counter. That's plus. And comes with belt clip, another plus. And it's pretty bright with convex lens, and 3 mode.",
#   "These little LED flashlights are very useful. They will work with a standard AA battery. The light has 3 settings (bright / dim / strobe), and has adjustable focus. This body is made of solid aluminum, and is really strong. I don't think you'll have to worry about breaking it. I carry one of these in my purse .And I'm glad I bought them.",
#   'Stopped working just after return period. Save your money.',
#   'Small and convenient. Can never have enough flashlights in case of emergency.',
#   'Great value for the money would recommend to all. I am an appliance repairman use one every day',
#   'Excellent product at an excellent price!  Arrived on time and was as described.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on December 28, 2017',
#   'on December 27, 2017',
#   'on December 26, 2017',
#   'on December 26, 2017',
#   'on December 24, 2017',
#   'on December 24, 2017',
#   'on December 24, 2017',
#   'on December 24, 2017',
#   'on December 23, 2017',
#   'on December 23, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_23 = url+str(23)
soup_23 = bs4.BeautifulSoup(requests.get(url_23).text, 'html5lib')
review_general_23 = soup_23.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_23 = review_general_23.find_all('div', attrs={'class': 'a-section review'})
review_title_23 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'}).
                 text.strip() for s in review_section_23]
review_body_23 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_23]
review_stars_23 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_23]
review_date_23 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_23]
review_title_23, review_body_23, review_stars_23, review_date_23
# Out:
# (['Absolutely terrible trash. Have yet to work properly',
#   'Five Stars',
#   'Do Not Buy!!!!  Very Poor Quality & short lifespan!',
#   'Great Utilily Light for the Emergencies',
#   'one broke the other was lost',
#   'Great product',
#   'Great deal. Size and weight have made them a ...',
#   'They aren’t super high quality',
#   'very nice set comes in handy',
#   'Complete Junk! Do not buy!'],
#  ["If i could give this product a zero i would. Absolutely terrible trash. Have yet to work properly. Wish i could have returned them. I wouldn't recommend this to anyone.",
#   'Very bright nice flashlight.',
#   "What a waste of money! These things looked like they'd be great, and I liked the adjustability of the beam angle. But they both stopped working within 1 week of being used. I've had lower quality cheaper crap from the dollar store last longer than these! I only rated them 1 star because there isnt an option for ZERO stars or even negative stars!",
#   'Great for the car.  Inexpensive.  Cheap on batteries.  Small and can be put anywhere.  A lot of light for a single AA battery.',
#   'one broke  the other was lost',
#   'Light is bright, material is good and it worked as advertised',
#   'Great deal. Size and weight have made them a go to light for camping, hiking, or working around the yard/home.',
#   'These are decent lights to keep around the house or in the car. They aren’t super high quality, one of mine the rubber cover over the on/off switch was installed wrong and it makes it hard to operate the light. I don’t think they are really 300 lumens either. I have a 300 lumen light that I compared it to and these are a lot dimmer. Good cheap flashlight.',
#   'very nice set comes in handy, one for the wife an one for me.  I like the clip so that I cant loose it. small compact bright, great unit',
#   "These are complete junk. Worst flashlights I've ever owned. Received as a gift. If I had a way to return, I would.- Very difficult to screw on battery cap on bottom (both).- Switch works intermittently (one).- Treads failed, so switch end keeps popping off (one). May try red thread locker to fix.- Battery gasket ring broke (one) - mostly likely from struggling w/ bottom battery cap (one).If you end up w/ these, change the batteries from the top, rather than the bottom. Never remove bottom battery cap."],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on December 23, 2017',
#   'on December 22, 2017',
#   'on December 22, 2017',
#   'on December 22, 2017',
#   'on December 21, 2017',
#   'on December 21, 2017',
#   'on December 20, 2017',
#   'on December 19, 2017',
#   'on December 19, 2017',
#   'on December 19, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_24 = url+str(24)
soup_24 = bs4.BeautifulSoup(requests.get(url_24).text, 'html5lib')
review_general_24 = soup_24.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_24 = review_general_24.find_all('div', attrs={'class': 'a-section review'})
review_title_24 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_24]
review_body_24 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_24]
review_stars_24 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_24]
review_date_24 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_24]
review_title_24, review_body_24, review_stars_24, review_date_24
# Out:
# (['Five Stars',
#   'Great! Great!',
#   'Very disappointed ordered these for my son for Christmas one of ...',
#   'and I love that it comes in a pair',
#   'great flashlight and size makes them convenient',
#   'I really liked these.',
#   'weak',
#   'Bright Light',
#   'Great light, inexpensive',
#   'Five Stars'],
#  ['Awesome lights!',
#   'Great!',
#   "Very disappointed ordered these for my son for Christmas one of them did not work looks like he's getting only one he needed one for home one for work I purchased because of ratings switch is bad",
#   'Small, incredibly bright, and I love that it comes in a pair.',
#   'These things seriously have range...great flashlight and size makes them convenient. Wicked bargain would buy again!',
#   'I really liked these.. Until they just broke about a month after use. Changing battery and then never worked again. Same for both flashlights in pack',
#   "Light is weak, the strobe-light is pointless, and maybe just barely worth $5. Expected more quality, but it's all looks.",
#   'they are a great deal.  they are not high end, but for the price, they throw a lot of light with 1 battery.  Put them in all of the cars.',
#   "Great light, very bright for the price.  Don't really care for the strobe mode, and you have to cycle through it to get back to the brightest mode.  But what can you expect for such a cheap price.",
#   'great'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on December 17, 2017',
#   'on December 17, 2017',
#   'on December 17, 2017',
#   'on December 14, 2017',
#   'on December 14, 2017',
#   'on December 13, 2017',
#   'on December 13, 2017',
#   'on December 12, 2017',
#   'on December 12, 2017',
#   'on December 11, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_25 = url+str(25)
soup_25 = bs4.BeautifulSoup(requests.get(url_25).text, 'html5lib')
review_general_25 = soup_25.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_25 = review_general_25.find_all('div', attrs={'class': 'a-section review'})
review_title_25 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_25]
review_body_25 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_25]
review_stars_25 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_25]
review_date_25 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_25]
review_title_25, review_body_25, review_stars_25, review_date_25
# Out:
# (['It gives a good amount of light',
#   'one worked, one didnt',
#   'Not happy with modes!!!!',
#   'Really good low cost flash lights',
#   'I belive there are better batteries for it but idk',
#   'Great light, rechargeable battery friendly',
#   'Five Stars',
#   'Five Stars',
#   'Solid',
#   'Not bad for the price'],
#  ['One did not work. Switched the tail caps and they both work for now.. . It gives a good amount of light, but 3 stars because now I can’t rely on the light.',
#   "i gave it 3 stars because only one of the flash lights worked.  it didnt seem worth it to send them back since i really only needed one for a Christmas gift, just seemed easier and cheaper to get the two pack.  I put the batteries in and one worked right away while the other only pretends to work if the spring touches the side wall while the battery is in it and that's impossible to use since you have to close the cap to keep the battery inside.  The one that works however is awesome and more than what i expected it to be, flashes, zooms and expands and is very bright for its small size. just wish the other one worked. overall happy with the one that works but disappointed only one worked",
#   'I ordered similar lights to this in the past... LOVED THEM!  These however constantly cycle the features each time you turn the light on.For example:First time you turn it on... Super bright.Next time... Dim mode.Next time... Flashing pattern.NORMALLY... These types of flashlights should function:Momentary press button = Changes mode.Turn unit off = Remembers where it was.',
#   'Really good low cost flash lights. I got them last minute for a camping trip and they worked amazing.',
#   'Its a lot brighter with duracell batteries. I belive there are better batteries for it but idk.',
#   "These are very lightweight and last forever on a single AA battery.I use them for evening strolls around (an increasingly dark as winter is upon us) set of streets and the flash mode make me very obvious to oncoming cars.Super lightweight, and built to last. I have been using them for months without an issue. They even work well with rechargeable batteries.One caution: Rechargeable batteries + LED's mean that when the power drops below the minimum the LEDs need, you will find that the light just stops working, unlike a bulb which dies slowly, this can cut off entirely. But keep a good charge and you won't be disappointed.",
#   'Thank you',
#   'THEY PUT THE OLD FLASH LITES TO SHAME. I HAVE BOUGHT MANY',
#   'goes perfectly with my bug out bag',
#   'Lights work well and are bright. You have to cycle by pressing buttons for the three different settings. Not bad for the price.'],
#  ['3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on December 11, 2017',
#   'on December 11, 2017',
#   'on December 10, 2017',
#   'on December 9, 2017',
#   'on December 6, 2017',
#   'on December 6, 2017',
#   'on December 5, 2017',
#   'on December 4, 2017',
#   'on December 2, 2017',
#   'on December 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_26 = url+str(26)
soup_26 = bs4.BeautifulSoup(requests.get(url_26).text, 'html5lib')
review_general_26 = soup_26.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_26 = review_general_26.find_all('div', attrs={'class': 'a-section review'})
review_title_26 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_26]
review_body_26 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_26]
review_stars_26 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_26]
review_date_26 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_26]
review_title_26, review_body_26, review_stars_26, review_date_26
# Out:
# (['great value for the money and brighter beam than expected',
#   'Five Stars',
#   'They worked well and I loved the clip',
#   'Five Stars',
#   'One Star',
#   'Five Stars',
#   'Nice bright compact light for the price',
#   'Great little light.',
#   'Surprising!',
#   "these are working great. I've had them for a few months and ..."],
#  ['great value for the money and brighter beam than expected. Nice telescoping feature that allows you to adjust the light beam width/brightness',
#   'These little things pack a punch! They let out tons of light despite the small size.',
#   'Bought these to keep on us during hurricane Irma. They worked well and I loved the clip. Made it a bit harder to lose track of.',
#   'Great flashlights',
#   'I would give these 0 zero star if the option were available. The flashlights broke within a week.',
#   'These lights are EXCELLENT for the price!',
#   'Nice bright compact light for the price.  The focused beam is an odd square shape, but not an issue for me.  Have been using for about 3 months and seem to be good quality.  Will buy more.',
#   'Great little light. Well worth the money. Built well for a small light.',
#   "The switch button on the end operates easily, but not so easily as to come on when, say, searching for my keys and being dead the next day.I like the single AA battery.I like the compact size. It's bright for its size-and this goes to the one thing I disliked: one photo shows this lite brightly illuminating both sides of a sidewalk. This doesn't quite do that. That overstatement is what gets this 4 stars instead of 5 from me. I got over that quickly. Ounce for ounce, this unit pulls its weight.",
#   "So far, these are working great.  I've had them for a few months and they've been on a few camping trips.  I like this size flashlight because they are easy to give to the kids and have them put them in their pockets.  Big flashlights get set down, and forgotten."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on November 30, 2017',
#   'on November 27, 2017',
#   'on November 27, 2017',
#   'on November 27, 2017',
#   'on November 26, 2017',
#   'on November 26, 2017',
#   'on November 25, 2017',
#   'on November 24, 2017',
#   'on November 24, 2017',
#   'on November 23, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_27 = url+str(27)
soup_27 = bs4.BeautifulSoup(requests.get(url_27).text, 'html5lib')
review_general_27 = soup_27.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_27 = review_general_27.find_all('div', attrs={'class': 'a-section review'})
review_title_27 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_27]
review_body_27 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_27]
review_stars_27 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_27]
review_date_27 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_27]
review_title_27, review_body_27, review_stars_27, review_date_27
# Out:
# (['looks like a toy',
#   'Very good little lights. Nice and bright. Need to buy more of them.',
#   'Well one worked great, the other one did not work since day ...',
#   'Four Stars',
#   'Five Stars',
#   'Perfect!',
#   'Great flashligths',
#   'Good, solid, small flashlights - great for camping',
#   'Great lights',
#   'They will be great for the glove box of the'],
#  ['Small than expected, looks like a toy, not a real big torch.',
#   'Very good little lights. Nice and bright. Need to buy more of them.',
#   'Well one worked great , the other one did not work since day one, was not so bright and just went off. Got a new battery and turned on and then off. DEAD NOW...SO , I WOULD NOT BUY! DID I MENTION THAT WE got HIT BY MARIA? YEAH AND REALLY NEEDED IT!',
#   'Very good.',
#   'fantastic lights! great value super bright.',
#   'These guys are perfect. I love their little size. And even though small they provide so much light. I love that I can spotlight or shine a large area. I am very satisfied and would order another one of these packs anytime!',
#   'Highly potent beams, sturdy and compact, great flashligths.',
#   "Great little flashlights for camping/hiking.  I kept one in my backpack for any emergency that might arise while hiking.  And the other in the car to use at my campsites.  I used the campsite flashlight EVERY night - it's small enough to comfortable fit in your pocket and bright enough to walk the dog and/or walk to the bathroom in near complete darkness and only had to replace the battery once.  The only complaint I have is that it seems to always rotate into strobe mode when I would turn it on - a little irritating, but not a deal breaker.",
#   'Very bright and durable',
#   'smaller than I expected, but that is ok. They will be great for the glove box of the vehiclesupdate, so far one of the lights works great, very bright. The other one however does not work when put together, I am hoping for a replacement'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on November 22, 2017',
#   'on November 21, 2017',
#   'on November 21, 2017',
#   'on November 20, 2017',
#   'on November 20, 2017',
#   'on November 20, 2017',
#   'on November 20, 2017',
#   'on November 19, 2017',
#   'on November 18, 2017',
#   'on November 18, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_28 = url+str(28)
soup_28 = bs4.BeautifulSoup(requests.get(url_28).text, 'html5lib')
review_general_28 = soup_28.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_28 = review_general_28.find_all('div', attrs={'class': 'a-section review'})
review_title_28 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_28]
review_body_28 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_28]
review_stars_28 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_28]
review_date_28 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_28]
review_title_28, review_body_28, review_stars_28, review_date_28
# Out:
# (['Five Stars',
#   'Love these cute little flashlights',
#   'Terrible. Did not light up consistently while pushing the ...',
#   'The price for these was great. For such a tiny item',
#   'Four Stars',
#   "for $10 i guess it's barely acceptable. but annoying",
#   'Four Stars',
#   'Not a good quality',
#   'Five Stars',
#   'One Star'],
#  ['Great flashlights!',
#   'perfect little flashlights!',
#   'Terrible.  Did not light up consistently while pushing the button.  Both flashlights had the same issue as they would eventually turn on after pushing the button repeatedly (5 or 6 times).  These are junk.',
#   "The price for these was great.  For such a tiny item, they are very bright.  Great in case of a hurricane when candles just won't do.",
#   'Gooooooood',
#   'fairly dim.also you have to adjust the tension of the battery cap just so. if you tighten it all the way the flashlight wont function, usually. inconsistent.',
#   'These are awesome, one has already started shorting out. Also be sure to have a spare battery with you!',
#   'One of the flash light stop working after about a month to use. It seems like the switch problem to something internal. Not recommendable',
#   'what a great deal',
#   "One DOA, second one can't use button to turn light off."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on November 17, 2017',
#   'on November 17, 2017',
#   'on November 16, 2017',
#   'on November 16, 2017',
#   'on November 16, 2017',
#   'on November 14, 2017',
#   'on November 14, 2017',
#   'on November 14, 2017',
#   'on November 13, 2017',
#   'on November 13, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_29 = url+str(29)
soup_29 = bs4.BeautifulSoup(requests.get(url_29).text, 'html5lib')
review_general_29 = soup_29.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_29 = review_general_29.find_all('div', attrs={'class': 'a-section review'})
review_title_29 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_29]
review_body_29 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_29]
review_stars_29 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_29]
review_date_29 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_29]
review_title_29, review_body_29, review_stars_29, review_date_29
# Out:
# (['I was expecting too much out of these little guys ...',
#   'CHEAP IN PRICE, CHEAP IN QUALITY',
#   "I wasn't expecting a lot on this very small flashlight but i guess good things comes in small packages",
#   'Two Stars',
#   'Light',
#   'i guess i need to read description better or measure better',
#   'Very good item!',
#   'Good buy',
#   'Great buy. Good price and they have three modes',
#   'Five Stars'],
#  ['I was expecting too much out of these little guys. Ad says 300 lumens if im remembering correctly. Id say theyre more around 90-110lumens. 3/4 have scratched lenses which isnt too much of an issue but considering theyre scratched on the inside, it could come as a concern to others.',
#   'Expect what you pay for. These started malfunctioning after ±6 uses. Really cheaply made. Expect to have these break very fast.',
#   "A very solid purchase, this flashlight blow my mind, I wasn't expecting a lot on this very small flashlight but i guess good things comes in small packages.",
#   'Not bright at all but handy enough',
#   'great value',
#   'would not buy again. why to small.  i guess i need to read description better or measure better.  these are sooooo small.  They work ok too but just to sarn small.',
#   'Though these were cheap quality but they are metal and really brite.Very good item!',
#   "It works as described. Does the job for me. Kids use it all the time and they're still intact. Batteries last decent amount of time so worth the money",
#   'Great buy. Good price and they have three modes. Low high and sos.  They also come with zoom that will allow more light and will put up a nice square when you pull the front on the flash light forward.',
#   'these things put out a lotta light .'],
#  ['2.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on November 11, 2017',
#   'on November 11, 2017',
#   'on November 11, 2017',
#   'on November 11, 2017',
#   'on November 11, 2017',
#   'on November 10, 2017',
#   'on November 9, 2017',
#   'on November 9, 2017',
#   'on November 8, 2017',
#   'on November 8, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_30 = url+str(30)
soup_30 = bs4.BeautifulSoup(requests.get(url_30).text, 'html5lib')
review_general_30 = soup_30.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_30 = review_general_30.find_all('div', attrs={'class': 'a-section review'})
review_title_30 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_30]
review_body_30 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_30]
review_stars_30 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_30]
review_date_30 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_30]
review_title_30, review_body_30, review_stars_30, review_date_30
# Out:
# (['Great for the kids while Camping',
#   'They work great. Light weight',
#   'I love',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Highly recommend',
#   'Superb quality, extremely bright flashlight',
#   'Four Stars',
#   'Five Stars'],
#  ['Even though, the wide angle gives a decent spray of light. With a fresh battery, these lights struggled to light the bushes from 50 yards away. That does not mean if you want to use these babies in the attic, while checking the rat traps, you wont have great light, but when you zoom the lens for a tighter Beam... you\'ll find a "square" which is emitted by the LED module/crystal. Which is okay, (for kids) but not great if you need to really see that "thing" that is right there... LOOKIN BACK AT YOU ......  All in all, this is great deal for a four pack of flashlights that you can give to the kids for a camping trip, to keep them all on the same wave, but if you\'re looking for something else to keep you out of the dark, and give yourself a chance to stay ahead of the critters... try something else.',
#   'Bought these as back up flashlights for the recent hurricane season. They work great. Light weight. Good price.',
#   'Bright, small, adjustable.  I love these',
#   'Very good, with high and low bright',
#   'very good Item... My recomendation 100%... only used a Battery....',
#   'Works as expected good product! A+',
#   'Great product!  Was very Impressed how much light they produce.  Perfect for walking my dog at night.  Feel a lot safer with these !!!!',
#   'Superb quality, extremely bright flashlight at an astoundingly low price. You will NOT be disappointed. I have them all over the house and in every car...ended up buying 8 of them.',
#   'good value',
#   'Good quality construction, bright light, working with no issues, using for hiking, back packing and on the nightstand'],
#  ['3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on November 7, 2017',
#   'on November 7, 2017',
#   'on November 7, 2017',
#   'on November 7, 2017',
#   'on November 7, 2017',
#   'on November 6, 2017',
#   'on November 4, 2017',
#   'on November 4, 2017',
#   'on November 4, 2017',
#   'on November 4, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_31 = url+str(31)
soup_31 = bs4.BeautifulSoup(requests.get(url_31).text, 'html5lib')
review_general_31 = soup_31.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_31 = review_general_31.find_all('div', attrs={'class': 'a-section review'})
review_title_31 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_31]
review_body_31 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_31]
review_stars_31 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_31]
review_date_31 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_31]
review_title_31, review_body_31, review_stars_31, review_date_31
# Out:
# (['Five Stars',
#   'Very small in size',
#   'One Star',
#   'Three Stars',
#   'My favorite small flashlight',
#   'Nice little torches',
#   'Police grade luminescence',
#   'Three Stars',
#   'Quality small size flashlights',
#   'Five Stars'],
#  ['Great lights.',
#   'VERY small in size (like 3 inches at most). Good for purses or kids backpacks.They work well tho.',
#   'weak',
#   'Works fine for close up lighting but distance is a problem.  Not the brightest either.',
#   'Really great flashlights, very bright, well made, for an excellent price.',
#   'Great little flashlights. These seem pretty rugged, have a focus setting and are very bright. Great purchase.',
#   'So bright it can be used as a weapon',
#   'Have to press the button repeatedly to cycle through the options.',
#   'The build quality is great and they were very useful during Hurricane Harvey but one of the flashlight in the 2-pack was defective and is hard to get it working.',
#   'Awesome flashlights!'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on November 4, 2017',
#   'on November 4, 2017',
#   'on November 4, 2017',
#   'on November 3, 2017',
#   'on November 3, 2017',
#   'on November 1, 2017',
#   'on November 1, 2017',
#   'on November 1, 2017',
#   'on November 1, 2017',
#   'on November 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_32 = url+str(32)
soup_32 = bs4.BeautifulSoup(requests.get(url_32).text, 'html5lib')
review_general_32 = soup_32.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_32 = review_general_32.find_all('div', attrs={'class': 'a-section review'})
review_title_32 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_32]
review_body_32 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_32]
review_stars_32 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_32]
review_date_32 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_32]
review_title_32, review_body_32, review_stars_32, review_date_32
# Out:
# (['good product',
#   'HELP',
#   'Five Stars',
#   'Buy These great brightness for the size and adjustable lens is awesome!',
#   'Four Stars',
#   'Four Stars',
#   'Five Stars',
#   'Five Stars',
#   'Four Stars',
#   'Sturdy and bright'],
#  ["handy.  don't know how long batteries last yet as they're still too new.  :)",
#   'One of the units does not work!!!  It should be replaced . There was no info as to who to contact. All the others work well.',
#   'I love these things. Such a steal for the price.',
#   'I love them the,1 fo me and 1 for mom very bright!!',
#   'good product',
#   'Ok nothing spectacular',
#   'Great lights',
#   'Perfect',
#   'Very good torchlights with zoom feature',
#   'Super bright and only takes one AA cell.  Seems very sturdy.'],
#  ['4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on October 31, 2017',
#   'on October 31, 2017',
#   'on October 31, 2017',
#   'on October 30, 2017',
#   'on October 30, 2017',
#   'on October 29, 2017',
#   'on October 28, 2017',
#   'on October 28, 2017',
#   'on October 28, 2017',
#   'on October 27, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_33 = url+str(33)
soup_33 = bs4.BeautifulSoup(requests.get(url_33).text, 'html5lib')
review_general_33 = soup_33.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_33 = review_general_33.find_all('div', attrs={'class': 'a-section review'})
review_title_33 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_33]
review_body_33 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_33]
review_stars_33 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_33]
review_date_33 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_33]
review_title_33, review_body_33, review_stars_33, review_date_33
# Out:
# (['Four Stars',
#   'Five Stars',
#   'Bright',
#   'Batteries not included.',
#   'Five Stars',
#   'Five Stars',
#   'Wish it did not flicker',
#   'Good working flashlights.',
#   'Not rugged. Not even a little...',
#   'They are decent!'],
#  ['Great flash Light for a great price.',
#   'Very bright and compact',
#   'Great gifts',
#   'Nice. Well made. Adjustable lens. Minimal packaging.  Batteries not included.',
#   'Great product!',
#   'very good',
#   'I thought the flashlight was good but I did not know that it flickers and I can’t use it for the intended purpose, which is to seat guest in a performing arts center.  Kind of disappointed',
#   'I used this type of flashlights before (they are rather generic), and these also perform as well or better than many brand name units. One thing to make sure is to tighten the clip screws using thread locker, as those screws tend to get loose over time and my get lost rendering the clip useless.',
#   "I got this in June of this year.  After less than four months, it's broken.  Something is rattling around inside, it won't zoom in all the way any more, and there are two rubber band like things that (I'm guessing) used to be inside the flashlight and are very likely related to why it isn't working any more.  My work backpack has a pocket on the shoulder strap. It had been in that pocket for maybe a month before I discovered it had broken.This flashlight is not rugged. Not even a little.  If clipping it on an office worker's backpack for a month breaks something... Well let's just say I'm glad I didn't get into a situation where I was relying on this light. Very glad.Oh, and nothing at all on this product offering about warranty, how to return it, etc.  Honestly, I wouldn't accept a replacement. Only a refund.One other and less important gripe: The pocket clip is way too rigid and is really hard to get on anything.  That's why I put it on the pocket on my backpack shoulder strap. I couldn't even get the clip over the edge of my jeans pocket without using a tool to pry it open.Move on...get something else. Anything.  A glow stick would be better and last longer.",
#   'They work well, lightweight and somewhat powerful. They do the job. Good on the battery also.'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on October 26, 2017',
#   'on October 26, 2017',
#   'on October 26, 2017',
#   'on October 25, 2017',
#   'on October 25, 2017',
#   'on October 25, 2017',
#   'on October 24, 2017',
#   'on October 24, 2017',
#   'on October 24, 2017',
#   'on October 24, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_34 = url+str(34)
soup_34 = bs4.BeautifulSoup(requests.get(url_34).text, 'html5lib')
review_general_34 = soup_34.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_34 = review_general_34.find_all('div', attrs={'class': 'a-section review'})
review_title_34 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_34]
review_body_34 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_34]
review_stars_34 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_34]
review_date_34 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_34]
review_title_34, review_body_34, review_stars_34, review_date_34
# Out:
# (['Useful in emergency situations and will glow only if exposed ...',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Tough, bright, compact and inexpensive, what more could one want?',
#   'WORST PRODUCT and CUSTOMER SERVICE',
#   'Five Stars',
#   'Durable',
#   'Two Stars',
#   'Don’t like the strobe light function'],
#  ["Brightness and modes are similar to all the other mini flashlights that are identical in shape. These flashlights do have glow in the dark rings that the competitors don't come with. Useful in emergency situations and will glow only if exposed to light beforehand. My main gripe is that the flashlights do not use the same mode again when you turn them on next time. It will choose the next mode. I like to use the high mode, but the next time I turn it on it will switch to low mode. If I leave it on low mode, it'll switch to strobe the next time I turn it on. Very frustrating having to cycle the modes each time.",
#   'Very bright and good for the price!',
#   'Very bright',
#   'Works very well..',
#   "The preformance and quality of these little flashlights is amazing.  I haven't used one long enough to expend the single AA cell but the amount of light they put out from 1.5 volts defies belief.  The color temperature is higher (bluer) than I would like for longer duration use, their small size makes up for that in convenience and their billet aluminum housing is as rugged as more expensive competitors",
#   'Unable to open battery cap of flashlights. Contacted supplier, still no response. Worst Product & Service.',
#   'Nice and bright',
#   'Very bright and heavy duty!',
#   'Very dim. Not worth the money.',
#   'One would not work. Amazon returned it. Don’t like the strobe light function.'],
#  ['3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars'],
#  ['on October 23, 2017',
#   'on October 23, 2017',
#   'on October 23, 2017',
#   'on October 23, 2017',
#   'on October 23, 2017',
#   'on October 22, 2017',
#   'on October 22, 2017',
#   'on October 22, 2017',
#   'on October 21, 2017',
#   'on October 21, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_35 = url+str(35)
soup_35 = bs4.BeautifulSoup(requests.get(url_35).text, 'html5lib')
review_general_35 = soup_35.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_35 = review_general_35.find_all('div', attrs={'class': 'a-section review'})
review_title_35 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_35]
review_body_35 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_35]
review_stars_35 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_35]
review_date_35 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_35]
review_title_35, review_body_35, review_stars_35, review_date_35
# Out:
# (['Love that it comes in a two pack',
#   'Five Stars',
#   'these flashlights are great. They seem very durable as well',
#   'Great little things, but I lost one.',
#   'Right Size',
#   'Works great. I like having only one AA batter to ...',
#   'One works great and the other has a disfunction when trying to ...',
#   'but for the size and being compact its easy to just leave it in a car to have ...',
#   'Not as bright as the Solaray one I have. ...',
#   'Love this little, bright light.'],
#  ['Very Bright and very portable. Love that it comes in a two pack. Would purchase again.',
#   "Great price, small and very bright- Easy fit in any pocket One can't have too many flashlights",
#   'For the price, these flashlights are great.  They seem very durable as well.',
#   "I was about to give it two stars since I was so sad that I lost one but then I realized that was silly. These are so bright and small! Great for camping or anything. Solid construction. Batteries haven't died. I'll buy more of these if I need more flashlights.",
#   'Right size. Easy to store in small emergency bag.',
#   'Works great.  I like having only one AA batter to replace.',
#   'One works great and the other has a disfunction when trying to use the “spot light.”  It won’t stay in place and I manually have to hold it.',
#   'The flash lights are just ok they are not as bright as I thought they would be. but for the size and being compact its easy to just leave it in a car to have just in case.',
#   'Not as bright as the Solaray one I have. These always want to start out flashing so I have to remember to push button twice.',
#   'Excellent flashlight.  Puts out a lot of light from a compact, durable body, uses only a single AA battery.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on October 21, 2017',
#   'on October 21, 2017',
#   'on October 21, 2017',
#   'on October 20, 2017',
#   'on October 19, 2017',
#   'on October 19, 2017',
#   'on October 19, 2017',
#   'on October 19, 2017',
#   'on October 18, 2017',
#   'on October 18, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_36 = url+str(36)
soup_36 = bs4.BeautifulSoup(requests.get(url_36).text, 'html5lib')
review_general_36 = soup_36.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_36 = review_general_36.find_all('div', attrs={'class': 'a-section review'})
review_title_36 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_36]
review_body_36 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_36]
review_stars_36 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_36]
review_date_36 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_36]
review_title_36, review_body_36, review_stars_36, review_date_36
# Out:
# (['Five Stars',
#   'Awesome and bright flashlight',
#   'this isnt  the one',
#   'Sending tons of these al9ng with batteries and led lamps ...',
#   'Great lights! Extremely bright',
#   'Five Stars',
#   'Five Stars',
#   'Three Stars',
#   'Five Stars',
#   '0/2 is good'],
#  ['Nice',
#   'These flashlights are great!  They work off of a standard AA battery which are cheap and easy to get.  Nice looking and great build.  High beam, low beam, and flashing.  The size of the beam is adjustable by sliding the lens in/out and once the flashlight is on you can change modes by lightly tapping the orange button.  I did get these flashlights at a highly discounted price but they are definitely worth the full price of $5 each!',
#   'update. both flashlights have ceased working after less than a month. so the verdict is; do not buy this product.fantastic little flashlight!! very bright and love the zoom feature.  I use it to walk dogs in the dark and it is perfect.',
#   'Sending tons of these al9ng with batteries and led lamps to 0yerto Rico. Folks having sone seruoys power  issues there.',
#   'Great lights!  Extremely bright.  The cost makes these quite the bargain.  I placed one in each of my cars.  I plan on buying more to put in my squad car for an emergency, and to carry while I am on duty.  By far the brightest light I have ever owned for the size.',
#   'nice flashlight for the value.....',
#   'This was a great buy and they work well.  Good to keep in the car glove box.',
#   "They're bright but very small. Gets the job done tho",
#   'Terrific lights you can carry for a walk, etc.  Fits in your pocket. Recommended.',
#   "Update: now they both have faulty switches. sometimes, won't turn on, sometimes, flickers, etc. I realize that it was 3 modes, this in't that. while they worked I could easily switch between modes.One of the flashlights stopped working reliably after maybe 10-20 minutes of use. The other still works great. Like all the other flashlights that look exactly like this it's a cheap copy of some high end design so quality control is not great."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on October 18, 2017',
#   'on October 17, 2017',
#   'on October 17, 2017',
#   'on October 17, 2017',
#   'on October 16, 2017',
#   'on October 15, 2017',
#   'on October 15, 2017',
#   'on October 14, 2017',
#   'on October 13, 2017',
#   'on October 13, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_37 = url+str(37)
soup_37 = bs4.BeautifulSoup(requests.get(url_37).text, 'html5lib')
review_general_37 = soup_37.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_37 = review_general_37.find_all('div', attrs={'class': 'a-section review'})
review_title_37 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_37]
review_body_37 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_37]
review_stars_37 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_37]
review_date_37 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_37]
review_title_37, review_body_37, review_stars_37, review_date_37
# Out:
# (['Great little flashlight',
#   'Great gift for a guy as mine keep dissapearing!',
#   'Five Stars',
#   'Solidly-Constructed Mini Flashlights',
#   'Five Stars',
#   'Five Stars',
#   'Great flashlights',
#   'Nice Little Light - Good Value',
#   'Five Stars',
#   'Tactical... Why not?'],
#  ['Great little flashlight. Bright and adjustable for close up or distance.',
#   'I really liked these...so did the repairmen in my home as they walked away with the two I owned!  Great gift for a man apparently!',
#   'Super bright lights. Work great and love they only take 1 AA battery.',
#   'This is a pair of solidly constructed, bright mini flashlights.Plan to leave one home and use the other for travel.',
#   'Great',
#   'super bright, and very handy. great buy for under $10',
#   'These flashlights are the BOMB! Love their size and brilliant light.  Reminds me of the flashlight seen on the tv show CSI.',
#   'For the money - these are very good little flashlights.  Slightly bulky to carry in a pants pocket.  Easy to carry in a purse, pack, coat pocket, or car.  I use these with the mini butterball 14500 batteries.  The total cost for the flashlights, batteries, and charger is about $20 for two.  I like the strobe mode for use as an emergency signal.  My only "beef" with the flashlight industry in general is the black color.  Seriously?  The point of a flashlight is to improve visibility in the darkness.  Try finding a jet black flashlight during a power outage!  Flashlights should be neon yellow or orange.  I don\'t care what they look like.  I want something I can easily find and use.  Please stop making black colored flashlights or provide options.',
#   'It was just as described',
#   "Bought them because who wouldn't want to have a tactical flash light for about $7? My friends and I laughed that we all had one for the same reason lol Until I had to use it during Hurricane Maria in Puerto Rico, it is a really good product."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on October 13, 2017',
#   'on October 12, 2017',
#   'on October 12, 2017',
#   'on October 11, 2017',
#   'on October 9, 2017',
#   'on October 9, 2017',
#   'on October 8, 2017',
#   'on October 8, 2017',
#   'on October 8, 2017',
#   'on October 8, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_38 = url+str(38)
soup_38 = bs4.BeautifulSoup(requests.get(url_38).text, 'html5lib')
review_general_38 = soup_38.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_38 = review_general_38.find_all('div', attrs={'class': 'a-section review'})
review_title_38 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_38]
review_body_38 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_38]
review_stars_38 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_38]
review_date_38 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_38]
review_title_38, review_body_38, review_stars_38, review_date_38
# Out:
# (['They are easy to use and provide sufficient light despite their small ...',
#   'Great!',
#   'Small but very bright.',
#   'Five Stars',
#   'Besides metal casing, lower quality than Harbor Freight $2 LED flashlights',
#   'Crap!',
#   'I donated these to people that needed them in Texas ...',
#   'Bright, efficient, easy to use.',
#   'Super powerful and bright.',
#   'Five Stars'],
#  ['All six flashlights worked perfectly out of the box and allows us to have quality flashlights in multiple rooms around the house.  They are easy to use and provide sufficient light despite their small form factor.',
#   'These are very sturdy, durable flashlights. They are also decently bright with two different light settings. Would definitely recommend.',
#   'Small but very bright. Bought four and keep in various places around house!',
#   'These are great',
#   'So I was hoping for a durable metal flashlight that had better than average candle power. What I got was essentially a $3 flashlight with a metal casing.First impressions were it was alittle lighter than I imagined.The light was not even that bright. I dug out a $1.99 Harbor Freight LED flashlight and compared the 2 on my basement wall. The H Freight one out shined the Rockbird one easily. Not terrible enough to junk or return, a small metal casing flashlight could come in handy.But when I need a bright light, I wont be reaching for this',
#   'Pure crap! They end up in garbage can two days after arrival. Very low quality.',
#   'I donated these to people that needed them in Texas for the hurricane.  I am sure they are getting used',
#   'Very bright and efficient. Easy to use.',
#   'Awesome little flashlights. Super powerful and bright. Would recommend.',
#   'Great lights for outside and inside came in handy during hurricane Irma.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on October 8, 2017',
#   'on October 8, 2017',
#   'on October 6, 2017',
#   'on October 6, 2017',
#   'on October 6, 2017',
#   'on October 5, 2017',
#   'on October 5, 2017',
#   'on October 4, 2017',
#   'on October 4, 2017',
#   'on October 4, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_39 = url+str(39)
soup_39 = bs4.BeautifulSoup(requests.get(url_39).text, 'html5lib')
review_general_39 = soup_39.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_39 = review_general_39.find_all('div', attrs={'class': 'a-section review'})
review_title_39 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_39]
review_body_39 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_39]
review_stars_39 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_39]
review_date_39 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_39]
review_title_39, review_body_39, review_stars_39, review_date_39
# Out:
# (['Five Stars',
#   'Very good lights',
#   'Five Stars',
#   'Good but TINY',
#   'Overall a very useful light. However be aware that it chews up ...',
#   'Powerful little handheld flashlights and extremely useful to have',
#   'Worth every penny!!',
#   'Three Stars',
#   'Four Stars',
#   'Five Stars'],
#  ['Good light at cheap price',
#   'Very good lights use them to look into computers and copiers. Came in real handy during the tropical storm..',
#   'Super bright light in a small package.',
#   'These are extremely tiny, they fit in the palm of my tiny lady hands but they are powerful and work great....I just want people to know because the picture can be deceiving.  I would still recommend these as I use them alot.',
#   'Overall a very useful light. However be aware that it chews up AA batteries. Battery life is frankly awful.',
#   'Powerful little handheld flashlights and extremely useful to have! They come in handy and I have them in several rooms, my car and tucked away where I would need them inthe dark. Easy to carry, they are unobtrusive so make it very easy to stash them.',
#   'These are awesome.  Would buy again.  Strong light!!',
#   'Very practical and perfect for my camping adventures',
#   "Good little lites!  A bit cheaply made, however, you can't beat the price!",
#   'Theses are very nice soon buy some more'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on October 4, 2017',
#   'on October 3, 2017',
#   'on October 3, 2017',
#   'on October 3, 2017',
#   'on October 2, 2017',
#   'on October 2, 2017',
#   'on October 2, 2017',
#   'on October 2, 2017',
#   'on October 2, 2017',
#   'on October 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_40 = url+str(40)
soup_40 = bs4.BeautifulSoup(requests.get(url_40).text, 'html5lib')
review_general_40 = soup_40.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_40 = review_general_40.find_all('div', attrs={'class': 'a-section review'})
review_title_40 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_40]
review_body_40 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_40]
review_stars_40 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_40]
review_date_40 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_40]
review_title_40, review_body_40, review_stars_40, review_date_40
# Out:
# (['Five Stars',
#   'Normal',
#   'Five Stars',
#   'Four Stars',
#   'Great Flashlight',
#   'A good little pair of flashlights!',
#   'Five Stars',
#   'Great deal',
#   'Good product; sweet deal($)',
#   'Five Stars'],
#  ['Great deal on a 4 pack. Light works good.',
#   'A lot smaller than I expected. Smaller than a palm of a hand. Nothing special about them. Brightness of flash light is normal.',
#   'Great deal and very small and compact.  Easily fits in a pocket or car glove box. Extremely bright!',
#   'They work great and it only takes one battery but it is nothing special',
#   'Love these! I carry one in my purse at all times. The size is great and the light is bright. I like being able to adjust the light as well.',
#   "Great little flashlights; bright as heck... To insert the battery; unscrew from the back of the unit. I failed the first time trying to unscrew the front. I've had it for over a month now, and still on the same battery I've first inserted with moderate usage. These flashlight has a good weight to them giving me a indicator of a quality product. I will buy more for emergencies.",
#   'Well made, really inexpensive',
#   'Great deal',
#   'Good product; sweet deal($); quick delivery.',
#   'Very well made aluminum lights for a great price.'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on October 1, 2017',
#   'on October 1, 2017',
#   'on October 1, 2017',
#   'on October 1, 2017',
#   'on September 30, 2017',
#   'on September 29, 2017',
#   'on September 29, 2017',
#   'on September 29, 2017',
#   'on September 28, 2017',
#   'on September 28, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_41 = url+str(41)
soup_41 = bs4.BeautifulSoup(requests.get(url_41).text, 'html5lib')
review_general_41 = soup_41.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_41 = review_general_41.find_all('div', attrs={'class': 'a-section review'})
review_title_41 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_41]
review_body_41 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_41]
review_stars_41 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_41]
review_date_41 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_41]
review_title_41, review_body_41, review_stars_41, review_date_41
# Out:
# (['Good buy.',
#   'Five Stars',
#   'Works great.',
#   'Rock solid flashlight',
#   'Solidly made',
#   'Best of the best',
#   'One of 2 has failed',
#   'Good Deal!',
#   'not bad but not 300 lumens',
#   'Five Stars'],
#  ['Excellent quality.',
#   'Excellent flashlight and a very good value.',
#   'Arrived in perfect condition, on time. Each one works great. Very happy. Have them scattered around the house.',
#   'Great flash light',
#   'Very solidly made. Very bright and the beam is easily changed from concentrated to broad by sliding the lens. Runs on one AA battery which is easy to change. The LED is easily changed as well if needed. There were two in the package. The main problem is that there are three modes: bright, dim and bright strobe and you need to cycle thru all of them to get to the one you want. Every time you turn it on. It does not stay on the last mode used.',
#   'Best of the best, use regular AA battery, just one battery. Similar flashlight I had in the past use 3.7v battery. Pain in the neck to get one. So I discarded. This one is the best. I am giving it as a gift to many people. Thanks for designing with common sense battery.',
#   'I use the flashlight with a 14500 battery. The flashlight works well - however one of the 2 flashlights has failed - I guess you get what you pay for',
#   "These are very nice, sturdy little flashlights, and it's hard to beat the price. They might not be as bright as other flashlights, but they certainly put out enough light for my needs.",
#   'these are decent lights for the price but are not 300 lumens more like 100. compared it to a 125 lumens I already have and its not even as bright',
#   'Great for the kids camping trips. Light is bright!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 27, 2017',
#   'on September 27, 2017',
#   'on September 27, 2017',
#   'on September 27, 2017',
#   'on September 27, 2017',
#   'on September 27, 2017',
#   'on September 27, 2017',
#   'on September 26, 2017',
#   'on September 26, 2017',
#   'on September 26, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_42 = url+str(42)
soup_42 = bs4.BeautifulSoup(requests.get(url_42).text, 'html5lib')
review_general_42 = soup_42.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_42 = review_general_42.find_all('div', attrs={'class': 'a-section review'})
review_title_42 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_42]
review_body_42 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_42]
review_stars_42 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_42]
review_date_42 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_42]
review_title_42, review_body_42, review_stars_42, review_date_42
# Out:
# (['Happy with it',
#   'Five Stars',
#   'Five Stars',
#   'Delighted with this 6-pack of small',
#   'not bad.',
#   'Good value',
#   'One Star',
#   'Five Stars',
#   'nice',
#   "I'm happy with my purchase"],
#  ['Bright light! Happy with it.',
#   'Great for suitcases, cars, etc., while traveling; we now have 5 of them for our travels.',
#   'Best yet',
#   'Delighted with this 6-pack of small, VERY bright flashlights.Only minor quibble is that it\'s unclear when pressing the "On" button will turn on a solid light, versus turning on a rapidly-flashing light.(Apparently the flashing light - which may or may not come on - is to confuse all those terrible criminals that are trying to attack you ... \'cause, you know, you\'re so likely to face that "tactical" situation.)Other quibblette is that it\'d be nice to be able to remove the pocket-clip (but it\'s attached with 2 unusual screws). On the other hand, if it was removed, then the flashlight would roll freely on any surface on which one might lay it - which would NOT be "desirable".  So, at least the pocket-clip keeps the otherwise completely round flashlight from rolling when layed-down.All in all, I LIKE \'em - a LOT!  :-)',
#   'Theyre flashlights, not incredible, not bad.',
#   'Nice, bright little flashlight for the money. I bought a couple to have on hand for power outages and I think these will be just what I need (although I have larger, camping lantern style lights if I need to light a bigger area).',
#   'does not work',
#   'Great Quality ... Very durable',
#   'Nice product, I love it because the price is reasonably and really high-quality. So I want to give it more stars!',
#   "this is a tiny flashlight but it is very bright. I'm happy with my purchase!"],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 26, 2017',
#   'on September 26, 2017',
#   'on September 26, 2017',
#   'on September 26, 2017',
#   'on September 26, 2017',
#   'on September 25, 2017',
#   'on September 25, 2017',
#   'on September 25, 2017',
#   'on September 24, 2017',
#   'on September 24, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_43 = url+str(43)
soup_43 = bs4.BeautifulSoup(requests.get(url_43).text, 'html5lib')
review_general_43 = soup_43.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_43 = review_general_43.find_all('div', attrs={'class': 'a-section review'})
review_title_43 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_43]
review_body_43 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_43]
review_stars_43 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_43]
review_date_43 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_43]
review_title_43, review_body_43, review_stars_43, review_date_43
# Out:
# (['I love them, very compact and bright light',
#   '... when they were only $8 They are such a great value and only take one AA battery',
#   'Poor quality',
#   'Great light and tough material for the price',
#   'Nice',
#   'Excellent',
#   'Impressed',
#   'Great deal',
#   'nice and bright for as small as they are,',
#   'Great little light!'],
#  ['I  love them , very compact and bright light.',
#   'I bought these (2) when they were only $8  They are such a great value and only take one AA battery.',
#   'Poor quality.  I thought these would be pretty decent, like the J5 tactical flashlights, but they are not.  The reflector and insides of one has already come apart and is not easily repairable.',
#   'For the price I paid I expected to be no so tough, but they have lasted so far, and the light they provide is very bright, my only complain one of them had a defective switch, but was an easy task to tear it apart and fix it.',
#   'Great little flashlights.',
#   'Very sturdy.  If you knew me, you would know I am rough on flashlights, but they have held up well to being dropped, tossed and banged.The beam is very clear and bright and has multiple adjustments on it. It even has a strobe light. Well made and very compact but packs a punch in features and brightness. Excellent product.',
#   'I typically do not write reviews, but I was impressed when I put in a AA battery. Very small flashlight, but super bright. I did not notice a big difference in brightness between the spray view and the focused view, but there could be a difference in distance (just guessing). My purpose for these was to be prepared during power outages and to maybe use while camping.  I am buying some more soon. I could see these as a nice gift.',
#   'Amazing little lights. Very bright and well made.Incredibly inexpensive for what you get.',
#   'I like these little light, bought for the tool box, and are bright,',
#   'Very bright and compact.  Work great around the grill.'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 24, 2017',
#   'on September 24, 2017',
#   'on September 24, 2017',
#   'on September 24, 2017',
#   'on September 24, 2017',
#   'on September 23, 2017',
#   'on September 22, 2017',
#   'on September 22, 2017',
#   'on September 22, 2017',
#   'on September 22, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_44 = url+str(44)
soup_44 = bs4.BeautifulSoup(requests.get(url_44).text, 'html5lib')
review_general_44 = soup_44.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_44 = review_general_44.find_all('div', attrs={'class': 'a-section review'})
review_title_44 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_44]
review_body_44 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_44]
review_stars_44 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_44]
review_date_44 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_44]
review_title_44, review_body_44, review_stars_44, review_date_44
# Out:
# (['These are great little flashlights for the price',
#   'Super Bright',
#   'Bright for small',
#   'Works great',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Four Stars',
#   'Small but mighty!',
#   'Love the AA battery size'],
#  ["Nice sized, bright flashlights. They have 3 settings - bright, dim and strobe, and you can adjust the lens so it either floods or is very narrow. You really can't beat them for the price, and the form factor is great for throwing one in a drawer, one in your truck, etc.Also running on only 1 AA battery is nice! Battery is not included though.",
#   'Love these little lights. Super bright. The strobe light can be used as a defensive weapon. It totally can slow someone down.',
#   'It is bright for a little flashlight. I always have it with me. I keep one in the car and one in my bag. I would buy this one again.',
#   'Very bright and compact',
#   'Great product',
#   'Excellent pocket or purse protection.  We ordered these for the hurricane season.  Perfect.',
#   'Works great, small, light and bright,',
#   'Good little lights for the money.',
#   'I’m actually surprised the amount of lights it puts out... and the ability to change the focus is amazing... Lowell made and compact.... After receiving the flashlight, I end up ordering another pair... try it and you won’t be disappointed...',
#   'very bright. Love the AA battery size. I assume it can burn for many hours?'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 22, 2017',
#   'on September 22, 2017',
#   'on September 22, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017',
#   'on September 21, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_45 = url+str(45)
soup_45 = bs4.BeautifulSoup(requests.get(url_45).text, 'html5lib')
review_general_45 = soup_45.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_45 = review_general_45.find_all('div', attrs={'class': 'a-section review'})
review_title_45 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_45]
review_body_45 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_45]
review_stars_45 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_45]
review_date_45 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_45]
review_title_45, review_body_45, review_stars_45, review_date_45
# Out:
# (['Five Stars',
#   'Blinded by the light',
#   'One Star',
#   'Its an okay flash light',
#   'Very practical product.',
#   'One for purse one for car.',
#   'Three Stars',
#   'Very Useful, & Bright!',
#   'They work just fine.',
#   'Pretty good.'],
#  ['Bright. 3 settings, strobe, bright and dim. Can focus light smaller.',
#   "Wow these work great, can't believe you get 2",
#   'One worked and the other would not.',
#   "They are pretty bright but nearly impossible to turn off. The connection is horrible where the battery goes. I got a great deal so it is okay but I wouldn't buy again.",
#   "I'm really glad I got these.  I keep one in the kitchen (for finding equipment in all the dark corners of cabinets) and one next to the attic door (I'm afraid I use the attic as kind of an extended storage closet).  They're very bright and I particularly like the ability to broaden or narrow the beam.  They're generally all-around handy for those of us with poor vision who need an extra boost of light at times.  They're also great for finding a pet that's hiding from you because it doesn't want it's medicine.",
#   "Everything they say about these flashlights is true as far as compact, fantasitic light, heavy duty and so on. They are 10 times better than the plastic ones you get in wally world. I like the clip on it because I can clip it to the pocket inside my purse which is at the top  and I don't have to go fumliing around in the bottom looking for it when I need it. This is one of the best deals on amazon and I promise you will love them .",
#   "Weird it doesn't come with batteries",
#   "Nice bright light. And it's cool that you can widen or narrow the beam, depending on the situation. Very happy with them.",
#   'The small flash lights are just what we needed.  They work just fine.',
#   'works good.  Love that it takes 1 AA and its pretty bright for what it is.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 20, 2017',
#   'on September 20, 2017',
#   'on September 20, 2017',
#   'on September 20, 2017',
#   'on September 20, 2017',
#   'on September 20, 2017',
#   'on September 19, 2017',
#   'on September 19, 2017',
#   'on September 19, 2017',
#   'on September 19, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_46 = url+str(46)
soup_46 = bs4.BeautifulSoup(requests.get(url_46).text, 'html5lib')
review_general_46 = soup_46.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_46 = review_general_46.find_all('div', attrs={'class': 'a-section review'})
review_title_46 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_46]
review_body_46 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_46]
review_stars_46 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_46]
review_date_46 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_46]
review_title_46, review_body_46, review_stars_46, review_date_46
# Out:
# (['One Star',
#   'Bright flashlight works great',
#   'I like the size and that it takes just one AA ...',
#   'Irma tested!',
#   'Five Stars',
#   'Great but be Careful of Quality!',
#   'Five Stars',
#   'One Star',
#   'Seemed high quality, power/selector button is flawed',
#   'Five Stars'],
#  ['Light does not go on sometimes and sometimes it switches itself into strobe mode on its own.',
#   "These are amazing and the multiple features are great too. Got 1 for my vehicle and gave 1 to hubby, he says it's a great quality product.",
#   "One of the two lights had a defective switch. The one working light is lower quality than similar products I have seen, but is bright enough. I like the size and that it takes just one AA battery. I'll keep this in my office for emergency use during power outages.",
#   'They ran all night during hurricane Irma. Really did the job! Great quality.',
#   'Great little light; good beam quality; heavy duty case.',
#   "I'd gotten these previously and it was time to get a few more.I was happy with the initial batch but while they're intelligently designed, the quality of the last batch I got wasn't great. 2 of the 4 didn't function properly. Though I will say the price is pretty exceptional.",
#   'Great flashlight, small but powerful ;)',
#   'after the First time using the flashlight it fell out of my pocket and it hasnt worked since.',
#   "These seem solid and good quality. However after using for one camping trip (right out of the box) the power button/mode selector on the flashlight has developed a short. It is indecisive on whether or not it will turn on at all when clicked, and the half click to change modes guarantees it shuts off and you're hard pressed to get it to turn back on again. I should have been thorough about putting these through the paces during the return window before trying to rely on them.",
#   'Very bright, neat can hold on a keyring  very helpful around the home etc.'],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 18, 2017',
#   'on September 18, 2017',
#   'on September 18, 2017',
#   'on September 17, 2017',
#   'on September 17, 2017',
#   'on September 17, 2017',
#   'on September 16, 2017',
#   'on September 15, 2017',
#   'on September 15, 2017',
#   'on September 15, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_47 = url+str(47)
soup_47 = bs4.BeautifulSoup(requests.get(url_47).text, 'html5lib')
review_general_47 = soup_47.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_47 = review_general_47.find_all('div', attrs={'class': 'a-section review'})
review_title_47= [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_47]
review_body_47 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_47]
review_stars_47 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_47]
review_date_47 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_47]
review_title_47, review_body_47, review_stars_47, review_date_47
# Out:
# (['These lights are so bright and we love the strobe light feature',
#   'It works great and the magnification is such a helpful thing',
#   'Neither flashlight worked. Checked my batteries in another light ...',
#   'Honestly not worth it I tried to use them for ...',
#   'meh',
#   'Flashy!',
#   'Good Flashlights',
#   'Five Stars',
#   'Very efficient and versatile little flashlights.',
#   'Great Flashlight!'],
#  ['These Babies pack a punch! These lights are so bright and we love the strobe light feature. I turned of the lights and my daughter and I each had our flashlights in hand and we had a dance party! So much fun and so worth the price. These things are awesome.',
#   'This flashlight deal is a steal! This light put out a strong beam for its size and its very durable. I am a locksmith and this has become my everyday flashlight. It works great and the magnification is such a helpful thing. I would highly highly recommend this product because the brightness, durability and the cost. Get you one and i promise you will not regret it!',
#   'Neither flashlight worked.  Checked my batteries in another light , problem with Rockbirds flashlight ,',
#   'Honestly not worth it I tried to use them for work and they worked half the time. The light would randomly start to change then just stop working. Just stay away from these',
#   "They are okay, but not very bright if only using regular batteries.  Don't get these unless you want to invest in the extra powerful battery/charger.  This doesn't put out nearly the light that the duracell 350 puts out with 4 aaa batteries(I use rechargables)",
#   'Great product at a great price!',
#   "Very small flashlights but they work well. I would have given a full 5 stars but one of them wanted to be annoying and not work 100% of the time. The light exposure was great, it gave a lot of bright light. They only take 1 AA battery which is great. I purchased a 24 pack of AA's with these flashlights- both were a good purchase.",
#   'nice and bright',
#   'Great little flashlights with good power and variable light beam to fit different situations. They were very useful and efficient in a power outage during a hurricane. I ordered two more.',
#   "My wife purchased these under her Amazon account in preparation for a coming hurricane, as backups to our main flashlight. I was very pleasantly surprised by the brightness and quality of the flashlights. They have three modes, dim, strobe, and bright, and I liked them so much that they were used as our primary lights when we lost power. We stood them on end to light an entire room as well as to move about the house from room to room. They were great for checking for damage in the dark once the hurricane had passed. They use only one AA battery each (not included) and they hold a charge for quite a while. We were without power for 27 hours with storm shutters on the house, so it was dark even during the day, and the flashlight that we used to light the main room only needed it's battery changed once."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 15, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 14, 2017',
#   'on September 13, 2017',
#   'on September 13, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_48 = url+str(48)
soup_48 = bs4.BeautifulSoup(requests.get(url_48).text, 'html5lib')
review_general_48 = soup_48.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_48 = review_general_48.find_all('div', attrs={'class': 'a-section review'})
review_title_48 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_48]
review_body_48 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_48]
review_stars_48 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_48]
review_date_48 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_48]
review_title_48, review_body_48, review_stars_48, review_date_48
# Out:
# (['Bought before hurricane Irma. Wanted led flashlights. Small ...',
#   'Small, but mighty',
#   'These flashlights had high and low beam as well flashers ...',
#   'Awesome Flashlights!',
#   'Perfect',
#   'One Star',
#   'Very bright!',
#   'Not as bright as expected. One very irritating feature ...',
#   'Five Stars',
#   'Three Stars'],
#  ["Bought before hurricane Irma. Wanted led flashlights.  Small enough to fit in pocket.  They were exactly what we needed , as our power was off several days.Don't overlook this pair of mini flashlights. They do the job.",
#   "These ended up being very handy, but I didn't realize how small they would be. To be fair to the manufacturer I probably didn't grasp what the dimensions they posted really meant so it's in. I way their fault. For those of you who are not as found of math or lack basic sense of  spatial awareness (like me), these little guys are about palm size. Maybe a little smaller or bigger depending on your body proportions, but that's my best comparison out the gate.All that being said these are some nifty flashlights. They have a bright, medium, and strobe setting which you change by halfway pressing the power button. I found that out a bit of a startling way, but was none the less impressed. Overall I am satisfied with my purchase.",
#   'These flashlights had high and low beam as well flashers...my only complaint their size..looking at the picture,I was expecting something bigger.',
#   'Awesome flashlights! Definitely recommend!',
#   "Perfect little flashlight. Feels very durable and rugged. Has three settings: bright, less bright, and strobe. Runs on a single battery, so it's cheap and easy to use.",
#   'No durability, both of them broke quickly after purchase.',
#   'Surprisingly small flashlights, but work great and are very bright. Like the option to focus or in focus  (spread the beam) the light.',
#   "Not as bright as expected. One very irritating feature is that pressing the ON button cycles through the flashlight's modes. So, whenever you turn it on, it turns on in low light, strobe, or high (in that order).",
#   'These are great, light up the night, need to order 8 more!',
#   'NOT REAL BRIGHT'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars'],
#  ['on September 13, 2017',
#   'on September 13, 2017',
#   'on September 12, 2017',
#   'on September 12, 2017',
#   'on September 12, 2017',
#   'on September 12, 2017',
#   'on September 11, 2017',
#   'on September 11, 2017',
#   'on September 11, 2017',
#   'on September 10, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_49 = url+str(49)
soup_49 = bs4.BeautifulSoup(requests.get(url_49).text, 'html5lib')
review_general_49 = soup_49.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_49 = review_general_49.find_all('div', attrs={'class': 'a-section review'})
review_title_49 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_49]
review_body_49 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_49]
review_stars_49 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_49]
review_date_49 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_49]
review_title_49, review_body_49, review_stars_49, review_date_49
# Out:
# (['So much light from such a tiny flashlight',
#   'Nice!',
#   'smaller than expected',
#   'Excellent flashlight!',
#   'Drains battery fast but very bright and compact',
#   'Unreliable',
#   'Five Stars',
#   'A very good product',
#   'These mini LED flashlights are the best! I have several in our RV',
#   'Best frickin lil light at great price you can see ...'],
#  ['Very happy with my purchase! They are tiny metalmagic flashlights as they illuminate so much light!!!Perfect feeling in your hand and great for kids as well! Three modes: bright light, refular light and strobing ligh.',
#   'Pretty brigt for their size',
#   'good lights and feel sturdy but way smaller than expected.',
#   'Excellent flashlight!  Love it.  Very bright.  Requires only one battery.  Would buy more if needed.',
#   "A little bummed at how fast it's draining the battery, but it is very bright. Loving the bright and dim modes but kind of hating the strobe. I guess if you have a BYO strobe party it's cool or you have to defend yourself against a racoon, but otherwise it's another button you have to push to get to bright mode again",
#   "These are totally unreliable. Most of the time they don't On when you need them to.",
#   'Great product.',
#   'Incredible product for 9.99. I have rechargeable batteries and bought these because of hurricane Irma but the power save mode is much appreciated. It is very bright and the ability to focus the light if you need too is very helpful too. They are a little small (pocket sized) but they are quite strong. Like I said, incredible product for 9.99 ($5 each flashlight)',
#   'These mini LED flashlights are the best !  I have several in our RV.  I carry one in my purse and another one near the garage door in the kitchen.',
#   'Best frickin lil light at great price you can see 300 feet in the dark I have bought over 20 of them . JUST AWESOME PRODUCT'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 9, 2017',
#   'on September 9, 2017',
#   'on September 9, 2017',
#   'on September 9, 2017',
#   'on September 9, 2017',
#   'on September 8, 2017',
#   'on September 8, 2017',
#   'on September 8, 2017',
#   'on September 8, 2017',
#   'on September 8, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_50 = url+str(50)
soup_50 = bs4.BeautifulSoup(requests.get(url_50).text, 'html5lib')
review_general_50 = soup_50.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_50 = review_general_50.find_all('div', attrs={'class': 'a-section review'})
review_title_50 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_50]
review_body_50 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_50]
review_stars_50 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_50]
review_date_50 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_50]
review_title_50, review_body_50, review_stars_50, review_date_50
# Out:
# (['Really Nice Flashlights...love them',
#   'Decent flashlight, but mediocre design regarding the battery',
#   'Five Stars',
#   'Based on the good reviews, I bought this pack of two flashlights ...',
#   "... I thought it would be but it's still a great price for the amount of flashlights you",
#   'Five Stars',
#   'Handy little flashlights',
#   'Pleased',
#   'Do not buy!',
#   'Five Stars'],
#  ['Love these little lights!!  They are very well made, very nice, heavy duty flashlights.  I was extremely surprise at how nice they are.  Very happy with my purchase.  The light has different settings so that you can change how big a area to cover. Has a pocket clip.  Very Nice!!!',
#   "Bought these to put in my hurricane preparedness kit. They are ok. They feel solid, and the brightness is fine. However, when I put in the battery and tightened the cap the light came on and stayed on despite depressing the button. I loosened the cap a bit and it worked properly, but it seems like a design flaw. Not the best flashlight I've purchased, but I got two for $9.00, so for the price they are ok.",
#   'Great product, well worth the money....',
#   'Based on the good reviews, I bought this pack of two flashlights in preparation for Hurricane Irma, as I live in Central Florida. One of the two in the pack is defective. The on/off switch does not work so that the light shines as soon as the battery is in and it cannot be turned off without taking out the battery.',
#   "they are not as bright as I thought it would be but it's still a great price for the amount of flashlights you receive",
#   'good quality',
#   "I wasn't expecting much out of these and bought them as a quick fix for a camping trip, but I ended up loving them and I'll use them for more than camping! It's great that they only take one AA battery and the light is still quite bright. The clip  is handy, and they feel much more durable than I was expecting.",
#   'I was actually impressed with this item. Fit and finish were excellent. Would recomend to everyone',
#   'Horrible lights!! The lights change modes with any bump of the flashlight. I cannot keep them on one mode without them changing modes from power saving to flashing to high beam. Every single bump or vibration will change modes and cause the lid to come off and the battery pop off! Cheap and not worth the money!',
#   'Great flashlight, especially for the price!'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 7, 2017',
#   'on September 7, 2017',
#   'on September 7, 2017',
#   'on September 7, 2017',
#   'on September 6, 2017',
#   'on September 6, 2017',
#   'on September 6, 2017',
#   'on September 5, 2017',
#   'on September 5, 2017',
#   'on September 5, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_51 = url+str(51)
soup_51 = bs4.BeautifulSoup(requests.get(url_51).text, 'html5lib')
review_general_51 = soup_51.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_51 = review_general_51.find_all('div', attrs={'class': 'a-section review'})
review_title_51 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_51]
review_body_51 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_51]
review_stars_51 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_51]
review_date_51= [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_51]
review_title_51, review_body_51, review_stars_51, review_date_51
# Out:
# (['Five Stars',
#   'Five Stars',
#   'Big beam in small package',
#   'The others are fine, but disappointing to have one be defective',
#   'Very bright. Excellent product.',
#   'Great lights',
#   'Cheap / Broken - Do Not Buy',
#   'Five Stars',
#   'One Star',
#   'Good deal'],
#  ['Wonderful and very bright product for the price.',
#   'Great for the pocket and traveling',
#   'These are great little lights and put out a big adjustable magnified beam. They last about 3 years before switch or other problems develop but worth every bit of the money paid.',
#   "One of the four flashlights doesn't work.  The others are fine, but disappointing to have one be defective.  Actually,a second one has stopped working.  I am going to see if I can contact the seller.",
#   'These little guys are super bright. I used when I went fishing and it illuminated all my surroundings. The zoom in  zoom out mode of these flashlights is excellent. I am very happy with this purchase and highly recommend it for anyone who is looking for a small flashlight.',
#   'I swear i buy too many flashlights, even so, these are good lights for the price.  Bright enough for sure, and as compact as they are, easy enough to keep stored just about anywhere.I took one of these lights and attached it to the head of an old desk light i had that had stopped working.  Now, i have a great little spot light while working at my workbench.',
#   "Very unhappy with these -- they feel cheap, and one looks like it's been damaged. And now I find out that I can't return them.",
#   'Great little flashlights, make good gifts.  Sturdy and provide bright light.',
#   "No returns and that's no good",
#   'Shipped super fast. Works great. Recommend'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on September 5, 2017',
#   'on September 5, 2017',
#   'on September 5, 2017',
#   'on September 4, 2017',
#   'on September 4, 2017',
#   'on September 4, 2017',
#   'on September 3, 2017',
#   'on September 2, 2017',
#   'on September 2, 2017',
#   'on September 2, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_52 = url+str(52)
soup_52 = bs4.BeautifulSoup(requests.get(url_52).text, 'html5lib')
review_general_52 = soup_52.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_52 = review_general_52.find_all('div', attrs={'class': 'a-section review'})
review_title_52 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_52]
review_body_52 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_52]
review_stars_52 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_52]
review_date_52 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_52]
review_title_52, review_body_52, review_stars_52, review_date_52
# Out:
# (['Four Stars',
#   'Small flashlights with okay light.',
#   'BE AWARE--NO RETURN',
#   'Solid feel.',
#   'Worth it',
#   'Initial Quality Issues',
#   'Five Stars',
#   'Love them',
#   'Four Stars',
#   'Great price on this two pack'],
#  ['Good flashlight for a price.',
#   "Small flashlights with okay light.  Not something I'd use except maybe to find my way to the bathroom in the middle of the night",
#   'I ordered these last week and after putting a battery in the first one thought it seemed like a good product, especially liking the small size.  I tried putting a battery in the second one and it will not close.  Apparently the grooves are stripped so it will not hold the end which secures the battery.  I tried to return and today discovered they are NOT ELIGIBLE FOR RETURN so I have one flashlight instead of two.  I am wondering how long this one will last.',
#   "These lights have a nice, solid feel to them.  I like'em. I have not used them much so I can't comment on the operational quality.  All too often, cheap flashlights tend to start having problems with the on/off buttons or you have to smack them to get the light to turn on.  We'll see how these hold up.",
#   'Nice little flashlight. A lot of light for something this size. Definitely worth the price.',
#   "One of the flashlights worked great right out of the box. The second light had an issue with the focusing collar. Extending the collar took a greater amount of effort over the first one and it snapped back upon releasing it. If there's an o-ring inside, it's too snug and is creating vacuum on extension. It doesn't snap back all the way leaving about one-eighth inch gap. The only way I could retract it all the way was by rotating the collar as I pressed down and as I pulled up. Eventually I could fully extend it and retract it with no issues. The same flashlight had a short issue with the switch. One day upon pressing the on-off button it flashed on momentarily then remained off. Pushing down on the button had no effect and the switch would not lock in position. It wouldn't even rotate to the next position. I Removed the switch portion from the main body and tapped it on a table and tried pressing again. No change. I eventually screwed the switch back figuring that it was broken. After screwing it back on I tried  pushing the button one last time. It worked again! Probably some debris inside the switch worked free. I was going to ask the seller for a new switch as the problem could occur again at some inconvenient future time.",
#   'two small flashlights that light things you point at.',
#   'They work great.',
#   'Handy little things to have around the house and in the car. Very bright.',
#   'these babies are bright and do not really go through the batteries. Great price on this two pack.'],
#  ['4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 2, 2017',
#   'on September 2, 2017',
#   'on September 2, 2017',
#   'on September 2, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_53 = url+str(53)
soup_53 = bs4.BeautifulSoup(requests.get(url_53).text, 'html5lib')
review_general_53 = soup_53.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_53 = review_general_53.find_all('div', attrs={'class': 'a-section review'})
review_title_53 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_53]
review_body_53 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_53]
review_stars_53 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_53]
review_date_53 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_53]
review_title_53, review_body_53, review_stars_53, review_date_53
# Out:
# (['Nice small and handy flashlights',
#   'Bargain LED Flashlight.',
#   'Handy lil light',
#   "Flashlights are ok better than I expected can't really beat 2 flashlights for ...",
#   'Five Stars',
#   'Five Stars',
#   'Not a good product!',
#   'You get what you pay for',
#   'one is great, one is not!',
#   'Five Stars'],
#  ["Nice small and handy flashlights.  I kept one myself (always in my pocket), gave one to my wife and one to my grown-up son, and am keeping one in my car. Will be handy during very likely upcoming (now as the temperature has hit 100F) power outage and soon approaching Fall season's power outages.",
#   'For $4.50? This is nuts. One for each car.',
#   'I got them today n love them. Small n handy. I put one in my daughters car',
#   "Flashlights are ok better than I expected can't really beat 2 flashlights for the price only had for a few days but so far so good.2nd review haven't had the flash lights longs and starting to not work thought was good first 2 weeks then work half the time",
#   "These are great. Experienced a power outage. We're very helpful.",
#   'A must for everyone. Works very well',
#   "They aren't very bright and only turn on half the time. Don't waste your money.",
#   'One of them, the threads holding the battery cap in, stripped the first time that I took it off.',
#   'Received mine.  One of them is working great and very bright. One of them is not :( ... can I return only one of them?',
#   'Took these camping and they are fantastic. Could see stuff 10 campsites down!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on September 1, 2017',
#   'on August 31, 2017',
#   'on August 31, 2017',
#   'on August 31, 2017',
#   'on August 30, 2017',
#   'on August 30, 2017',
#   'on August 30, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_54 = url+str(54)
soup_54 = bs4.BeautifulSoup(requests.get(url_54).text, 'html5lib')
review_general_54 = soup_54.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_54 = review_general_54.find_all('div', attrs={'class': 'a-section review'})
review_title_54 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_54]
review_body_54 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_54]
review_stars_54 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_54]
review_date_54 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_54]
review_title_54, review_body_54, review_stars_54, review_date_54
# Out:
# (['Fairly Good Lights for the money!',
#   'Good for dealing with emergencies',
#   'Not great, but worth the price.',
#   'One for the price of two',
#   'Five Stars',
#   'Very bright',
#   'It works great.',
#   'DONT BUY!!!',
#   'Three Stars',
#   'good for the vehicle'],
#  ["Good lights, overall. I do have a couple complaints. But, nothing serious. 1)You can't turn off the 'emergency flashing light' function. Every other time you turn it on, it's on strobe. You have to turn it off and back on to get back to the regular light. There's no switch to shut that part off. 2)The barrel gets really hot after 4-5 minutes. Not burning your hand hot. But, it's not really comfortable after holding it 15-20 minutes. Other than those things, they're great lights. Even with my complaints, I use them almost daily. And, I would recommend them. They're cheap and affordable lights. And, you don't get everything you want on the cheaper economy priced stuff.",
#   'These work even when repeatedly submerged under water about 12" deep.  Good for dealing with emergencies, floods, surf fishing...',
#   "These flashlights aren't as bright as I expected, but they work. I don't really like how each press of the power button cycles through the three settings (bright, dim, flashing). When I press the power, I expect it to always start on the bright setting, but it doesn't. It goes to whatever setting was next in the rotation. It's not a big deal, but it's a little annoying.I would give these 3 stars, but the good price point bumps it up to 4. I didn't pay much for these, so they're mostly worth the price. I have another small flashlight I much prefer, but it was also a lot more expensive.",
#   "Opened the box, grabbed one of the flashlights, twisted the top off, placed the battery.  Seemed to work pretty good.  Then, I grabbed the other flashlight, twisted the... twisted the stuck top, pull the top, WD40 the top, twist the top while holding the body with pliers, threw in trash.  The top was welded on and stripped so badly there was nothing I could do to open it and place the battery.  If you're going to seal it shut, at least provide the battery.  Ridiculous.",
#   'These are amazingly good little flashlights.  Ten stars for the set!',
#   'These flashlights are amazing. I have a surefire tactical flashlight that cost over $100, and these flashlights are just as good or even better than my other flashlight. I think these are a great addition to any emergency or duty bag.',
#   '2/$3.91 What a steal. It works great.',
#   "Don't buy these little flashlights. When I got them one of the button on the back of the flashlight doesn't work and this product did not allow returns.",
#   'Fair value, very cheap and functional.',
#   'Work well, good for the vehicle.'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars'],
#  ['on August 30, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 29, 2017',
#   'on August 28, 2017',
#   'on August 28, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_55 = url+str(55)
soup_55 = bs4.BeautifulSoup(requests.get(url_55).text, 'html5lib')
review_general_55 = soup_55.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_55 = review_general_55.find_all('div', attrs={'class': 'a-section review'})
review_title_55 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_55]
review_body_55 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_55]
review_stars_55 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_55]
review_date_55= [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_55]
review_title_55, review_body_55, review_stars_55, review_date_55
# Out:
# (['My husband loved these. He had bought the traclight that is ...',
#   'Ordered For Me But Husband & Kids Took Them',
#   'Outstanding buy for the price',
#   'One works, ones detective.',
#   'Five Stars',
#   'Follow the light',
#   'One Bright, One Dim!',
#   'Great Flashlight',
#   'im shocked',
#   'Solid little light.'],
#  ["My husband loved these. He had bought the traclight that is shown on tv and compared these and one of those. He says that these work as good as the traclight. The best part for him was that he didn't need to spend much to get a good flashlight",
#   'I had to fight my husband and children for these lol. They are very bright and the clip makes it easy to store  on a pocket shirt or pants pocket.',
#   "After a power outage, I decided we needed more flashlights available. The cheap 9 LED flashlights just didn't cut it and it was a lot of trouble having to insert three batteries into the flashlight cartridge. I have only tried out one Rockbird but the results were good. It isn't the most powerful flashlight around but it does the job. It puts out plenty of light and inserting one AA battery is very easy. For general use, it is a very good flashlight. My only con is that it is black and hard to find in the dark and in dark drawers. Wish I was able to get them in silver.",
#   "One came damaged.... it only strobes no matter what we do. I was unable to return them. Otherwise, they're good quality",
#   'really good',
#   'Perfect size for purse or glove box. Great for carrying on night walks. Would give 5 star but i prefer sa wrist strap added.',
#   "Handy little flashlights and I thought the clip would be great for for those times I don't happen to have pockets.  So far I found that the metal bar is so tight that I can't it to clip on any clothing and I am afraid to pry it open too far in case it snaps off.I also received one that was great and one that was significantly dimmer.  Can't blame the batteries as I switched them out with the same results.If they were both the same intensity I would rate them 5 stars.",
#   'Nice, durable flashlights that are surprisingly very bright. This was a great addition to my emergency pack.',
#   'it is a bright,durable and cheap little light perfect for camping and the like.  i even used as an ice hammer when i forgot to close the lid on my ice chest and the top layer froze solid.  still works btw',
#   "Bright, well built, handy little flashlights.  Easy to carry in one's pocket.  Like that they only need a single AA battery."],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 28, 2017',
#   'on August 28, 2017',
#   'on August 28, 2017',
#   'on August 26, 2017',
#   'on August 26, 2017',
#   'on August 25, 2017',
#   'on August 25, 2017',
#   'on August 25, 2017',
#   'on August 24, 2017',
#   'on August 24, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_56 = url+str(56)
soup_56 = bs4.BeautifulSoup(requests.get(url_56).text, 'html5lib')
review_general_56 = soup_56.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_56 = review_general_56.find_all('div', attrs={'class': 'a-section review'})
review_title_56 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_56]
review_body_56 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_56]
review_stars_56 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_56]
review_date_56 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_56]
review_title_56, review_body_56, review_stars_56, review_date_56
# Out:
# (['Five Stars',
#   "Don't waste your money on flash lights that take AAA batteries",
#   'Great little lights.  Strong light.',
#   'Pretty good',
#   'Five Stars',
#   'Thank you',
#   'Very good flashlights only problem I have is that one of ...',
#   'Great item as expected',
#   'Five Stars',
#   'Fantastic Flashlights!!!'],
#  ['Good quality for the price.  Feel sturdy.',
#   "Incredibly bright! Don't waste your money on flash lights that take AAA batteries. These take just",
#   'Excellent.  Just what I needed.',
#   'One is really dim. It works though.',
#   'kinda small but will update when we go camping this thursday!',
#   'Thank you very much.',
#   'Very good flashlights only problem I have is that one of them will It open yo put a battery in.',
#   'Great item as expected',
#   'I like it',
#   'I was a little skeptical when I saw these because I got them on a super sale, but I would pay full price for these all.day.long. I have bought SEVERAL different flashlights and tactical light, and these so far have been my favorite!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 24, 2017',
#   'on August 22, 2017',
#   'on August 22, 2017',
#   'on August 22, 2017',
#   'on August 22, 2017',
#   'on August 22, 2017',
#   'on August 22, 2017',
#   'on August 21, 2017',
#   'on August 21, 2017',
#   'on August 21, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_57 = url+str(57)
soup_57 = bs4.BeautifulSoup(requests.get(url_57).text, 'html5lib')
review_general_57 = soup_57.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_57 = review_general_57.find_all('div', attrs={'class': 'a-section review'})
review_title_57 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_57]
review_body_57 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_57]
review_stars_57 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_57]
review_date_57 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_57]
review_title_57, review_body_57, review_stars_57, review_date_57
# Out:
# (['Five Stars',
#   'Review  on bockbirdes LED  flashlight A 100 mini superbright',
#   'Five Stars',
#   'Small but bright',
#   'Bright LED Flashlight',
#   "Don't waste your money",
#   'Four Stars',
#   'Great flash lights Are very bright and durable Small which ...',
#   'Five Stars',
#   'just like me: )'],
#  ['Great light',
#   "A OK flashlight for the price good for  fishing  hunting and outdoor activities  Like the fact that it's  made with a metal material  very bright  Love the belt clip  Good product",
#   'Great little flashlight. It works well and is very bright for its size.',
#   'Very bright, well made, I like that it only uses one battery.  Small enough to fit in my pocket.  I use it for dog walks at night.  It lights up the ground very well and has a decent light projection for being so some.  It was a very good buy.',
#   'The lights are great LED lights. They came in handy during a recent camping trip and a late night going trip. Great Bargain!!',
#   "These things are junk. They work for about 2 minutes and then they die. Not battery dead just dead. Don't waste your money",
#   'nlce flashligh like the fact aa battery',
#   'Great flash lightsAre very bright and durableSmall which makes it easy to carry around. Can keep it in your purse, car, bag, pocket, etc.good for anyone to use.',
#   'Great product',
#   'Small and powerful...just like me :)'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 21, 2017',
#   'on August 20, 2017',
#   'on August 19, 2017',
#   'on August 19, 2017',
#   'on August 18, 2017',
#   'on August 18, 2017',
#   'on August 18, 2017',
#   'on August 18, 2017',
#   'on August 18, 2017',
#   'on August 17, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_58 = url+str(58)
soup_58 = bs4.BeautifulSoup(requests.get(url_58).text, 'html5lib')
review_general_58 = soup_58.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_58 = review_general_58.find_all('div', attrs={'class': 'a-section review'})
review_title_58 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_58]
review_body_58 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_58]
review_stars_58 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_58]
review_date_58 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_58]
review_title_58, review_body_58, review_stars_58, review_date_58
# Out:
# (['Good deal',
#   'Five Stars',
#   'Five Stars',
#   'Awesome flashlights!',
#   'Absolute Garbage',
#   'Five Stars',
#   'Dangerous',
#   'Five Stars',
#   'Great flashlight',
#   'Perfect little flashlights'],
#  ['Great bright little flashlights!!!',
#   'I installed the batteries and they both worked great.',
#   'Great flashlight.  Great price!',
#   'Awesome flashlights!!! Small enough to carry with you without being a bother. Very bright. I love that they clip on your belt or pocket!',
#   'I bought these  flashlights to keep in the glove box of both cars to use in case of an emergency.  They both failed only after using them several times.  The product is garbage and i threw both of them away.  Not even worth the hassle of packaging them back up to send back.  You get what you pay for I guess.',
#   'Nice light.',
#   'One worked fine but the other heated up to an unsafe temperature, hot enough we removed the battery and disposed of it. If we had left it much longer it could have been seriously bad news.',
#   'Great for the price!',
#   'Excellent flashlight',
#   'These little guys are rugged, durable, functional, and easy to use.  Great purchase! Especially for the price, you cant go wrong.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 15, 2017',
#   'on August 15, 2017',
#   'on August 15, 2017',
#   'on August 15, 2017',
#   'on August 14, 2017',
#   'on August 14, 2017',
#   'on August 14, 2017',
#   'on August 12, 2017',
#   'on August 11, 2017',
#   'on August 11, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_59 = url+str(59)
soup_59 = bs4.BeautifulSoup(requests.get(url_59).text, 'html5lib')
review_general_59 = soup_59.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_59 = review_general_59.find_all('div', attrs={'class': 'a-section review'})
review_title_59 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_59]
review_body_59 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_59]
review_stars_59 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_59]
review_date_59 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_59]
review_title_59, review_body_59, review_stars_59, review_date_59
# Out:
# (['Five Stars',
#   'Three Stars',
#   'Five Stars',
#   'Five Stars',
#   'Very sad bout this',
#   'Game changing flashlight',
#   "Ok for price, didn't last super long.",
#   'Five Stars',
#   'Great choice',
#   'fantastic product.'],
#  ['Blinding light one battery love it',
#   'Not as expected',
#   'Nice little flashlights.',
#   'Love how compact it is- Gives off a bright beam',
#   "Was really excited for these lights. Poor quality the on/off button on one is failing it doesn't turn on and the others internals aren't holding together where it should slide to zoom very disappointed in this product.",
#   "This flash light proves great things come in small packages. It's compact sleek metal design is stunning. It has 3 different light modes. The first is a broad normal shine, the second is a more concentrated light such as a spotlight, the third is a blinking emergency type light. It also has a convenient clip located on the side for carting on your bag or clothes. I am 100% satisfied with this purchase. I am glad I ordered the two pack because my husband has already taken one. It is a great gift for men and women. It is great for the hunter or fisherman in your life because of the long range it shines. You will not be disappointed.",
#   "The flashlights haven't been very durable. The back button get's kind of finicky where you have to click it several times for it to turn back on.",
#   'Awesome Product works really good.',
#   'Great product. Small thought it was bigger but great!',
#   'For the price, fantastic product.'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 10, 2017',
#   'on August 10, 2017',
#   'on August 10, 2017',
#   'on August 10, 2017',
#   'on August 9, 2017',
#   'on August 8, 2017',
#   'on August 8, 2017',
#   'on August 8, 2017',
#   'on August 7, 2017',
#   'on August 7, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_60 = url+str(60)
soup_60 = bs4.BeautifulSoup(requests.get(url_60).text, 'html5lib')
review_general_60 = soup_60.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_60 = review_general_60.find_all('div', attrs={'class': 'a-section review'})
review_title_60 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_60]
review_body_60 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_60]
review_stars_60 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_60]
review_date_60 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_60]
review_title_60, review_body_60, review_stars_60, review_date_60
# Out:
# (['Five Stars',
#   'Five Stars',
#   'Four Stars',
#   'Not the brightest',
#   'Small, Compact and Bright',
#   'The ability to focus the beam is a very nice feature. The tactical teeth on both sides are ...',
#   'Five Stars',
#   'Excellent!',
#   'Five Stars',
#   'Five Stars'],
#  ['Awesome light and wicked bright',
#   'love the AA, bright, use it everyday',
#   'Good',
#   'Not as bright I thought it would have but works good.',
#   'Wow. What a great little flashlight. Very small and compact with a nice weight to it. Great solid construction. Use it when we walk the dogs at night and have them in each of our cars. The way this is constructed, even if you drop it, there’s no way to damage the glass. All you’d get is some dings and scratches on the body. The clip on the body is a nice touch. Plus you get the added benefit of getting 2.',
#   'For a 4 inch flashlight, this one packs a punch! It feels solid in your hand, but is not bulky when on your belt. It is very bright and has a long range. The ability to focus the beam is a very nice feature. The tactical teeth on both sides are not that sharp upon first look, but if used correctly would definitely hurt, especially if twisted upon contact. I have not tested the battery life or water resistance. In conclusion, I would agree that this is the best value all purpose flashlight.',
#   'Awesome little light that are zoomable and feel like quality',
#   'Small and bright!  Excellent!',
#   'Thought they would be larger but works good..',
#   'perfect'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on August 7, 2017',
#   'on August 7, 2017',
#   'on August 7, 2017',
#   'on August 7, 2017',
#   'on August 7, 2017',
#   'on August 7, 2017',
#   'on August 6, 2017',
#   'on August 5, 2017',
#   'on August 5, 2017',
#   'on August 5, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_61 = url+str(61)
soup_61 = bs4.BeautifulSoup(requests.get(url_61).text, 'html5lib')
review_general_61 = soup_61.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_61 = review_general_61.find_all('div', attrs={'class': 'a-section review'})
review_title_61 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_61]
review_body_61 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_61]
review_stars_61 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_61]
review_date_61 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_61]
review_title_61, review_body_61, review_stars_61, review_date_61
# Out:
# (['These LED Flashlights are so amazing an they last FOREVER',
#   'Five Stars',
#   'It appears to have good quality material',
#   'Quality - probably the best one made',
#   'Nifty little flashlights!',
#   'For the price these are very nice and worth it',
#   'Great product',
#   'Five Stars',
#   "Don't Think, Perfect High Quality Carry Ons",
#   'Four Stars'],
#  ['OMG;  who would buy regular flashlights anymore?  LED is the new bright light.... These LED Flashlights are so amazing an they last FOREVER!',
#   'Good product as described.',
#   'This flashlight is compact and it clips on to the hat, no need to hold it in my hand. The light is very bright and adjustable with the zoom in and zoom out. It appears to have good quality material. Highly recommended.',
#   'Exactly as described, and more. Well engineered item, water resistant 100%. Super bright white beam. Battery easy to replace. I will buy again - these make excellent gifts for friends and family (just make sure you order them some AmazonBasic AA batteries too :-)',
#   'These are pretty nifty flashlights! They are super bright but still nice and small. They seem to be very well made.',
#   "For the price these are very nice and worth it. They easily compete with my more expensive Fenix flashlights. I can't speak to battery life yet though. I am definitely happy so far with them. I will update this review if they break down or die quickly.",
#   'Not as powerful as I would have hoped but I got these things for like 5 bux on prime day so no complaints. Not gonna massively illuminate a path in a dark deserted forest for u, but does the job in the car, around the house and flashing cars walking the pupper',
#   'i like this flashlight, its size and weight are perfect for its performance',
#   'Bright as can be. Best survival kit addition. You should buy two of these sets. One for your back pack, one for you car, one for your apartment, and one for your travel bag. Seriously a great flashlight to carry along with you, everywhere. Very bright, focused and wide light adjustments, and durable!Buy buy buy! Ok Bye',
#   'Compact and solid'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on August 5, 2017',
#   'on August 5, 2017',
#   'on August 3, 2017',
#   'on August 3, 2017',
#   'on August 2, 2017',
#   'on August 2, 2017',
#   'on August 1, 2017',
#   'on August 1, 2017',
#   'on August 1, 2017',
#   'on July 30, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_62 = url+str(62)
soup_62 = bs4.BeautifulSoup(requests.get(url_62).text, 'html5lib')
review_general_62 = soup_62.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_62 = review_general_62.find_all('div', attrs={'class': 'a-section review'})
review_title_62 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_62]
review_body_62 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_62]
review_stars_62 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_62]
review_date_62 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_62]
review_title_62, review_body_62, review_stars_62, review_date_62
# Out:
# (['Five Stars',
#   'Nice lite for carrying or just extras in the glove box.',
#   'Two Stars',
#   'You get what you pay for!',
#   'Feel safe with these lights',
#   'Four Stars',
#   'Four Stars',
#   'Four Stars',
#   'Five Stars',
#   'Ok so far.....had about 2 months.,'],
#  ['Great little flashlights!',
#   'These are great... great size, excellent beam.  Used them while camping.',
#   'These are cheap knockoffs of a more quality product.  Not very bright.  Not worth the money.',
#   'Used around 10 times, already stopped working, when you can get it to turn on it goes from high to low to flashing all by its self!',
#   'I wish they had come with some instructions, but one can figure it out. Bright light, great for small places, like a car or purse, and easy to tuck ito a pocket for an evening walk.',
#   'good flashlight for the price. nice and bright. small size fits in pocket easily.',
#   'Good Deal.',
#   "It would've been nice if you could've adjusted the size of the light ? But still enjoy the light.",
#   'Awesome',
#   'Nice - in past flash lights crapped out after a few months - corroded with white stuff inside...will see how these do..'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 30, 2017',
#   'on July 30, 2017',
#   'on July 29, 2017',
#   'on July 29, 2017',
#   'on July 29, 2017',
#   'on July 29, 2017',
#   'on July 28, 2017',
#   'on July 28, 2017',
#   'on July 28, 2017',
#   'on July 28, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_63 = url+str(63)
soup_63 = bs4.BeautifulSoup(requests.get(url_63).text, 'html5lib')
review_general_63 = soup_63.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_63 = review_general_63.find_all('div', attrs={'class': 'a-section review'})
review_title_63 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_63]
review_body_63 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_63]
review_stars_63 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_63]
review_date_63 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_63]
review_title_63, review_body_63, review_stars_63, review_date_63
# Out:
# (['Rockbirds LED Flashlight',
#   'Five Stars',
#   "Don't work",
#   'A1',
#   'Five Stars',
#   'Five Stars',
#   'Got both light and was excited about them (from the ...',
#   'Five Stars',
#   'Cool flashlights',
#   'Great buy'],
#  ['Perfect size for evening walks!  Nice and bright for the size!',
#   'Great Flashlight',
#   "They don't work.  I bought them for a trip and they don't work.  What a waste of money",
#   'perfect',
#   'Great little flashlights!!!',
#   'very good',
#   'Got both light and was excited about them (from the description) one would not hold batteries because the threads were stripped. The other would not zoom/focus light the description stated it could 🤦🏻\u200d♂️ Very disappointing to say the least',
#   'Very good very good',
#   'Nice flashlights. Seem to be durable and perfect fit for a pocket.',
#   'Bright light and inexpensive.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 28, 2017',
#   'on July 28, 2017',
#   'on July 28, 2017',
#   'on July 27, 2017',
#   'on July 27, 2017',
#   'on July 27, 2017',
#   'on July 26, 2017',
#   'on July 26, 2017',
#   'on July 26, 2017',
#   'on July 26, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_64 = url+str(64)
soup_64 = bs4.BeautifulSoup(requests.get(url_64).text, 'html5lib')
review_general_64 = soup_64.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_64 = review_general_64.find_all('div', attrs={'class': 'a-section review'})
review_title_64 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_64]
review_body_64 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_64]
review_stars_64 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_64]
review_date_64 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_64]
review_title_64, review_body_64, review_stars_64, review_date_64
# Out:
# (['Small and very bt\\right.',
#   'one star',
#   'Five Stars',
#   'Buy in bulk',
#   'Four Stars',
#   'came as a 2 pack one flashlight only turns on ...',
#   'Five Stars',
#   'Five Stars',
#   'Three Stars',
#   'Five Stars'],
#  ['Small and very bt\\right.',
#   'Received July 1, 2017 & worked fine.  Now one is very dim and other will not work.  Very disappointed, please advise.',
#   'Good, sturdy, bright flashlight.',
#   'Never can have enough flashlights!',
#   'One out of 4 light was bad, other than that was ok.',
#   'came as a 2 pack one flashlight only turns on in dim mode, flash and high mode no longer work, was used on two or three times. The second one still works',
#   'works great.',
#   'good',
#   'they did not come with any info.',
#   'Good size, great intensity'],
#  ['4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 26, 2017',
#   'on July 26, 2017',
#   'on July 26, 2017',
#   'on July 24, 2017',
#   'on July 24, 2017',
#   'on July 24, 2017',
#   'on July 24, 2017',
#   'on July 23, 2017',
#   'on July 22, 2017',
#   'on July 22, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_65 = url+str(65)
soup_65 = bs4.BeautifulSoup(requests.get(url_65).text, 'html5lib')
review_general_65 = soup_65.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_65 = review_general_65.find_all('div', attrs={'class': 'a-section review'})
review_title_65 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_65]
review_body_65 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_65]
review_stars_65 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_65]
review_date_65 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_65]
review_title_65, review_body_65, review_stars_65, review_date_65
# Out:
# (['Great for bedside service.',
#   'Four Stars',
#   "Don't buy. Unreliable",
#   'Very Nice Flashlight(s)',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Danger!Danger!',
#   'Five Stars',
#   'Five Stars'],
#  ['Excellent flashlights.',
#   "Great flashlight just wish you didn't have to cycle through the modes everytime.",
#   'One does not work.',
#   'This small flashlight is small and shines very bight. Great deal for 2 Flashlights!',
#   'Great, powerful little flashlight that can focus its beam. Seems solid and sturdy.',
#   'Perfect size for my purse.',
#   'Excellent value.',
#   'Flashlight would not turn off and almost burned my hand. It seems there is a short and the battery power is turned into heat in the handle!',
#   'they are very useful',
#   'Great Value'],
#  ['4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 22, 2017',
#   'on July 22, 2017',
#   'on July 22, 2017',
#   'on July 21, 2017',
#   'on July 20, 2017',
#   'on July 20, 2017',
#   'on July 20, 2017',
#   'on July 18, 2017',
#   'on July 18, 2017',
#   'on July 18, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_66 = url+str(66)
soup_66 = bs4.BeautifulSoup(requests.get(url_66).text, 'html5lib')
review_general_66 = soup_66.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_66 = review_general_66.find_all('div', attrs={'class': 'a-section review'})
review_title_66 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_66]
review_body_66 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_66]
review_stars_66 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_66]
review_date_66 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_66]
review_title_66, review_body_66, review_stars_66, review_date_66
# Out:
# (['I like this flashlight. I recommend it.',
#   'Rockbirds LED Flashlight',
#   'Poor quality.',
#   'Four Stars',
#   "They're decent little lights",
#   'Strobe - Light & etc...',
#   'great gift for men and women',
#   'Five Stars',
#   'Perfect size for dusk dog walking',
#   'Pretty good'],
#  ['I like this flashlight, they are very bright and focus adjustable. Compare with MINI MAGLITE, this is very good and save more using 1 AA battery compare with the other brands. I recommend it.',
#   'The light is super Bright for its size. I am not sure how long it last on 1 set of batteries yet. I wish it had a rechargeable battery option so I gave it a 4 star.',
#   'one worked one did not work',
#   'good little and bright light',
#   'for the price its worth it. no batteries included.',
#   '10 bucks, 2 torches = yep , Yep ; YEP ! ! !this little torch is actually a flashlight as well :)sharp strong aluminum ;) with the weight a few coins...Quality ! @ \' chewing -gum \' " Prices " . . .Literally AwEsOmE ! ! !I got the twin pack, my only PROBLEM now is how do i justify buying  MORE when i have no need of any more of this Kool Lite ?/ Hugz ;)',
#   'great gift for men and women. Battery stay fresh even in the trunk of a car. The end switch needs to be checked as sometimes they needed reassembled to work correctly',
#   'This is an incredibly cool flashlight.  Very powerful for the size.  Impressed with quality. Great deal!',
#   "I bought these in lightening deal not entirely realizing the compact size (my husband is a flashlight fanatic). Wow, was I ever excited to open these up and realizing they fit into my dog walking bag. It's also a nice compact size to stash in my center console. Needless to say, hubby hasn't gotten one finger on these flashlights. These are mine, all mine.",
#   'Good bang for the dollar.'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on July 18, 2017',
#   'on July 17, 2017',
#   'on July 16, 2017',
#   'on July 16, 2017',
#   'on July 16, 2017',
#   'on July 15, 2017',
#   'on July 15, 2017',
#   'on July 14, 2017',
#   'on July 13, 2017',
#   'on July 13, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_67 = url+str(67)
soup_67 = bs4.BeautifulSoup(requests.get(url_67).text, 'html5lib')
review_general_67 = soup_67.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_67 = review_general_67.find_all('div', attrs={'class': 'a-section review'})
review_title_67 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_67]
review_body_67 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_67]
review_stars_67 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_67]
review_date_67 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_67]
review_title_67, review_body_67, review_stars_67, review_date_67
# Out:
# (['Bright! Just what I wanted!',
#   'TERRIBLE',
#   'Three Stars',
#   'Terrible product.',
#   'Reccommended.',
#   'Great lights for a great price.',
#   'Four Stars',
#   'liked them enough to order four more',
#   'Three Stars',
#   'Great light'],
#  ['Great price for the same basic light I had purchased for a higher price from another vendor.  Excellent! Small, lightweight and light stream can be narrow or wide angle.',
#   'Complete junk.  Worked for like a day',
#   'they are cool',
#   "As arrived, upon inserting the battery, the flashlight didn't turn on.  Only 1 of the flashlights worked.  The second flashlight, trash.",
#   'These work great. Have a good weight to them. Good quality for the price. Perfect size for a pocket or a purse.',
#   'These mini LED flashlights are perfect for my little ones to use while we are out camping. They are heavy duty yet light and water resistant so they can withstand the rain (it always rains while camping). With these you have the ability to focus and adjust the intensity of light. There are 3 different modes: high beam, low beam and flashing and it only takes one AA battery. My son loves the handy built-in clip; he can clip the flashlight to his pant pocket, on his shirt or where ever it fancies him. Only flaw to me is that the clip is quite stiff so it can be difficult trying to clip it on but it definitely stays in place. Overall, these are great, sturdy little lights for the money. You get alot of light from such a small flashlight.',
#   'Good flashlights so far. touch design. bright light.',
#   "Bought two of these...liked them enough to order four more. Recently opened a two pack of the second ones I ordered. Good light overall not great. Disappointed to find out one flashlight doesn't work out of the box brand new. Would've given five stars based on the value. Not an extremely bright light but better than average considering price. They also burn through AAA batteries quickly. Can't get past only getting half of what I paid for...that kills the value part that compensated for the average brightness.",
#   'Too small for regular use. They are listed as  mini though.',
#   'This was a daily deal.  Gave one to my husband-he loves it.'],
#  ['5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 12, 2017',
#   'on July 12, 2017',
#   'on July 12, 2017',
#   'on July 12, 2017',
#   'on July 11, 2017',
#   'on July 11, 2017',
#   'on July 11, 2017',
#   'on July 10, 2017',
#   'on July 10, 2017',
#   'on July 10, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_68 = url+str(68)
soup_68 = bs4.BeautifulSoup(requests.get(url_68).text, 'html5lib')
review_general_68 = soup_68.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_68 = review_general_68.find_all('div', attrs={'class': 'a-section review'})
review_title_68 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_68]
review_body_68 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_68]
review_stars_68 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_68]
review_date_68 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_68]
review_title_68, review_body_68, review_stars_68, review_date_68
# Out:
# (['Four Stars',
#   'Five Stars',
#   'but not happy description and actually product functions do not match',
#   'Im not bright, but my flashlight is.',
#   'Got a good deal on these $5 s piece',
#   'Five Stars',
#   'Four Stars',
#   "Not bad. One of them doesn't turn on anymore",
#   'Poor quality',
#   'Looks can be deceiving'],
#  ['Good cheap flashlight.',
#   'The light is much brighter when you use 14500 3.7 v battery.',
#   'The flashlight description stated online does not match the actual product. The product zoom is COMPLETELY different as stated in the pictures shown as what it actually does. Will keep flashlight, but not happy description and actually product functions do not match!!!',
#   'These are cery good flashlights and exactly what I expected. Flashlight doesnt stay on the same mode when turning off and on, but they do have a bright, dim, and strobe, and you can change the mode with a half push of the button while it is on.',
#   'Got a good deal on these $5 s piece, are very bright, or dimmer battery saving mode as well as strobe.',
#   'Very bright and tougher then most',
#   'Bought as a gift.',
#   "Not bad.  One of them doesn't turn on anymore, and not sure why.  Battery is good, and all connections seem good.  ???",
#   'Only one out of the two worked.  Something in the switching mechanism that turns the light on and off did not work.',
#   "At first I was going to give it 1 star....Upon opening my package, I see this tiny box. No way that's 1 flashlight, let alone 2. I open the tiny box and see 2 tiny flashlights. Great, I got ripped off. I put in a battery to try one out just for the hell of it. Was I wrong.....these tiny things are sweet. They pack as much light power as a bigger flashlight I have, which looks similar. These are great for BOB or EDC equipment. I might even buy a couple more."],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 9, 2017',
#   'on July 9, 2017',
#   'on July 9, 2017',
#   'on July 9, 2017',
#   'on July 8, 2017',
#   'on July 8, 2017',
#   'on July 8, 2017',
#   'on July 8, 2017',
#   'on July 8, 2017',
#   'on July 8, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_69 = url+str(69)
soup_69 = bs4.BeautifulSoup(requests.get(url_69).text, 'html5lib')
review_general_69 = soup_69.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_69 = review_general_69.find_all('div', attrs={'class': 'a-section review'})
review_title_69 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_69]
review_body_69 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_69]
review_stars_69 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_69]
review_date_69 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_69]
review_title_69, review_body_69, review_stars_69, review_date_69
# Out:
# (['Five Stars',
#   'Good and helpful.',
#   'love them!',
#   'ONLY ONE WORKS LIKE IT SHOULD...',
#   'Great Little Flashlights',
#   'Awesome.',
#   'Rip off',
#   'Five Stars',
#   'good deal work great and seem very durable thx',
#   'Five Stars'],
#  ['For 1 AAA battery, this flashlight is very bright.',
#   'Wish they were brighter. Have been very helpful around the house to look in dark closets or searching for things in the car. Good product.',
#   'Awesome produced, you will not be disappointed.',
#   'only one of the two i received works correctly.  one of them does the hi and lo and strobe.  the other one shines a light only.  china...',
#   "Totally worth the price. Much brighter than the LED flashlights you buy at the checkout counter for the same price and this needs just 1aa battery rather than 3aaa like the checkout counter models.  These are tiny -FYI.  They fit in your palm so don't expect something bigger.  Great little lights.  I bought 2 just to check them out. Now I'll order the six pack and stash them all over.Just ordered 4 more. They arrived and work great.",
#   'I was so impressed by the first set that I ordered a second set. Will make a great Christmas gift. Heavy duty and great lighting.',
#   "This didn't work at all when I got them and they didn't refund me the price I paid🙃😐",
#   'Bright light',
#   'these lights work great  nice and bright good to keep in auto just  incase thx',
#   'compact and work great.'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 8, 2017',
#   'on July 7, 2017',
#   'on July 6, 2017',
#   'on July 6, 2017',
#   'on July 6, 2017',
#   'on July 6, 2017',
#   'on July 6, 2017',
#   'on July 5, 2017',
#   'on July 5, 2017',
#   'on July 4, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_70 = url+str(70)
soup_70 = bs4.BeautifulSoup(requests.get(url_70).text, 'html5lib')
review_general_70 = soup_70.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_70 = review_general_70.find_all('div', attrs={'class': 'a-section review'})
review_title_70 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_70]
review_body_70 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_70]
review_stars_70 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_70]
review_date_70 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_70]
review_title_70, review_body_70, review_stars_70, review_date_70
# Out:
# (['Just ok.',
#   'Best damn little 5 buck flashlight for EDC I like ...',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   'Manual',
#   'these are super bright, need only one common AA battery',
#   'Quick shipping. Flash light is week compared to other ...',
#   'Love these lights!',
#   'These are as good as any light I have used'],
#  ["I don't like the modes that it forces you to cycle through. I have to click through dim and flasher modes before I get to the regular bright mode which is all I wanted in the first place. For the price it's a marginally ok product.",
#   "Best damn little 5 buck flashlight for EDC I like the nuts that are on the outside holding the clip on, several other types I've had used screws but screws require very small driver to tighten, these any pliers and your good to go again, the light with 1 AA gives almost as much as the NEBO Ihave that requires 3 AAAs strobe and multiple intensity beams all work very well. My only critique would be for a slightly less stiff clip it definitely stays on but requires an assist to clip on, or take out of pocket",
#   'These flashlights are AMAZING and so portable and bright!',
#   'work great, super handy.',
#   'Excellent quality and workmanship!',
#   'The only problem was there is no manual instruction.',
#   "these are super bright, need only one common AA battery. fit easily in glove box or center console of car. they don't weigh hardly anything so I imagine ideal for a purse as well. I'd purchase again in the future",
#   'Quick shipping.Flash light is week compared to other 300 lumens flash lights.  This may be due to the fact that it uses a single AA battery.Not recomended.',
#   'OMG! I love these flash lights!  I originally I got these for my survival kit. I put one in my survival pack and the other one in my purse.  I use the one in my purse all the time!  My purse is so big, I loose things!  Lol!',
#   'These are as good as any light I have used. I live in the woods and they light up the country side. I have one on my shotgun and it works great.Super compact size allows for east carry and mounting on a weapon.'],
#  ['3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on July 4, 2017',
#   'on July 4, 2017',
#   'on July 3, 2017',
#   'on July 3, 2017',
#   'on July 2, 2017',
#   'on July 1, 2017',
#   'on July 1, 2017',
#   'on July 1, 2017',
#   'on June 30, 2017',
#   'on June 30, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_71 = url+str(71)
soup_71 = bs4.BeautifulSoup(requests.get(url_71).text, 'html5lib')
review_general_71 = soup_71.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_71 = review_general_71.find_all('div', attrs={'class': 'a-section review'})
review_title_71 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_71]
review_body_71 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_71]
review_stars_71 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_71]
review_date_71 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_71]
review_title_71, review_body_71, review_stars_71, review_date_71
# Out:
# (['These flashlights are not actually 300lumens. They are not ...',
#   '50/50 chance',
#   'Five Stars',
#   "Feels like I'm using a 100 dollar flashlight so worth it ...",
#   'Worked well and were priced well.',
#   'Great Value',
#   'not as expected',
#   'Great little light.',
#   'I did not expect much from this light at this ...',
#   'Amazing little light!'],
#  ["These flashlights are not actually 300lumens. They are not even 200 lumens. When compared to other 300 lumen and a 200 lumen flashlight I found that with new batteries at its highest setting folly zoomed in, was still visibly dimmer than the 200 lumen flashlight. I bought the two pack, and compared both to each other with both new alkaline and fully charged nickle-cadmium rechargeable batteries and found that they do not even match each other in brightness. They're inexpensive, and were the compact size I was looking for, but it seems you get what you pay for, and in this case you pay for under 200 lumens.",
#   'One works fine, the other was DOA',
#   'More than I expected. Got these for 5 dollars a piece.',
#   "This item for 10 dollars is so worth it!!! Feels like I'm using a 100 dollar flashlight so worth it ordering more!!!!!",
#   'Worked well and were priced well.  The lights are bright, they include a strobe light and a wide to narrow beam focus and a belt clip.  They are made well from sturdy metal with no plastic parts.',
#   'Good value and quality. perfect for my needs',
#   'One failed within 5 days.the on off switch stopped working',
#   'Got two of these on deal of the day.  I should have bought a dozen and stashed them everywhere.  They work great and are small enough to use wherever a light is needed.  Very intense for a small light.',
#   'I did not expect much from this light at this price, but I did expect it to last longer than one day.  It did not.',
#   'I got a 2 pack on sale for like 8$. These are incredible little lights and being adjustable can focus on at a distance.'],
#  ['2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on June 30, 2017',
#   'on June 30, 2017',
#   'on June 30, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017',
#   'on June 29, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_72 = url+str(72)
soup_72 = bs4.BeautifulSoup(requests.get(url_72).text, 'html5lib')
review_general_72 = soup_72.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_72 = review_general_72.find_all('div', attrs={'class': 'a-section review'})
review_title_72 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_72]
review_body_72 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_72]
review_stars_72 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_72]
review_date_72 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_72]
review_title_72, review_body_72, review_stars_72, review_date_72
# Out:
# (['One Star',
#   'great item',
#   'So far so good, not super bright but not bad either',
#   'Great buy at a great price.',
#   'Birght light',
#   "It's Okay for the Price",
#   'tiny flashlights big area of light!',
#   'Disappointing.',
#   'Five Stars',
#   'Very Dim and Disappointing.'],
#  ['little rust inside and poor quality',
#   'great item',
#   'Just received these today. So far so good, not super bright but not bad either. They feel a little "flimsy" so not sure how long they will hold up. About what you\'d expect for $9, definitely wouldn\'t spend more than that.',
#   "I purchased the 2 pack. They arrived quickly. Only take 1 AA battery and it was easy to install. I bought them so I could keep one in my cars glovebox and one either on me or in my apt. For the price they are perfect. Heavy duty housing that doesn't feel cheap. Also has strobe function.",
#   'This flashlight is like having  your own personal automobile headlight. set to high beam. Very bright flashlight and barely the size of you pinky finger, incredible!!',
#   'These are not bad for the price, but you get what you pay for.  Few things to point out: 1. It uses a single AA battery and it is NOT included. 2. It has 3 light modes, bright, flashing-off-and-on quickly, and not-as-bright light modes.  I found this to be bit annoying, when I turn my flashlight on, I just want a bright light but with these, you have cycle through the other modes before you get to the simple "stay on" bright light mode.  I guess my fault for not reading the product description bit more carefully.',
#   'tiny flashlights big area of light! A++',
#   'Does not return to bright after powering off, full clicks cycle through modes the same way that half-clicks do. Brightness seems below what is advertised. Will likely return.',
#   'these flashlights are awesome!',
#   "Incredibly dim. The rubber on the button is warped and bubbled. I found metal shavings in the threading of the battery chamber. Did I mention that it is so dim it's pathetic? I was going to give this as a gift but after trying it out I would be so ashamed if I had given it. Other than the metal shavings, warped rubber button and a pretty poor battery fit it does feel like it does feel like it is a well built flashlight, too bad that its so weak at actually producing light."],
#  ['1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars'],
#  ['on June 27, 2017',
#   'on June 27, 2017',
#   'on June 27, 2017',
#   'on June 27, 2017',
#   'on June 27, 2017',
#   'on June 27, 2017',
#   'on June 27, 2017',
#   'on June 26, 2017',
#   'on June 26, 2017',
#   'on June 26, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_73 = url+str(73)
soup_73 = bs4.BeautifulSoup(requests.get(url_73).text, 'html5lib')
review_general_73 = soup_73.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_73 = review_general_73.find_all('div', attrs={'class': 'a-section review'})
review_title_73 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_73]
review_body_73 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_73]
review_stars_73 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_73]
review_date_73 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_73]
review_title_73, review_body_73, review_stars_73, review_date_73
# Out:
# (['One Star',
#   'One unit works great. It will be good for my tool box ...',
#   'Not all that good.',
#   'BRIGHT LIGHT FOR NIGHT',
#   'super bright',
#   'Nice portable flashlights.',
#   'Buy yourself a few of these great flash lights.',
#   'Five Stars',
#   'Five Stars',
#   'The one light is nice for the price but I paid for'],
#  ['The flashlights were defective when received.  One could not be opened to insert a battery.  Cheap and unreliable.',
#   'I know they were not expensive. One unit works great. It will be good for my tool box at work. The other .. the lens is messed up and not half as bright as the first. So in closing 50/50 dosnt work for me.',
#   "To be honest, I'm not impressed. I'm comparing these to my Streamlight Protac, which is also 300 lumens.Firstly, at first glance the construction seems fine. Quality of materials is ok.Secondly, there is no way in Hell that these flashlights are 300 lumens. I'd wager that they aren't even 100 lumens. Not bright at all.",
#   'SUPER BRIGHT COMPACT',
#   'i was really surprised how bright they were and they only take 1 AA battery per flashlight',
#   'Very bright light, non adjustable beam',
#   "I work at a hospital, at night. These work perfect when I don't want to disturb my patients and wake them up with a bright light. They are so cute and fit in my pocket of my uniform. I also keep one in my purse.",
#   "Incredibly bright light for it's size! Arrived in excellent condition, works perfectly. It's a great little light.",
#   'VERY Bright lights for the cost. Plus uses common AA Batteries.',
#   'Only received one light in my order. The one light is nice for the price but I paid for two'],
#  ['1.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on June 25, 2017',
#   'on June 25, 2017',
#   'on June 25, 2017',
#   'on June 24, 2017',
#   'on June 24, 2017',
#   'on June 24, 2017',
#   'on June 24, 2017',
#   'on June 24, 2017',
#   'on June 23, 2017',
#   'on June 23, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_74 = url+str(74)
soup_74 = bs4.BeautifulSoup(requests.get(url_74).text, 'html5lib')
review_general_74 = soup_74.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_74 = review_general_74.find_all('div', attrs={'class': 'a-section review'})
review_title_74 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_74]
review_body_74 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_74]
review_stars_74 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_74]
review_date_74 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_74]
review_title_74, review_body_74, review_stars_74, review_date_74
# Out:
# (['Five Stars',
#   "Don't pass em up",
#   'Five Stars',
#   'Three Stars',
#   'Not too shabby',
#   'Great product, one minor issue.',
#   'Four Stars',
#   'Rockbirds LED small flashlights',
#   'Five Stars',
#   'Five Stars'],
#  ['ty...I like',
#   'Bright, nice portable size.  they fit in my glove box.',
#   'They are small yet brilliant light. Great product!',
#   'One of the three flashlights did not work',
#   'Not too bad for the price I paid.  They are bright.  The area where the battery goes is a little hard to turn, but still worked just fine.',
#   'Overall love the light. Only thing keeping it from being 5 stars for me is that switching the modes around can be a pain because it switches the mode as soon as it is turned off.',
#   'Great little flashlights with very bright light!',
#   "Nice bright little LED flashlights, can't beat them for the price, love the adjust-ability and the different light modes.",
#   'Work good. Batteries  last a long time. Really bright',
#   'Perfect'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on June 23, 2017',
#   'on June 23, 2017',
#   'on June 22, 2017',
#   'on June 21, 2017',
#   'on June 21, 2017',
#   'on June 21, 2017',
#   'on June 19, 2017',
#   'on June 19, 2017',
#   'on June 17, 2017',
#   'on June 16, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_75 = url+str(75)
soup_75 = bs4.BeautifulSoup(requests.get(url_75).text, 'html5lib')
review_general_75 = soup_75.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_75 = review_general_75.find_all('div', attrs={'class': 'a-section review'})
review_title_75 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_75]
review_body_75 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_75]
review_stars_75 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_75]
review_date_75 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_75]
review_title_75, review_body_75, review_stars_75, review_date_75
# Out:
# (['Five Stars',
#   'Luis Miguel Niño',
#   '... beam strobe and high beam small and compact I love',
#   "It's not that bright, and only for a short ...",
#   'Five Stars',
#   'Four Stars',
#   'Four Stars',
#   'Buy It',
#   'good lights',
#   'great if you want to warm your hands in say-Alaska'],
#  ['Great, sturdy little light for the money. A lot of light from such a small flashlight.',
#   'Excelente producto',
#   'High quality product low beam strobe and high beam small and compact I love it',
#   "It's not that bright, and only for a short distant and you can't change the focus on bulb. But it is small and handy. I can carry it around all day to do my inspection for my spaces.",
#   'Husband loves them.',
#   'Uses just one AA battery, features adjustable beam by sliding the front part with the lens.',
#   'Good to have',
#   'Fantastic deal.  Buy it.',
#   'bought these on sale, they came 2 to the package.  nice quality, good light output, appear to be long lasting on the batteries.',
#   'When using for any amount of time these get really warm in your hand, great if you want to warm your hands in say-Alaska!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars'],
#  ['on June 16, 2017',
#   'on June 15, 2017',
#   'on June 14, 2017',
#   'on June 11, 2017',
#   'on June 11, 2017',
#   'on June 11, 2017',
#   'on June 10, 2017',
#   'on June 10, 2017',
#   'on June 9, 2017',
#   'on June 9, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_76 = url+str(76)
soup_76 = bs4.BeautifulSoup(requests.get(url_76).text, 'html5lib')
review_general_76 = soup_76.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_76 = review_general_76.find_all('div', attrs={'class': 'a-section review'})
review_title_76 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_76]
review_body_76 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_76]
review_stars_76 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_76]
review_date_76 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_76]
review_title_76, review_body_76, review_stars_76, review_date_76
# Out:
# (['Great little flashlights',
#   'A GREAT DEAL!',
#   'Five Stars',
#   'Nice flashlight',
#   'Flash light',
#   'great flashlight(s)',
#   'best flashlight to have',
#   'Bright!',
#   'and they look and feel pretty durable. Perfect to have in the house just ...',
#   'Five Stars'],
#  ['They work great, my some love them. Had a little problem figuring them out, but good now.',
#   'These little flashlights are mighty. They feel like they are going to last, metal not plastic.  Lots of light!',
#   "Wow, can't believe how much light we get out of this little one.",
#   'Love the size of these flashlights. Makes them easy to carry with you until you need it. Nice that they come in a pair. Can put one in my purse and one in the car. Very bright for the size it is.',
#   "Awesome light if you get this you'll like it I keep one in my room and one in the truck",
#   'great flashlight, and whats even better is that they come in a pair!!  and a great size, they easily fit in your pocket or sporting vest.  Click the on/off button 1/2 way and you get the strobe effect.  Strobe effect is great for walking at night making yourself more visible to cars, or also great for self defense if needed.',
#   'great Flashlight ,',
#   'These are tiny, but mighty. I can keep one in my pocket when needed. The light is very bright and illuminates well.',
#   "I ordered these because it's hurricane season here in Hawaii. They came just in time, and they look and feel pretty durable. Perfect to have in the house just in case.",
#   'These small flashlights are a lifesaver!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on June 8, 2017',
#   'on June 7, 2017',
#   'on June 6, 2017',
#   'on June 6, 2017',
#   'on June 6, 2017',
#   'on June 5, 2017',
#   'on June 4, 2017',
#   'on June 3, 2017',
#   'on June 2, 2017',
#   'on June 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_77 = url+str(77)
soup_77 = bs4.BeautifulSoup(requests.get(url_77).text, 'html5lib')
review_general_77 = soup_77.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_77 = review_general_77.find_all('div', attrs={'class': 'a-section review'})
review_title_77 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_77]
review_body_77 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_77]
review_stars_77 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_77]
review_date_77 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_77]
review_title_77, review_body_77, review_stars_77, review_date_77
# Out:
# (['Five Stars',
#   'easy to use',
#   'Great pocket sized flashlight',
#   'Very small but VERY bright I LOVE them!!!!',
#   'I like this pack of flashlight so much',
#   'Excellent for your go bag.',
#   'Five Stars',
#   'Five Stars',
#   'Great compact flashlights',
#   'Way smaller than I thought.'],
#  ['Super happy with how bright they are just wish they had come with batteries',
#   'They are small and light, easy to use. The best thing I like is it only need one battery, not three.',
#   'Great pocket sized flashlight. These are the best around. Super bright and I love that these can switch in several modes. Flash light can dim to safe on battery life, zoom in for a smaller focus, flash patterns, this is a must for every bug out bag or emergency kit',
#   'I love this set of 2 mini but very powerful flashlights I keep 1 in my purse and 1 in the drawer of my nightstand next to my bed for an emergency if the power ever goes out during a storm.  You can pull the top part up and down to make the light wider or smaller to fit the amount of light you need.  It also has a flashing light on it as well.  You can even clip the light to your pants belt clip that is on it. The LED bright light is perfect for helping you find your keys in the dark and also when walking at night time.  I will be getting me another set so my kids can have 1 for them to keep in they backpacks.',
#   'I like this pack of flashlight so much!! It comes 4 pieces in one package. Also it is very convenient to carry, you can also clip on your pocket!! The light is bright! I will consider buying another set.',
#   'Good quality.',
#   'Very bright light. Small enough to carry clipped inside my pocket. It is part of my EDC.',
#   'Very well made and super bright.',
#   "I used these flashlights at night when I take my dog out. They are very bright and work great. They are so small they fit in your pocket! I actually keep one on the leash at night. You can tell it's made of great quality! I can't believe 2 were only $10, it's an amazing value. You need these if you go outside in the dark at all!",
#   'Way smaller  than I thought. My fault'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on May 31, 2017',
#   'on May 31, 2017',
#   'on May 31, 2017',
#   'on May 30, 2017',
#   'on May 30, 2017',
#   'on May 30, 2017',
#   'on May 30, 2017',
#   'on May 30, 2017',
#   'on May 29, 2017',
#   'on May 29, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_78 = url+str(78)
soup_78 = bs4.BeautifulSoup(requests.get(url_78).text, 'html5lib')
review_general_78 = soup_78.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_78 = review_general_78.find_all('div', attrs={'class': 'a-section review'})
review_title_78 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_78]
review_body_78 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_78]
review_stars_78 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_78]
review_date_78 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_78]
review_title_78, review_body_78, review_stars_78, review_date_78
# Out:
# (['Campact and Bright light',
#   'I really like these little flashlights',
#   'Bright and perfect size',
#   'Great lighting',
#   'Four Stars',
#   'Five Stars',
#   'Awesome flashlight',
#   'I am very happy with how well these lights have worked',
#   'Like the fact in only takes 1 AA battery',
#   'Five Stars'],
#  ['Love the size, husband and I just got back from a camping trip to the beach. At night we used the flashlights for sand crabs. Also perfect fit in the small pocket of my beach bag. Also has a belt clip, my husband wore his. Bright light and has a blinking setting.',
#   'I really like these little flashlights.\xa0 They are perfect for keeping in your purse. They also can easily hook onto your waistband. This is what I carry for convenience and safety since they are such a compact size. Gave one to my teenage daughter too. The price is great for two',
#   'This set of two flashlights is a great deal. I bought these so I would have one for my purse and an extra around the house. They are super small and compact but brighter than most flashlights. Small and only takes up about as much room as some lip glosses.I love that it only takes one AA to function. These flashlights are great to keep around.',
#   "I purchased these flashlights to add to my bug out bag that I carry in my car. They're small, good quality, and only require 1 AA battery. It has a zoom in/out feature that is very handy. I also like that the power on and off button is at the end of the flashlight for quick access, whereas some other lights I've purchased have them on the side. My husband is using one for when he takes the dogs out to use the restroom at our apt complex and likes it.",
#   'good size and bright enough  for the price.',
#   'cheap item but excellent',
#   'These flashlights are awesome. They are small and able to be carried easily.  They give a lot of light and we got them just in time to use for a power outage which was perfect!',
#   'These flash lights are small but they put off so much light. I bought these for my family and I to take to the beach and use them to go crab hunting. I am very happy with how well these lights have worked.Great quality and compact which makes it easier to take anywhere or carry in purse.',
#   'handy little light to have. Like the fact in only takes 1 AA battery.',
#   'Very nice! A luxury box to cover these items.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 29, 2017',
#   'on May 28, 2017',
#   'on May 28, 2017',
#   'on May 27, 2017',
#   'on May 27, 2017',
#   'on May 26, 2017',
#   'on May 26, 2017',
#   'on May 26, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_79 = url+str(79)
soup_79 = bs4.BeautifulSoup(requests.get(url_79).text, 'html5lib')
review_general_79 = soup_79.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_79 = review_general_79.find_all('div', attrs={'class': 'a-section review'})
review_title_79 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_79]
review_body_79 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_79]
review_stars_79 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_79]
review_date_79 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_79]
review_title_79, review_body_79, review_stars_79, review_date_79
# Out:
# (['Great Buy',
#   'Small but bright',
#   'Flashlights',
#   'Four Stars',
#   'Five Stars',
#   'Great little flashlight',
#   'They are excellent and meet my every need',
#   'Five Stars',
#   'Five Stars',
#   'great'],
#  ['They work and price is unbeatable.',
#   'I really liked the Rockbirds LED flashlights. First of all, they came in a 2-pack. More is better so I can keep one in my truck and keep the second one for other uses. They fit just about anywhere and come with a clip. Secondly, for being a mini flashlight, it puts out a very bright light. And it is adjustable – wide to narrow focus. Plus, they come with 3 modes – bright, dimmer, and flashing. The feel of the flashlight is that of a good quality make – sturdy, easy to grip, and small enough to carry anywhere. Definitely a good buy.',
#   'Nice sized little flashlight! They are really bright and compact. Perfect for pocket sized emergencies and for keeping in your purse for extra reassurance.',
#   'good',
#   'Great miniature lights with big light output.',
#   'Great little flashlight.  Uses one AA battery.  Bright and very compact.  Can take it anywhere.  It has three modes: very bright, bright and a flashing mode.',
#   'Thank you for the Rockbirds LED Flashlights.  They are excellent and meet my every need.  I have have used them almost daily.  The brightess of the light is great and they hold a charge over a longer period of time.',
#   'Very good.',
#   'Awesome flashlight! Solid construction and the light range is amazing. You will not be disappointed with this purchase.',
#   'unbelievable how bright for a little light with rechargeable battery. great price'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 25, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017',
#   'on May 25, 2017',
#   'on May 24, 2017',
#   'on May 24, 2017',
#   'on May 23, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_80 = url+str(80)
soup_80 = bs4.BeautifulSoup(requests.get(url_80).text, 'html5lib')
review_general_80 = soup_80.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_80 = review_general_80.find_all('div', attrs={'class': 'a-section review'})
review_title_80 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_80]
review_body_80 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_80]
review_stars_80 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_80]
review_date_80 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_80]
review_title_80, review_body_80, review_stars_80, review_date_80
# Out:
# (['Great value',
#   'Okay flashlight',
#   'Amazingly bright flashlight',
#   'works great. Warning - keep away from kids',
#   'Five Stars',
#   'Awesome little flashlights!!!',
#   'Rockbirds LED Flashlight',
#   'like they like to do',
#   'Small and bright,  good handy personal light.',
#   'Good could be better'],
#  ["I picked these up for a song during one of the Amazon deals.  They are outstanding little flashlights, plenty bright.  I'd recommend the 14500 Li rechargeable batteries at 3.7V if you want the intensity to go up about 3x.",
#   "I was hoping the flashlight would be brighter based on the description, but it's not as bright as advertised.",
#   "These little flashlights outshine some of the bigger flashlights I've taken with me on camping trips.  I also really like the strobe feature, if I ever became lost in the woods, this would come in handy for flagging down assistance.  The flashlight also has a clip on it, which makes it very convenient for attaching to my waist or my backpack.",
#   'Bright, works great.  Warning - keep away from kids.  Disconcertingly way too bright for the little ones.',
#   'Great flashlight, use it all the time. Also a great deal!',
#   'Awesome little flashlights!!!  Very bright. Would recommend getting. I am buying a second set.',
#   "Bought these little Led flashlights for my grandsons. I don't know why but all my grandkids love flashlights I can't ever have too many.This is the type of flashlight that they can just slip into their pocket without feeling bulky and heavy.Great product for the price. Only downside is that I didn't think they were very bright, but the boys love them.",
#   "I needed two mini flashlights to keeps by my kids' bedside ... these work perfectly.  They are the right brightness for using when you need to get up out of bed in a dark room -- not blinding, but fully illuminates what you shine it on.  Actually brightened the whole room.  Not blinding when kids shine it at each other, like they like to do!  Great product for the price.",
#   'These are great little lights, small, cheap, and bright.  What more can I ask for... ?  Well, I could ask for a switch that always comes on in bright mode instead of the next mode from when you used it last, very annoying,  But overall, a handy little light to drop in your pocket.',
#   'So far these seem like good solid lights I would compare them to the "csi" nebo lights the only thing I would like better is if you could make then only bright mode and not have to cycle the switch 3 times through dim and strobe to get to bright again'],
#  ['5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 23, 2017',
#   'on May 22, 2017',
#   'on May 22, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_81 = url+str(81)
soup_81 = bs4.BeautifulSoup(requests.get(url_81).text, 'html5lib')
review_general_81 = soup_81.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_81 = review_general_81.find_all('div', attrs={'class': 'a-section review'})
review_title_81 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_81]
review_body_81 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_81]
review_stars_81 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_81]
review_date_81 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_81]
review_title_81, review_body_81, review_stars_81, review_date_81
# Out:
# (['Amazing!!!!',
#   'Five Stars',
#   'Love it!',
#   'Five Stars',
#   'Meh...',
#   'Five Stars',
#   'Cheap but bright',
#   "only marginally average, at best. and that's if all of the flashlights work.",
#   'Disappointed',
#   'Good to have as backups around the house or for'],
#  ["I received this light couple days ago. I was actually amazed how bright it is. Blindingly so. Focuses from beam to spot. I'm using it with a 2000 mAh NiMH AA battery. It seems to be made of pretty resilient materials. The strobe mode was an added plus not mentioned in the specs. I plan to use the light as a backup signal device for night walk. I was so impressed, I just ordered 2 more for my family. Highly recommends!!!!",
#   'Awesome shine low price about 12 hours on a battery',
#   'I like it and my daughter too. We will use them for camping next week!! ⛺️',
#   'Great pair of flashlights that works great and actually have switches that works, unlike many of the cheap flashlights.',
#   "Not impressed. These aren't much better than the dollar store flashlights, not very bright, as the high dollar flashlights are.",
#   'Great flashlight. Small but powerful.',
#   "really cheaply made and flimsy.  The light is bright and there's a flimsy lense you can move to adjust the beam... not bad all in all but not great... you get what you pay for.",
#   "short and sweet -- one worked, one didn't.they're pretty dim, granting powered off a single, AAA battery. That's only 1.5v. their rather small size is appealing for storage in an automobile or a purse, i suppose. those were the purchase designs here, anyway or it's highly unlikely would have gone this route.contacted the company twice, indicating one worked/one didn't. IDK yet if they've responded; I don't manage this account. my wife's account and I'm the occasional buyer. that said, looking at the order history, there's no clear Amazon indication that any adjustments have been made.lastly, seems one can reasonably expect a hit & miss scenario with these -- notice the irregular pricing, strongly nudging a buyer toward a larger collection. to whit -- we bought a 2-pack for $9.99; now i see both that same 2-pack but also a 4-pack for $12.99.caveat emptor",
#   'Delivery and packaging was great but the item is poor quality, cheap feeling although it has a metal body.  When screwing on the cap to battery compartment the metal sheered on the threads.  I do not imagine it will be very long lasting.  The light is good, though the pinpoint beam, I expected, would be more spot focused, it is still a fairly wide beam',
#   'Very inexpensive and bright. Good to have as backups around the house or for camping'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 22, 2017',
#   'on May 21, 2017',
#   'on May 21, 2017',
#   'on May 21, 2017',
#   'on May 21, 2017',
#   'on May 20, 2017',
#   'on May 20, 2017',
#   'on May 20, 2017',
#   'on May 20, 2017',
#   'on May 19, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_82 = url+str(82)
soup_82 = bs4.BeautifulSoup(requests.get(url_82).text, 'html5lib')
review_general_82 = soup_82.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_82 = review_general_82.find_all('div', attrs={'class': 'a-section review'})
review_title_82 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_82]
review_body_82 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_82]
review_stars_82 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_82]
review_date_82 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_82]
review_title_82, review_body_82, review_stars_82, review_date_82
# Out:
# (['Five Stars',
#   'only 1 AA battery needed',
#   'Great Value Flashlights',
#   'Five Stars',
#   'Five Stars',
#   'Great little light for the money.',
#   'Three Stars',
#   'This is the best little flashlight',
#   'great value',
#   'Fits in my purse'],
#  ['I like',
#   'best single AA battery flashlight',
#   'These are Great, Small, and Bright flashlights. We use them often and are excellent replacements for the large bulky flashlights we carry in our cars.',
#   'Very bright and compact',
#   'great for the money',
#   "I got this 2-pack for $8 shipped, so I guess there's little to complain about. I bought them for the cars since the small size doesn't require a space premium. Surprisingly bright for a single AA battery. I'm curious to try them with 14500 batteries to see how they perform. For the price, it can't be beat. They are solid and perform well. Definitely recommendable if on sale.",
#   'nice for a small every day use',
#   'This is the best little flashlight.  It is so bight and such a good size for my purse.  I gave the other one to a friend, who was delighted to receive it.I love it.',
#   'Very nice-was a gift. Fast shipping',
#   'Perfect size flashlight for my purse and one for my car.  It provides a bright light for such a small flashlight and the price was excellent.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 19, 2017',
#   'on May 19, 2017',
#   'on May 18, 2017',
#   'on May 18, 2017',
#   'on May 18, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_83 = url+str(83)
soup_83 = bs4.BeautifulSoup(requests.get(url_83).text, 'html5lib')
review_general_83 = soup_83.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_83 = review_general_83.find_all('div', attrs={'class': 'a-section review'})
review_title_83 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_83]
review_body_83 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_83]
review_stars_83 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_83]
review_date_83 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_83]
review_title_83, review_body_83, review_stars_83, review_date_83
# Out:
# (['Five Stars',
#   'Amazing & compact ! Perfect',
#   'Five Stars',
#   'Five Stars',
#   'These are great little flashlights',
#   'Five Stars',
#   'Perfect for camping',
#   'Bright idea!',
#   'They do the job, but be realiztic',
#   'Not happy'],
#  ['prompt shipping and great item',
#   'Amazing & compact ! Perfect',
#   'Great little flashlight for nightstand, car or travel.',
#   'Powerful enough and handy tools to run quick inspections of my car.',
#   'These are great little flashlights! I bought more of them because I loved them so much! They are extremely bright and easy to carry in your pocket.',
#   'Great item thanks',
#   'Small but solid and bright. Three click light modes. High, low and strobe. Perfect for camping.',
#   "Tiny cheap flashlights that are very bright. I haven't tried freezing them in a block of ice or running over them with a Humvee but there's still time.",
#   "Yes, just ok.  Runs on a single AA battery.  Ok light in a pinch.  We're not talking about a zillion lumens, by any stretch.  But, click the button, the light goes on.  Simple three mode mechanism.  Adjustable bezel, push/pull, to adjust beam size.  Flood setting looks best, but not the brighest.  Worth the buy, in case of an emergency. Besides, AA batteries are cheaper than dirt, and so easy to find.",
#   'The batteries in BOTH flashlights were no good.  It took 6 AAA batteries.  Not happy.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 15, 2017',
#   'on May 14, 2017',
#   'on May 14, 2017',
#   'on May 14, 2017',
#   'on May 14, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_84 = url+str(84)
soup_84 = bs4.BeautifulSoup(requests.get(url_84).text, 'html5lib')
review_general_84 = soup_84.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_84 = review_general_84.find_all('div', attrs={'class': 'a-section review'})
review_title_84 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_84]
review_body_84 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_84]
review_stars_84 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_84]
review_date_84 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_84]
review_title_84, review_body_84, review_stars_84, review_date_84
# Out:
# (['Good for walking the dog at night.',
#   'low price and perfect around the house',
#   'Small but powerful flashlight.',
#   "Piece of Crap - Don't Buy",
#   'Very poor light for a flash light',
#   'lightweight,good for group camping',
#   'Perfect',
#   'great price and works like a charm',
#   'poor buy',
#   'These work wonderfully well!'],
#  ['Awesome for taking the dog for a walk at night.',
#   'low price and perfect around the house. I slip one on my belt and take to job sites . Good light and easy to use',
#   'I bought these for my son and his friend to take camping on a school trip. They came in really handy because they got caught in the rain while hiking at night and these worked the entire time (almost one hour) until they got back to their campsite. They are small enough to fit in his jacket pocket so he was the only one to have one with him beside the counselor. We have them in a drawer in our kitchen in case the building loses power and it does all summer so they will come in handy. They are very bright and I would not expect that from such a small flashlight.',
#   "I wasn't able to open one of them to insert a battery.  Very poor design with the battery portal being combined with a light adjustment feature at the top.  It just turns and turns as though the battery portal is stripped. What a piece a crap!! It was a waste of time trying to open it and an even bigger waste of money!! In addition, the strobe function should work off an exterior switch that can be activated when the light is on. Not when you turn it off and then turn it back on only to have a useless strobe function activated.  That requires you to turn off the light again and turn it back on just to activate its normal function.  One agitated customer!",
#   "Don't let the edgy design fool you. Very poor light for a flash light.  Gives off as much as much light as a 3 dollar harbor freight 2 pack.",
#   'I got the 4 pack camping lights the other day.I love them much as they are lightweight and practical.The lights are strong and have zoom in and out.3 light modes: strong,SOS,weak.and it has a clip that is sweet.and the price is so reasonable.We need more than 1 flashlight and buying 4 pack is saving some dollars.thanks!',
#   'We needed small strong flashlights so we could see our new very dark puppy in the yard in the dark.  These are heavy, solid, bright and work perfectly.  I would recommend for purse, car, or very dark puppies at night....',
#   "This is a great price and works like a charm. The loading of the battery is not really complicated, once I read the questions section above the reviews section. Does not come with any description but once you've figured how to load the battery and clicked on the switch you should be good to go.",
#   'One worked. The second one I could not get it open to put the battery in so do not know if it works or not. one good one bad',
#   "We often need to head outdoors with no prior warning to deal with issues with the farm animals.  A bright, reliable flashlight that can slip into a pocket is a must for us.Shipping was fast with Amazon Prime and the packaging was excellent.  These flashlights did not come with batteries, but I had some on hand for the flashlights we already own.These flashlights are lightweight and very, very bright.  The adjustable beam allows us to search the woods quickly and then to pinpoint what we're searching for.  Most recently that was a wild raccoon who was tipping our waste cans and stealing food from the barn cats.The clips are strong, enabling us to ensure that the flashlights won't fall out of our pockets while we're working.I have absolutely no complaints and intend to buy these again!"],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 14, 2017',
#   'on May 13, 2017',
#   'on May 12, 2017',
#   'on May 12, 2017',
#   'on May 10, 2017',
#   'on May 10, 2017',
#   'on May 9, 2017',
#   'on May 9, 2017',
#   'on May 7, 2017',
#   'on May 7, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_85 = url+str(85)
soup_85 = bs4.BeautifulSoup(requests.get(url_85).text, 'html5lib')
review_general_85 = soup_85.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_85 = review_general_85.find_all('div', attrs={'class': 'a-section review'})
review_title_85 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_85]
review_body_85 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_85]
review_stars_85 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_85]
review_date_85 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_85]
review_title_85, review_body_85, review_stars_85, review_date_85
# Out:
# (['Small but very handy ;)',
#   'Small and bright',
#   'Four Stars',
#   'For the price, a good buy.',
#   'they dont cost much but now i know why',
#   'Solid',
#   'lights up my life',
#   'Bright',
#   'One out of the two works. It did not ...',
#   'Five Stars'],
#  ["Great light use it for work. Super bright and you can adjust if you want the beam to be narrow and bright or have it cover more ground but not as bright. I've used one for a couple hours and still have not needed to replace the battery so that's super nice.",
#   'These lights are handheld lights and pretty bright. Easy to grip and can conveniently be stored just about anywhere. Good buy!',
#   'A great light for little bucks.',
#   "Pretty darn good for the price. Clip is stout. No batteries included, but it's a single AAA, and puts out enough light to see well. Had to figure out which end to unscrew as the machining was in good tolerances. That was fun. Glad there were two. For the price, can't beat it.",
#   "save your money if you drop them they don't shut off anymore both are broke in less then a week",
#   "These things are quality, didn't even know they had three light settings with purchase, pleasant surprise. Gonna buy my brother a couple",
#   "I'm amazed that something so cool can be so inexpensive.",
#   'Really bright,  especially for the size.  Took them camping for the weekend,  they worked great!',
#   'One out of the two works. It did not light up when the battery was a applied.  It just over heated.',
#   'Nice lights at a good price.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on May 7, 2017',
#   'on May 6, 2017',
#   'on May 5, 2017',
#   'on May 5, 2017',
#   'on May 4, 2017',
#   'on May 4, 2017',
#   'on May 3, 2017',
#   'on May 2, 2017',
#   'on May 1, 2017',
#   'on May 1, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_86 = url+str(86)
soup_86 = bs4.BeautifulSoup(requests.get(url_86).text, 'html5lib')
review_general_86 = soup_86.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_86 = review_general_86.find_all('div', attrs={'class': 'a-section review'})
review_title_86 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_86]
review_body_86 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_86]
review_stars_86 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_86]
review_date_86 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_86]
review_title_86, review_body_86, review_stars_86, review_date_86
# Out:
# (['Super bright and light weight',
#   'Fantastic Little Flashlight, Except...',
#   'Five Stars',
#   'Nice Small Flashlights',
#   'Not for use with Vampires.',
#   'Five Stars',
#   'Bright little lights. Good buy.',
#   'I love having these around the house',
#   'love these mini flashlights',
#   'Only One Flashlight Worked.'],
#  ['These flashlights are the most recent addition to my emergency/camping equipment. They are super bright and only require one battery. You can use them as a spotlight or wide light which is convenient. I love how light weight they are and they have a clip that allows you to keep them on your belt, hat, or backpack and in easy reach. I will be purchasing more!',
#   "Really love these little flashlights, they're the best I've found on market. Small, VERY powerful for their size, focusable and only require one AA battery.Why not 5 stars? Because of the three modes that you must cycle through every time. I have a couple of flashlights that stay in the same mode unless you repeatedly press the button, and then stay in that mode until changed again. That's the way all of these should work. It's a real pain to have to click so many times, just to get back to the only setting I'll use: high. Make that change and I'll buy a dozen for everyone in the family.",
#   'great!',
#   'My fiancé really likes the how small these flashlights are.  He likes that he can carry these around in his pocket and it is not uncomfortable.  He is very pleased with the durability and brightness of these flashlights.',
#   'I use this to fend off the demons that haunt me. Works good.  So far, I am demon-less.',
#   'Perfect size and got flashlight!',
#   "Great little lights. The only two downsides are that the clip is tempered and will break if you try to bend it a little more so it's easier to clip on your pocket. The other is that when you turn it off, and then back on it goes to the next mode. So if you turn it off on the bright setting and turn it turn it back on, it'll be on the low setting. The modes are bright, low, & strobe. So I just switch it to strobe before I turn it off, that way it comes on bright. Not a deal breaker for me. But for some it might be.",
#   'Quick shipping!I love having these around the house, compact and very bright.',
#   "Great deal for a pair of mini flashlights.  Very small and lightweight so very easy to throw in your purse to have just in case or around the house if the power goes out.  Fits in the palm of my hand.  Takes just one double AA battery.  Very bright and you can adjust to turn it even brighter.  Pictures I've taken below are in pitch black so you see how bright they are.",
#   'Only one of my flashlights worked. The other is broken and cannot even be opened for me to insert the battery because it is broken. They come in a set of 2. I needed both flashlights.'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '2.0 out of 5 stars'],
#  ['on May 1, 2017',
#   'on April 30, 2017',
#   'on April 30, 2017',
#   'on April 28, 2017',
#   'on April 28, 2017',
#   'on April 27, 2017',
#   'on April 27, 2017',
#   'on April 27, 2017',
#   'on April 27, 2017',
#   'on April 27, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_87 = url+str(87)
soup_87 = bs4.BeautifulSoup(requests.get(url_87).text, 'html5lib')
review_general_87 = soup_87.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_87 = review_general_87.find_all('div', attrs={'class': 'a-section review'})
review_title_87 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_87]
review_body_87 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_87]
review_stars_87 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_87]
review_date_87 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_87]
review_title_87, review_body_87, review_stars_87, review_date_87
# Out:
# (['Great Value',
#   'Well worth the price, quality product!',
#   'Great little flashlight.',
#   'Absolutely wonderful for that price',
#   'PRICE RAISED!',
#   'Worth every penny',
#   'Go for it. For the price you pay it ...',
#   'Bright, well made. But wait for a sale to buy them.',
#   'surprised',
#   'Decent flashlights'],
#  ['Great Value',
#   'Well built , compact, nice light!',
#   'Awesome little flashlights!  One AA battery and your set. Very bright for the size.',
#   "Got the 2-pack for 8$. Absolutely wonderful for that price. Reasonably bright and the focus adjusts really well too.For this price, I wouldn't think it twice.",
#   'Great Flashlight and packs a lot of power for something so small. Purchased a pair for $8. Went back to get more and price went up to $29!',
#   'These things are awesome. Perfect size and use a simple AA battery. If u need a flashlight for ur junk droor or for your tool bag this is the one to get. Its fully metal and shines bright. Not the best for mounting to guns. But perfect for everything else',
#   'Go for it . For the price you pay it serves the purpose. Very small and portable',
#   'Very well made aluminium tube and very bright. What more could you want? Well, maybe a bigger flashlight. These things are tiny but crank an amazing amount of light given their size. Good for car, purse or pocket. Or to clip on your belt. The ability to focus the beam from narrow to wide is a plus. Be sure to wait for the sales. Prices are all over the map on these things, from as little as $8 (for 2) to almost $30. A good deal at the lower price point.',
#   'very bright and portable.  will use in the car as a light for maps, task lighting, or, emergencies.  great for entering a dark movie theater.  would love to try out other products from this supplier.',
#   'Decent set of heavy flashlights. I like that they use standard batteries as opposed to rechargeable ones. These lights are bright and get the job done. Good set for the price'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on April 26, 2017',
#   'on April 26, 2017',
#   'on April 26, 2017',
#   'on April 26, 2017',
#   'on April 26, 2017',
#   'on April 25, 2017',
#   'on April 25, 2017',
#   'on April 25, 2017',
#   'on April 24, 2017',
#   'on April 24, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_88 = url+str(88)
soup_88 = bs4.BeautifulSoup(requests.get(url_88).text, 'html5lib')
review_general_88 = soup_88.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_88 = review_general_88.find_all('div', attrs={'class': 'a-section review'})
review_title_88 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_88]
review_body_88 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_88]
review_stars_88 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_88]
review_date_88 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_88]
review_title_88, review_body_88, review_stars_88, review_date_88
# Out:
# (['Five Stars',
#   "Toggle switch doesn't work",
#   'These flashlights are OK. Nothing special. For as ...',
#   'Disappointing with one light',
#   'Great price for pair',
#   'Perfect',
#   'Little blowtorches.',
#   'Very Good Quality',
#   "Buy It. You'll love it.",
#   'Awesome! Really brute for its size'],
#  ['Very good flashlights.',
#   "Ordered 2 packages - 4 flashlights total.  One of the push button toggle switches works only when it feels like it - and it's not often it feels like it.  The other 3 flashlights work okay, but I wonder how long before their push button toggle switch craps out.This is the first time in 14 years of shopping with Amazon that a product we purchased doesn't work.  I guess it was bound to happen sooner or later.It's not worth the hassle to send a $4 flashlight back. It should be thrown away, but then I'm throwing away $4 of my money.  It's not the money, it's the principle.  Come on Amazon, just suck it up and mail me a working replacement.",
#   "These flashlights are OK. Nothing special.For as cheap as they are, I don't suppose you can set your sights too high!",
#   "Very disappointing one of the lights doesn't open, but the one that works is very bright.",
#   'it is REALLY bright for 1 AA battary',
#   'Best flashlight ever',
#   'These units are very bright and powerful. Small but mighty. Fits in a glove box very well.',
#   'Nice and bright and well made.  I recommend.',
#   "It just arrived this morning.  After first glance and touch, I think it's well worth the cost... .  Small, but rugged and with a great design.",
#   "Awesome! Really brute for its size. 1 AA battery is all it needs.  Kids love playing with the 'blinking feature."],
#  ['5.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 23, 2017',
#   'on April 23, 2017',
#   'on April 23, 2017',
#   'on April 23, 2017',
#   'on April 23, 2017',
#   'on April 23, 2017',
#   'on April 23, 2017',
#   'on April 22, 2017',
#   'on April 22, 2017',
#   'on April 21, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_89 = url+str(89)
soup_89 = bs4.BeautifulSoup(requests.get(url_89).text, 'html5lib')
review_general_89 = soup_89.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_89 = review_general_89.find_all('div', attrs={'class': 'a-section review'})
review_title_89 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_89]
review_body_89 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_89]
review_stars_89 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_89]
review_date_89 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_89]
review_title_89, review_body_89, review_stars_89, review_date_89
# Out:
# (['These are better quality than the ones you would buy on eBay ...',
#   'I am really pleased with this product',
#   'Bright and well made',
#   'Great quality',
#   'I love these flashlights',
#   'Nice',
#   'Nice and Compact',
#   'Bright little flashlights!!',
#   'A cimplete waste of money.',
#   'These are super handy and bright'],
#  ['These are well made being machined aluminum and the paint is done very well as well. These are better quality than the ones you would buy on eBay for around $2 or so even though they look exactly like them.',
#   "I am really pleased with this product. They are lightweight and compact. They'll easily fit in my purse or even a pocket. The quality is great too,  they're really bright and easy to operate. All in all, I'm very happy with them. They also arrived quickly and were packaged securely. I'd absolutely order again.",
#   'These little flash lights are so useful! I love the fact they are small enough to fit in my handbag, glove box or clip on my pocket. I was not expecting the light to be so bright, they are actually brighter than a bigger much more expensive flashlight my husband keeps in the garage. I will be purchasing a second set to keep in our camper!',
#   'With a house full of boys my flash light are always turning up missing. So I find myself looking for smaller but strong and bright flashlights. These led flashlights from rockbirds are the perfect choice for my family. They are small and very sturdy. Strong and very bright. There are what I would call 3 different modes of light. The first is a regular flashlight beam. This light is very bright and shows a long distance from the user. Next is a more.focused beam just pull on the flashlight and you get a smaller more focused beam of light in a square. Next is a flashing mode. I like this one best because I will take the dogs for a walk in the morning before it is light out and I can use this in flashing mode attach it to my jacket so that drivers can see me.Overall I have been very impressed with the quality of this flashlight. It is small and light weight. Perfect to keep in your purse, car glove box or anywhere else you might need to.',
#   "I love these flashlights. I bought for my son who's going on a camping trip. Very compact. Has three different settings.",
#   'Nice little flashlights... they have a distress flash as well as a dim and bright light!',
#   "I ordered these because of their size. They fit nicely and discreetly into my purse and I can take it to go in case I need it.These flashlights are nice and bright, perfect for emergency situations or power outages. I don't like having huge bulky flashlights in my tiny apartment. They really take up way too much space. These are well built, strong and will last a long time. Really happy to have found these.",
#   'Great little flashlights! When we got them, we put the AA batteries in ( 1 per light) and they worked perfectly! When you click the button the light come on bright, click it again, and it\'s a different brightness, click it a 3rd time, and it strobes! They even have a little clip on it for a belt or a backpack! When you turn the front edge if it, the "circle" of light gets larger and smaller... this will be perfect for camping!!',
#   'Absolute junk..Received the 2 lights today : 1 light does not telescope at all..The other turns to strobe whenever you put it downon a hard surface.',
#   'These are super handy and bright!  They fit in my pocket but can spot a coyote from a far  these are going to be my lifeline out here in the country this year!  So glad I purchased these and intend to order another set for my daughter.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 21, 2017',
#   'on April 21, 2017',
#   'on April 19, 2017',
#   'on April 19, 2017',
#   'on April 18, 2017',
#   'on April 18, 2017',
#   'on April 15, 2017',
#   'on April 15, 2017',
#   'on April 13, 2017',
#   'on April 13, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_90 = url+str(90)
soup_90 = bs4.BeautifulSoup(requests.get(url_90).text, 'html5lib')
review_general_90 = soup_90.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_90 = review_general_90.find_all('div', attrs={'class': 'a-section review'})
review_title_90 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_90]
review_body_90 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_90]
review_stars_90 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_90]
review_date_90 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_90]
review_title_90, review_body_90, review_stars_90, review_date_90
# Out:
# (["It's little but mighty",
#   'Four Stars',
#   'Pretty Good, Not as expected for any pinpoint viewing',
#   'great brightness. WIll get lots of use',
#   'Just like other reviews say',
#   'Great little flashlight!',
#   'Very powerful lights',
#   "I liked these. I didn't realize two came in the ...",
#   'Super bright, compact and a great value',
#   'Good buy.'],
#  ['Great little flashlight. At first glancethey look so little you wonder how much light they give. These little things give you just as much light as a full size flashlight but with the clip they fit anywhere!',
#   'good for the price.',
#   'Pretty Good, Not as expected for any pinpoint viewing, also the AA battery depletes very fast. However, When you get 4 of them with the Flash Mode, you got yourself an Instant Seizure!',
#   'Rugged, great brightness. WIll get lots of use.',
#   "Just like other reviews say, there is 3 settings.  High, Low, and Strobe.  You can't just use one, so you will have to push the button to go through the three settings.  I have one set on high so when I go outside, and I have one set on the strobe that is locked up in the lockbox next to the pistol.",
#   'These are so much brighter than I expected! First of all, love that there are two. But the fact that there are different settings makes it a hit with the kids too! Personal flashlight for kid = win. It means that she can handle things on her own despite it being darker in the house than she prefers. On a less personal note, though - Small/portable, easy to use, super bright. Love it!',
#   'These are great handy little flashlights. I put one in my car and after using it my husband said he is taking my other one for his truck. I really love that you can adjust the light to sort of "zoom in" on something specific with the light.',
#   "I liked these. I didn't realize two came in the package so I was pleasantly surprised. They are extremely bright (which my toddler loves, she uses them to shine on the ceiling during the day). And they only require one AA battery, which is better than some since I don't always have larger batteries on hand.",
#   'I didn\'t expect that the mini flashlights would be as powerful as they are. They\'re great to keep in your toolbox, glovebox or purse. Also great to keep in a kitchen drawer for power outages, just in case.At just over 3.5" long they emit a super strong beam of LED light. They are really solid and have a nice weight to them. Two AA batteries (not included) is all it takes to operate them both. I\'m going to keep one in the car and use one for camping.Since they\'re water-resistant I can bring it out on the kayak for those evening paddles and I won\'t have to worry about the flashlight getting splashed.',
#   'I got these for my older sons. They are very durable and compact. The light is bright enough. Good buy.'],
#  ['5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 12, 2017',
#   'on April 12, 2017',
#   'on April 12, 2017',
#   'on April 12, 2017',
#   'on April 12, 2017',
#   'on April 11, 2017',
#   'on April 11, 2017',
#   'on April 10, 2017',
#   'on April 10, 2017',
#   'on April 10, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_91 = url+str(91)
soup_91 = bs4.BeautifulSoup(requests.get(url_91).text, 'html5lib')
review_general_91 = soup_91.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_91 = review_general_91.find_all('div', attrs={'class': 'a-section review'})
review_title_91 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_91]
review_body_91 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_91]
review_stars_91 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_91]
review_date_91 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_91]
review_title_91, review_body_91, review_stars_91, review_date_91
# Out:
# (['Great item to have',
#   'Super Bright and very high quality tactical flashlight!',
#   'I really like that you can pin point the light as well',
#   'Five Stars',
#   'Great Flashlights in a small package',
#   'Five Stars',
#   'steady dim (which produces a softer light but still illuminates pretty well), and rapid flash bright',
#   'Five Stars',
#   'compact and practical',
#   'Very durable flashlights'],
#  ['Great item to have. They are so compact that you can carry one in your purse, bag, or car, and not worry about it taking up much room at all. Easy on/off button for someone with arthritis, or a young child.',
#   'Rockbirds LED Flashlight is a very high quality, heavy duty, and super bright tactical flashlight.  Extremely satisfied with this product!',
#   'These are much brighter than I thought they would be. Its a must if you live in back in the woods. They will be used for alot more than taking the pups out at night. I really like that you can pin point the light as well. Makes for trying to seeing certain things much better. What is great about this is I get one and my husband gets one. Great purchase.',
#   'I really like this product. They are the perfect soze.',
#   "Don't be fooled by their small appearance they pack a punch! Liked the fact that two came in a package. They are small enough that I kept one in my glove box in my car and one in the bathroom vanity in our upstairs bathroom.  When the electricity goes out it always seems like I can never find the flashlights now I have them on every level of my home. With one simple Double A battery they are ready to go.  They really give off a lot of light for a small flashlight.  I also like the fact that they have a setting that is like a strobe light.  That is why I decided to keep one in the car if we ever get stuck in the dark it can be used to flag someone down. I will be purchasing more of these!",
#   'I really like this item..Very light,and strong..Built well,and very handy around the house...I wish i could have 2 more...Thanks..Mr.Keiper!',
#   "Incredibly brights,compact light. Exactly what I was looking for. It has 3 modes, steady bright, steady dim (which produces a softer light but still illuminates pretty well), and rapid flash bright. It's small enough to fit into a pocket, the clip is strong enough to keep it secured on a bet. And you get 2. I'm probably ordering 2 more to keep in vehicles. Thanks for a great product at a great price.",
#   'Works really good',
#   "I always like to keep a small flashlight in my handbag in case of emergencies- you never know when an elevator will have a power outage or when you'll get stuck outside after dark. These are perfect for that purpose- they're lightweight enough yet comfortable to hold. I like that it comes in a pack of two, so I have a backup. The clip allows me to attach it to the pocket in my handbag for easy retrieval. And for a small flashlight, the LED light is strong, so I can see myself holding this for a long time in case of a power outage, unlike other powerful flashlights that are large, bulky and heavy.",
#   'These flashlights work really well. The are heavy duty metal so they feel like they will take some abuse and not break. They get very bright which is obviously what you want from a flashlight. You get 2 so its a good value for your money. I keep one in the car for emergencies and my husband has the other one. I think these will last a very long time.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 10, 2017',
#   'on April 9, 2017',
#   'on April 8, 2017',
#   'on April 7, 2017',
#   'on April 7, 2017',
#   'on April 7, 2017',
#   'on April 7, 2017',
#   'on April 7, 2017',
#   'on April 6, 2017',
#   'on April 6, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_92 = url+str(92)
soup_92 = bs4.BeautifulSoup(requests.get(url_92).text, 'html5lib')
review_general_92 = soup_92.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_92 = review_general_92.find_all('div', attrs={'class': 'a-section review'})
review_title_92 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_92]
review_body_92 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_92]
review_stars_92 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_92]
review_date_92 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_92]
review_title_92, review_body_92, review_stars_92, review_date_92
# Out:
# (['Five Stars',
#   'Good light - Good size',
#   'Five Stars',
#   'Four Stars',
#   'High Powered Mini Flashlight Set',
#   'Great and tough',
#   'Two nice sturdy LED flashlights',
#   "This flashlight has exceeded my expectations so far, I've ...",
#   'Will definitely come in handy',
#   'Perfect size Flashlight for small spaces'],
#  ['Awesome Light I love it Thank you Thank you',
#   'Have only used a few times but are so far they are good, especially for the price paid.',
#   'Great product',
#   'pretty bright for a little flashlight.',
#   "This is a great pair of mini flashlights. The beams are on both of these flashlights are bright and very focused. Each flashlight has side clips that make it easy to attach to a pocket so they can be carried and not lost. The push button design is comfortable and works well. Each flashlight requires 1 AA battery to operate, which is quite impressive based on the actual light output from such a compact design. There are three different light settings and an easy to grip housing design. I've found these to be great little lights for around the house and in the vehicle.",
#   'ran over it with a forklift still works fine nothing broke off of it',
#   'I ordered my Rockbird led Flashlight thinking i was getting one. I am so surprised at the fact I recieved two. These by the way came so fast by prime. They didnt come with batteries so i loaded them today. Woot hoo. they are bright exactly what I aspected with LED. Nice and small fit so comfortly in my hand as a women the are about the size of my palm. I am totally keeping one of these in my kitchen and one in my SUV. Totally never know when its needed. Has a screw off top to change batteries as well as a nice sturdy clip to hold onto stuff. These Rock! Thank you again for the great Deal.',
#   "This flashlight has exceeded my expectations so far, I've had it about a month I bought them because I have a lot of AA batteries and they were cheap. I had a similar Cree with rechargeable batteries it lasted three months barely on my last deployment, this one is a month in and going strong,it's been doused in jet fuel and dropped more times then I know but still shines bright for 10 bucks and you get two can't beat it.",
#   "Don't be fooled by the size of these flashlights. They might be mini, but they give off so much light. These two flashlights are so convenient and handy. The fact that they are small, they can fit anywhere (glove department, purse, pocket- there's even a clip that you can attach to your pocket). Will be a great addition to a survival kit.",
#   'Definitely a fan of these flashlights, they are small but very bright. Really good quality and the clip on them is perfect for outdoor activities when not in use. The perfect size to keep in a convenient place, I put one in my glove compartment and another in my first aid kit. Definitely recommend these as you get an excellent product for the price.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on April 5, 2017',
#   'on April 5, 2017',
#   'on April 5, 2017',
#   'on April 5, 2017',
#   'on April 5, 2017',
#   'on April 5, 2017',
#   'on April 4, 2017',
#   'on April 3, 2017',
#   'on April 3, 2017',
#   'on April 3, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_93 = url+str(93)
soup_93 = bs4.BeautifulSoup(requests.get(url_93).text, 'html5lib')
review_general_93 = soup_93.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_93 = review_general_93.find_all('div', attrs={'class': 'a-section review'})
review_title_93 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_93]
review_body_93 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_93]
review_stars_93 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_93]
review_date_93 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_93]
review_title_93, review_body_93, review_stars_93, review_date_93
# Out:
# (['Amazing Light Output!',
#   'Great small flashlight',
#   'Five Stars',
#   'Rockbirds LED flashlight.',
#   'Awesome flashlights, small and portable.',
#   "They work as advertised. It's a handy little light ...",
#   'Four Stars',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars'],
#  ["These are a new fad right now and it seems that the single battery LED Flashlight are working tons better than the multi-battery ones.  Seems like that shouldn't be the case but it is my experience with these so far!  I bought this particular one because of the saving I got from it being a 2 pack.  I used the extra to give to my parents.  Make a great gift, especially when you can show how great and bright the light is for such a small unit.",
#   'My husband works in the oilfield so I grabbed this two pack for him and his friend to use while at work. They are simple, only take 1 battery, and they really liked the brightness of the light and the fact that it has a tight clip on it so it stays in their pocket well.',
#   'One double A battery and you have a Super bright flashlight!',
#   'Always, always need flashlights in our house and only LED ones.  The flashlight is bright, has a belt clip, fits perfectly in your hand and compact.  It has a caution mode, where the light blinks to let others know something is wrong. HOpefully no one will ever have to use that setting.  This flashlight being so compact is great for you need to look under cabinets and small spaces.  My husband used it for the lower compartment on his boat.',
#   'Really cool little flashlights. These are fairly small and light but they are also very sturdy. They do not feel cheap or weak in any way. Really nice quality, well made. I like that they are small, makes them super portable. I also like the adjustable focus feature, could come in handy. I definitely like these and can surely recommend this product.',
#   "They work as advertised.  It's a handy little light.",
#   'They work good but are small. Only about 3 inches each but still strong light.',
#   'Powerful!',
#   'Great quality for the price!',
#   'Surprisingly bright for size.'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on March 31, 2017',
#   'on March 30, 2017',
#   'on March 30, 2017',
#   'on March 30, 2017',
#   'on March 26, 2017',
#   'on March 26, 2017',
#   'on March 24, 2017',
#   'on March 24, 2017',
#   'on March 23, 2017',
#   'on March 21, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_94 = url+str(94)
soup_94 = bs4.BeautifulSoup(requests.get(url_94).text, 'html5lib')
review_general_94 = soup_94.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_94 = review_general_94.find_all('div', attrs={'class': 'a-section review'})
review_title_94 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_94]
review_body_94 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_94]
review_stars_94 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_94]
review_date_94 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_94]
review_title_94, review_body_94, review_stars_94, review_date_94
# Out:
# (['I am very happy I purchased the Rockbirds LED Flashlights',
#   'Great little flashlights that put out Great light',
#   'small but powerful',
#   'Good Buy',
#   'i was looking for something to keep in my vehicle that wasnt big but was still bright wnought ro get the job down and this is th',
#   'very bright led flashlights',
#   "so they don't get held to super high standards",
#   'Super bright little lights that work well.',
#   'Great little flashlights',
#   'great, small and so bright'],
#  ['I am very happy I purchased the Rockbirds LED Flashlights.  They are the perfect size for your purse, pocket, fanny pack or to store in the door of your car.  They are easy to use and very bright. They come in a pack of two. I put one in my Jeep and the other in my husbands truck.  I have used mine every time I have come home at night and needed to light my way to the door.  I highly recommend these flashlights.',
#   'Great little flashlights that put out Great light. I recently started with a volunteer Fire Department and was looking for tools to fill my pockets with. Flashlights are one of those key tools. This little flashlight is simple to use and even with it being so small and with wearing gloves, it is easy to turn on and off. Definitely worth the buy.',
#   'These are small enough to carry in a purse or backpack. I personally carry one in my purse for those times when I am going to my car late in the evening and need a light to see.  I take evening classes and sometimes going to my car is a little scary, so I really like having the flashlight readily available. It eases my stress and fears waking to my car being able to actually see.  We recently lost power and I used my rockbird flashlight most of the evening. I was amazed at how long and well it worked. I am very happy with these flashlights and look forward to using them for camping and hiking over the summer. I am impressed for as small as they are, they emit quite a bit of light.',
#   'Great little flashlight for the price, super bright and sturdy.',
#   'these are the bigest bang for youe buck. very very bright. i was looking for something to keep in my vehicle that wasnt big but was still bright  wnought ro get the job down and this is the PERFECT flash light for that!I have no relation to the seller, this is my honest opinion. :)',
#   'Very bright flashlight. I like the LED glow vs the regular lens. Item come packed well in a box. Very good quality. Metal casing that can stand up to wear and tear. I plan on using these lights for emergency and also when we go camping. It is nice that there is a place to put a clip or lanyard.',
#   "They cheap, so they don't get held to super high standards. The slide to amplify light is only useful when at max power. The light gets focused into some logo I can't make out. Not good or bad, just an observation.",
#   "Super bright little flashlights. The focus on them is fun, but usually not very necessary. They seem like they can handle a pretty good beating. I carry one on my belt at work as it is compact, lightweight, and it comes in really handy. The only complaint I have is I wish the belt clip was heavier; I snagged it on my bench the other day while I was working and bent it all up. I took off the clip (held on by two small allen screws) and applied some love with a pair of pliers and it works great again. I don't know if anyone else would have this problem and it's easy to fix, so it's not worth taking off a star. I may make a heavier clip for it myself though.Overall, they do what I expect them to do.",
#   "This set of two flashlights are a great deal in my opinion.  I gave my husband one to use in his tow truck and one stays in the house for me. These flashlights are very bright and you can adjust the scope of the light from a large area to a precise close area. I use my flashlight in the house to check on eggs in an incubator so I pull the top of the flashlight out to narrow the scope. It is plenty bright for me to see the babies in the eggs. My husband has used his for lots of things in the tow truck. It is great for lots of jobs since it has adjustable lighting. It's also easy for him to keep on himself with the metal clip and non-slip grip.  I like that they are made with aluminium so they are lightweight and durable. So far they show no wear and tear even though we are constantly using them.",
#   'Tell you the truth... i bought them for my mother in law who was always complaining about not having flashlight when ahe loses power in the house and ahe bothered me to borrow mine. Now since I got her these flashlights she doesnt even use them and keep bugging me for flashlights... guess what i took flashlights back for myself and borrow her the ones i bought her... great , small and so bright... ask my mother in law!!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on March 20, 2017',
#   'on March 17, 2017',
#   'on March 16, 2017',
#   'on March 15, 2017',
#   'on March 15, 2017',
#   'on March 14, 2017',
#   'on March 13, 2017',
#   'on March 11, 2017',
#   'on March 10, 2017',
#   'on March 9, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_95 = url+str(95)
soup_95 = bs4.BeautifulSoup(requests.get(url_95).text, 'html5lib')
review_general_95 = soup_95.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_95 = review_general_95.find_all('div', attrs={'class': 'a-section review'})
review_title_95 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_95]
review_body_95 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_95]
review_stars_95 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_95]
review_date_95 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_95]
review_title_95, review_body_95, review_stars_95, review_date_95
# Out:
# (['Five Stars',
#   'Great EDC light',
#   'Great Light',
#   'Five Stars',
#   'This flash light is very nice. It has an option of a dimmed light',
#   'Good deal!',
#   'Heavy Duty and Bright',
#   'Awesome',
#   'Great flashlight.',
#   'A nice LED (small) flashlight!'],
#  ['Very bright and no problems so far.',
#   "These were purchased as gifts.  Both recipients are very happy with the lights.  These are being used as Every Day Carry (EDC) tools.  These have been in daily carry/use for three months with no complaints.  Very bright, work great, good battery life and a variable beam at a great price....what is not to like?Remember...it is not a Streamlight, SureFire, Fenix, etc....but it works, and it's 5$.  Worth every penny!",
#   'These are great little flashlights. Very compact and very bright. Small enough to fit in my pocket; and they are very sturdily built. Recommended.',
#   'Great price, bright for a little flashlight.',
#   'This flash light is very nice. It has an option of a dimmed light, flashing light, and also a bright and long extended light. I like it a lot and have used it  lot.',
#   "The flashlights are light weight and very bright. Once you put the battery on it's a bit difficult to put the bottom back on. But it's a clear white light and not that yellow hue. So it's a great find especially since you get two! I use them when I'm walking around at night and it doesn't take up space at all.",
#   "These are good quality tactical flashlights. They have three modes and in the video I am posting along with this review you can see the difference in the 3 modes which are changeable with a click of the button at the end of the flashlight. There is a sturdy pocket clip mounted to the side of the flashlights with two small screws. So far I haven't had any problems with the flashlights which seem to be pretty durable and are just what I expected.",
#   'No problems at all ,strong lil lights',
#   'I use this flashlight for work. It has awesome brightness and uses one AA battery as opposed to the expensive special batteries the tactical flashlights usually take. Works great for up close or zoom it in for distance. Definitely a good buy, especially for the price.',
#   'I purchased the LED Flashlight by Rockbirds because I wanted a flashlight I could easily put into the center console of my Jeep. This flashlight is perfect because it is small enough to fit just about anywhere that you want to put a flashlight. You could carry this in your purse, your vehicle, it even has a clip for a belt. Just remember, batteries are not included. So you will need two AA batteries. I am pleased with this purchase. :-)'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on March 9, 2017',
#   'on March 9, 2017',
#   'on March 9, 2017',
#   'on March 8, 2017',
#   'on March 8, 2017',
#   'on March 7, 2017',
#   'on March 7, 2017',
#   'on March 6, 2017',
#   'on March 5, 2017',
#   'on March 5, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_96 = url+str(96)
soup_96 = bs4.BeautifulSoup(requests.get(url_96).text, 'html5lib')
review_general_96 = soup_96.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_96 = review_general_96.find_all('div', attrs={'class': 'a-section review'})
review_title_96 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_96]
review_body_96 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_96]
review_stars_96 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_96]
review_date_96 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_96]
review_title_96, review_body_96, review_stars_96, review_date_96
# Out:
# (['... bought a pair similar to these previously and really like the design',
#   'Very fast shipping!',
#   'Quality made and a fantastic deal!  Let me show you how they work.',
#   'great',
#   'Fantastic mini lights',
#   'Five Stars',
#   'Five Stars',
#   'Five Stars',
#   "It's rock solid!",
#   'Not for rugged use.'],
#  ['I had bought a pair similar to these previously and really like the design. This brand however was cheapened considerably. I was not impressed with the switch most of all. Being not as crisp as the other brand.',
#   "This is probably the best and most compact set of flashlights I've ever owned! I don't like candles so they are perfect for power outages and I'm always losing things so the ultra brightness is very effective for that too!",
#   'These Rockbirds LED Flashlights I bought came it a pack of 2 for only $9.99 which is a crazy good deal.  I collect LED flashlights and have about 30 right now but I really like these smaller ones because I can just keep them in my pocket.These are heavy duty and made with aluminum.  The battery compartment has an O ring to keep moisture out.  They are waterproof but not to be submerged in water but they will withstand rain.The beam is adjustable and you can see that in the video I provided to go with this review and I also show all 3 modes of lighting.  All you need to do is slightly tap the on and off switch and it will change modes.Please watch the video to get a better idea of what I am talking about.  Overall it is excellent for the price and you get 2!  I give this 5 stars easily.  I hoped this helped in some way.',
#   'great little lights',
#   'Fantastic mini lights. Very bright . They come in a convienet 2 pack.  Perfect for purse or bag , keep a spare in the car. Happy customer here.',
#   'love them',
#   'Excellent! These are great!',
#   'MUY BUEN PRODUCTO',
#   "Rock solid construction with great beams of light. Only use 1 AA size battery. It fits comfortably in my jeans pocket and compliments my EDC. Not to mention that the price is extremely reasonable.What's not to like? :))",
#   "Dropped the light one time. Now the slightest change in grip will turn it to strobe or off. But it's bright."],
#  ['2.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars'],
#  ['on March 5, 2017',
#   'on March 4, 2017',
#   'on March 4, 2017',
#   'on March 2, 2017',
#   'on March 2, 2017',
#   'on March 1, 2017',
#   'on March 1, 2017',
#   'on February 24, 2017',
#   'on February 23, 2017',
#   'on February 23, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_97 = url+str(97)
soup_97 = bs4.BeautifulSoup(requests.get(url_97).text, 'html5lib')
review_general_97 = soup_97.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_97 = review_general_97.find_all('div', attrs={'class': 'a-section review'})
review_title_97 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_97]
review_body_97 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_97]
review_stars_97 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_97]
review_date_97 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_97]
review_title_97, review_body_97, review_stars_97, review_date_97
# Out:
# (['Bright and Tough with only 1 AA Battery!',
#   'Five Stars',
#   'Great Pint Size Flashlight!!',
#   'Five Stars',
#   'Great sporting flashlights',
#   'Brighter Than Expected',
#   'Four Stars',
#   'When turning these on, you get a different mode ...',
#   'Best $4.00 dollar light we have had.',
#   'GREAT VALUE'],
#  ['Really like these flashlights! Work very well. Very useful.',
#   'Nice little lights. Got one for them glove boxes. Very rugged and bright for their size.',
#   'These are perfect for when I walk the dog and the sun goes down before I get home.  They are small enough to fit in my pocket without being annoyingly bulky.  Decent quality, metal construction, only takes one AA battery.  It is pretty much a pint size zoom-able LED flashlight that is very bright for its size.  I would recommend to family and friends.',
#   'bright and compact design. have them all thru out my house.',
#   'These are great flashlights. They are perfect for any outdoor activity - hunting, fishing, walking your dog and picking up poop... They are heavy duty so they can be packed in your gear and will stand up to the rugged outdoors.',
#   'Wow these were a lot brighter than I expected. I bought one to attach to my home defense shotgun and the other for my car. The only draw back was not being able to get the belt clip off without snapping it but no biggie.',
#   'Great for the price.No complaints so far.',
#   'When turning these on, you get a different mode each time. Who wants a flashlight that shines a random mode each time? I use the same mode 99% of the time so have to change modes every time I turn it on. No thanks.',
#   "After getting screwed by the seller Vaya I bought this 2 pack. Not bad for a $4 flashlight. The clips are strong, might have to modify the clip. I'm happy with this product. Get what you pay for. I waited nearly 2 months for the Vaya and never did get it. This one I got overnight.",
#   'These are GREAT!'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '2.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on February 23, 2017',
#   'on February 19, 2017',
#   'on February 19, 2017',
#   'on February 18, 2017',
#   'on February 17, 2017',
#   'on February 16, 2017',
#   'on February 16, 2017',
#   'on February 15, 2017',
#   'on February 13, 2017',
#   'on February 6, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_98 = url+str(98)
soup_98 = bs4.BeautifulSoup(requests.get(url_98).text, 'html5lib')
review_general_98 = soup_98.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_98 = review_general_98.find_all('div', attrs={'class': 'a-section review'})
review_title_98 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_98]
review_body_98 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_98]
review_stars_98 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_98]
review_date_98 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_98]
review_title_98, review_body_98, review_stars_98, review_date_98
# Out:
# (['Santa Flew right by',
#   'Five Stars',
#   'Changed battery stopped working',
#   'but very good light source',
#   'They feel nice and hefty feel like theyre powerful',
#   'Not durable',
#   'and the illumination is great for the size',
#   'Excellent Flashlights',
#   'All of them are working great. Bought some from another company in colors',
#   'Nice compact light'],
#  ['The lights are  Nice.  Several others are similar.however  promised the Xmas Delivery..  no-show- Still waiting for some type of acknowledgement.ps it kept saying out for delivery.  im rural and i froze three days waiting for the driver',
#   'They work as expected.',
#   "Don't use to often very bright.Broken spring not making good contact. After changing battery.iI initially gave it 5 Stars but changed it after it stopped.working.",
#   'Wish they were smaller, but very good light source, and good price. Would buy again.',
#   'WOW are these bright. Theyre small but they pack quite the punch. They feel nice and hefty feel like theyre powerful. 10/10 i love em',
#   "Loved it at first, but after dropping it once, the flashlight will not turn on. I tried replacing the battery, and looking inside to see if I could fix it. I don't see any way.",
#   "These are very small flashlights. They feel very solid though, and the illumination is great for the size. They easily clip inside the pocket of a pair of jeans and feel very similar to a clipped folding knife in my pocket. The housing at the end of the light slides in and out to adjust the beam, and there is a strobe setting on the light when you press the power button off and on again. Two lights come in the package. At first it seemed a little spendy for them when looking at their size, but as I have used it, and had it in my pocket, these are 20 times the light you get at a dollar store, or by spending less somewhere else. I bought 3 packs of 2. They have held up under the abuse my son's and friends dish out so far. And, they are very compact.",
#   'These flashlights are awesome. They are very small but provide a super-bright light. I especially like the 3 settings: bright, dim and flash. The flash is almost like a strobe light and is perfect for walking the dog at night. The clip is great too. Highly recommend.',
#   'All of them are working great. Bought some from another company in colors, and a few had problems, so they are not prefect, but for the price, amazing even if one out of 10 does not work.Seem to use up batteries a bit faster, but with only one battery at a time, seems to be OK or on par with other flashlights on battery use.Have 10 now, all over house, use them all the time, fantastic.',
#   '5 out of 6 were good.'],
#  ['4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '4.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '1.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '4.0 out of 5 stars'],
#  ['on January 21, 2017',
#   'on January 20, 2017',
#   'on January 17, 2017',
#   'on January 17, 2017',
#   'on January 15, 2017',
#   'on January 10, 2017',
#   'on January 6, 2017',
#   'on January 5, 2017',
#   'on January 3, 2017',
#   'on January 3, 2017'])

# %%
url = """https://www.amazon.com/RockBirds-Flashlights-Bright-Aluminum-Flashlight/product-reviews/B00X61AJYM/ref=cm_cr_getr_d_paging_btm_147?sortBy=recent&pageNumber="""
url_99 = url+str(99)
soup_99 = bs4.BeautifulSoup(requests.get(url_99).text, 'html5lib')
review_general_99 = soup_99.find('div', attrs={'class': 'a-section a-spacing-none review-views celwidget'})
review_section_99 = review_general_99.find_all('div', attrs={'class': 'a-section review'})
review_title_99 = [s.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base a-text-bold'})
                 .text.strip() for s in review_section_99]
review_body_99 = [s.find('div', attrs={'class':'a-row review-data'}).text.strip() for s in review_section_99]
review_stars_99 = [s.find('span', attrs={'class':'a-icon-alt'}).text.strip() for s in review_section_99]
review_date_99 = [s.find('span', attrs={'class':'a-size-base a-color-secondary review-date'}).text.strip() for s in review_section_99]
review_title_99, review_body_99, review_stars_99, review_date_99
# Out:
# (['Five Stars',
#   'Good',
#   'Five Stars',
#   'Five Stars',
#   'Ehh...Cheap',
#   'Five Stars',
#   'Perfect',
#   'Like it very much',
#   'Five Stars',
#   'Five Stars'],
#  ['better than expected',
#   'Product as described, shipped promptly.',
#   'great flash lights, 3 modes low light, bright light, and strobe',
#   'The best! Love that it uses 1 AA cell. Bought 2 more for Xmas presents.',
#   "They're cheap, but you knew that already. They're definitely not streamlight flashlights, but I mean, for the kids to have in their pocket while we're camping, who cares. They put off a square light. They squareness dissipates some as you zoom it. If you want a cheap couple lights for the kids, grab these. But for your car or backpack, I'd spend a bit more.",
#   'I use these for security and they are perfect. Not too big but very bright.',
#   'Great product! These things are amazingly bright. I also like that you can adjust the beam from a smaller, focused beam to a wider beam.',
#   "Nice flashlights. Carry in your pocket. Simple to use. Push the button, it's on. Zoom works well.",
#   'very nice',
#   'Great mini flashlight that packs a punch in brightness'],
#  ['5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '3.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars',
#   '5.0 out of 5 stars'],
#  ['on January 2, 2017',
#   'on January 2, 2017',
#   'on January 1, 2017',
#   'on December 30, 2016',
#   'on December 29, 2016',
#   'on December 20, 2016',
#   'on December 20, 2016',
#   'on December 19, 2016',
#   'on December 19, 2016',
#   'on December 18, 2016'])

# %%
import pandas as pd
from pandas.core.frame import DataFrame
import numpy as np

# %%
review_title = review_title_1 + review_title_2 + review_title_3 + review_title_4 + review_title_5 + review_title_6 + review_title_7 + review_title_8 + review_title_9 + review_title_10+ review_title_11 + review_title_12 + review_title_13 + review_title_14 + review_title_15 + review_title_16 + review_title_17 + review_title_18 + review_title_19 + review_title_20 + review_title_21 + review_title_22 + review_title_23 + review_title_24 + review_title_25 + review_title_26 + review_title_27 + review_title_28 + review_title_29 + review_title_30 + review_title_31 + review_title_32 + review_title_33 + review_title_34 + review_title_35 + review_title_36 + review_title_37 + review_title_38 + review_title_39 + review_title_40 + review_title_41 + review_title_42 + review_title_43 + review_title_44 + review_title_45 + review_title_46 + review_title_47 + review_title_48 + review_title_49 + review_title_50 + review_title_51 + review_title_52 + review_title_53 + review_title_54 + review_title_55 + review_title_56 + review_title_57 + review_title_58 + review_title_59 + review_title_60 + review_title_61 + review_title_62 + review_title_63 + review_title_64 + review_title_65 + review_title_66 + review_title_67 + review_title_68 + review_title_69 + review_title_70 + review_title_71 + review_title_72 + review_title_73 + review_title_74 + review_title_75 + review_title_76 + review_title_77 + review_title_78 + review_title_79 + review_title_80 + review_title_81 + review_title_82 + review_title_83 + review_title_84 + review_title_85 + review_title_86 + review_title_87 + review_title_88 + review_title_89 + review_title_90 + review_title_91 + review_title_92 + review_title_93 + review_title_94 + review_title_95 + review_title_96 + review_title_97 + review_title_98 + review_title_99

# %%
review_stars = review_stars_1 + review_stars_2 + review_stars_3 + review_stars_4 + review_stars_5 + review_stars_6 + review_stars_7 + review_stars_8 + review_stars_9 + review_stars_10 + review_stars_11 + review_stars_12 + review_stars_13 + review_stars_14 + review_stars_15 + review_stars_16 + review_stars_17 + review_stars_18 + review_stars_19 + review_stars_20 + review_stars_21 + review_stars_22 + review_stars_23 + review_stars_24 + review_stars_25 + review_stars_26 + review_stars_27 + review_stars_28 + review_stars_29 + review_stars_30 + review_stars_31 + review_stars_32 + review_stars_33 + review_stars_34 + review_stars_35 + review_stars_36 + review_stars_37 + review_stars_38 + review_stars_39 + review_stars_40 + review_stars_41 + review_stars_42 + review_stars_43 + review_stars_44 + review_stars_45 + review_stars_46 + review_stars_47 + review_stars_48 + review_stars_49 + review_stars_50 + review_stars_51 + review_stars_52 + review_stars_53 + review_stars_54 + review_stars_55 + review_stars_56 + review_stars_57 + review_stars_58 + review_stars_59 + review_stars_60 + review_stars_61 + review_stars_62 + review_stars_63 + review_stars_64 + review_stars_65 + review_stars_66 + review_stars_67 + review_stars_68 + review_stars_69 + review_stars_70 + review_stars_71 + review_stars_72 + review_stars_73 + review_stars_74 + review_stars_75 + review_stars_76 + review_stars_77 + review_stars_78 + review_stars_79 + review_stars_80 + review_stars_81 + review_stars_82 + review_stars_83 + review_stars_84 + review_stars_85 + review_stars_86 + review_stars_87 + review_stars_88 + review_stars_89 + review_stars_90 + review_stars_91 + review_stars_92 + review_stars_93 + review_stars_94 + review_stars_95 + review_stars_96 + review_stars_97 + review_stars_98 + review_stars_99

# %%
review_date = review_date_1 + review_date_2 + review_date_3 + review_date_4 + review_date_5 + review_date_6 + review_date_7 + review_date_8 + review_date_9 + review_date_10 + review_date_11 + review_date_12 + review_date_13 + review_date_14 + review_date_15 + review_date_16 + review_date_17 + review_date_18 + review_date_19 + review_date_20 + review_date_21 + review_date_22 + review_date_23 + review_date_24 + review_date_25 + review_date_26 + review_date_27 + review_date_28 + review_date_29 + review_date_30 + review_date_31 + review_date_32 + review_date_33 + review_date_34 + review_date_35 + review_date_36 + review_date_37 + review_date_38 + review_date_39 + review_date_40 + review_date_41 + review_date_42 + review_date_43 + review_date_44 + review_date_45 + review_date_46 + review_date_47 + review_date_48 + review_date_49 + review_date_50 + review_date_51 + review_date_52 + review_date_53 + review_date_54 + review_date_55 + review_date_56 + review_date_57 + review_date_58 + review_date_59 + review_date_60 + review_date_61 + review_date_62 + review_date_63 + review_date_64 + review_date_65 + review_date_66 + review_date_67 + review_date_68 + review_date_69 + review_date_70 + review_date_71 + review_date_72 + review_date_73 + review_date_74 + review_date_75 + review_date_76 + review_date_77 + review_date_78 + review_date_79 + review_date_80 + review_date_81 + review_date_82 + review_date_83 + review_date_84 + review_date_85 + review_date_86 + review_date_87 + review_date_88 + review_date_89 + review_date_90 + review_date_91 + review_date_92 + review_date_93 + review_date_94 + review_date_95 + review_date_96 + review_date_97 + review_date_98 + review_date_99

# %%
review_body = review_body_1 + review_body_2 + review_body_3 + review_body_4 + review_body_5 + review_body_6 + review_body_7 + review_body_8 + review_body_9 + review_body_10 + review_body_11 + review_body_12 + review_body_13 + review_body_14 + review_body_15 + review_body_16 + review_body_17 + review_body_18 + review_body_19 + review_body_20 + review_body_21 + review_body_22 + review_body_23 + review_body_24 + review_body_25 + review_body_26 + review_body_27 + review_body_28 + review_body_29 + review_body_30 + review_body_31 + review_body_32 + review_body_33 + review_body_34 + review_body_35 + review_body_36 + review_body_37 + review_body_38 + review_body_39 + review_body_40 + review_body_41 + review_body_42 + review_body_43 + review_body_44 + review_body_45 + review_body_46 + review_body_47 + review_body_48 + review_body_49 + review_body_50 + review_body_51 + review_body_52 + review_body_53 + review_body_54 + review_body_55 + review_body_56 + review_body_57 + review_body_58 + review_body_59 + review_body_60 + review_body_61 + review_body_62 + review_body_63 + review_body_64 + review_body_65 + review_body_66 + review_body_67 + review_body_68 + review_body_69 + review_body_70 + review_body_71 + review_body_72 + review_body_73 + review_body_74 + review_body_75 + review_body_76 + review_body_77 + review_body_78 + review_body_79 + review_body_80 + review_body_81 + review_body_82 + review_body_83 + review_body_84 + review_body_85 + review_body_86 + review_body_87 + review_body_88 + review_body_89 + review_body_90 + review_body_91 + review_body_92 + review_body_93 + review_body_94 + review_body_95 + review_body_96 + review_body_97 + review_body_98 + review_body_99

# %%
df = pd.DataFrame(list(zip(review_title,review_stars, review_date,review_body)))
df.columns = ['review_title','review_stars','review_date','review_body']
df.head(983)
# Out:
#                                           review_title        review_stars  \
# 0    It isn't very bright but it's small and will e...  5.0 out of 5 stars
# 1                           Bright, but eats batteries  5.0 out of 5 stars
# 2           They work pretty good. Didn't blow me away  4.0 out of 5 stars
# 3                                           Four Stars  4.0 out of 5 stars
# 4                                           Five Stars  5.0 out of 5 stars
# 5    Works good on 1.2 volt Rechargeable Ni-Mh Batt...  5.0 out of 5 stars
# 6                                           Five Stars  5.0 out of 5 stars
# 7                                     Dependable light  5.0 out of 5 stars
# 8                                           Four Stars  4.0 out of 5 stars
# 9            One worked fine, the other would not turn  2.0 out of 5 stars
# 10                                          Five Stars  5.0 out of 5 stars
# 11                           Well made, solid aluminum  4.0 out of 5 stars
# 12   When you zoom in it doesnt even look like the ...  1.0 out of 5 stars
# 13                             Do not waste your money  1.0 out of 5 stars
# 14                                          Five Stars  5.0 out of 5 stars
# 15                                          Five Stars  5.0 out of 5 stars
# 16                                        Flash lights  1.0 out of 5 stars
# 17                                 Perfect for camping  5.0 out of 5 stars
# 18                                          Five Stars  5.0 out of 5 stars
# 19                                         A GREAT BUY  5.0 out of 5 stars
# 20                                          Five Stars  5.0 out of 5 stars
# 21                                        Good Quality  5.0 out of 5 stars
# 22                           Not worth a 3star review.  2.0 out of 5 stars
# 23    I loaded each flashlight with a with an AA 2 ...  5.0 out of 5 stars
# 24                     Great range for a small package  5.0 out of 5 stars
# 25                                          Five Stars  5.0 out of 5 stars
# 26                                Sturdy little lights  5.0 out of 5 stars
# 27                                          Five Stars  5.0 out of 5 stars
# 28                                   Love this product  5.0 out of 5 stars
# 29                                    Light but bright  5.0 out of 5 stars
# ..                                                 ...                 ...
# 953                                              great  5.0 out of 5 stars
# 954                              Fantastic mini lights  5.0 out of 5 stars
# 955                                         Five Stars  5.0 out of 5 stars
# 956                                         Five Stars  5.0 out of 5 stars
# 957                                         Five Stars  5.0 out of 5 stars
# 958                                   It's rock solid!  5.0 out of 5 stars
# 959                                Not for rugged use.  3.0 out of 5 stars
# 960           Bright and Tough with only 1 AA Battery!  5.0 out of 5 stars
# 961                                         Five Stars  5.0 out of 5 stars
# 962                       Great Pint Size Flashlight!!  4.0 out of 5 stars
# 963                                         Five Stars  5.0 out of 5 stars
# 964                         Great sporting flashlights  5.0 out of 5 stars
# 965                             Brighter Than Expected  5.0 out of 5 stars
# 966                                         Four Stars  4.0 out of 5 stars
# 967  When turning these on, you get a different mod...  2.0 out of 5 stars
# 968               Best $4.00 dollar light we have had.  4.0 out of 5 stars
# 969                                        GREAT VALUE  5.0 out of 5 stars
# 970                                Santa Flew right by  4.0 out of 5 stars
# 971                                         Five Stars  5.0 out of 5 stars
# 972                    Changed battery stopped working  1.0 out of 5 stars
# 973                         but very good light source  4.0 out of 5 stars
# 974  They feel nice and hefty feel like theyre powe...  5.0 out of 5 stars
# 975                                        Not durable  1.0 out of 5 stars
# 976         and the illumination is great for the size  5.0 out of 5 stars
# 977                              Excellent Flashlights  5.0 out of 5 stars
# 978  All of them are working great. Bought some fro...  5.0 out of 5 stars
# 979                                 Nice compact light  4.0 out of 5 stars
# 980                                         Five Stars  5.0 out of 5 stars
# 981                                               Good  5.0 out of 5 stars
# 982                                         Five Stars  5.0 out of 5 stars
#
#               review_date                                        review_body
# 0       on April 17, 2018  It isn't very bright but it's small and will e...
# 1       on April 16, 2018  Very bright, I work in a run down steel mill a...
# 2       on April 16, 2018  They work pretty good. Didn't blow me away, an...
# 3       on April 16, 2018  I will only say for now so far so good, will s...
# 4       on April 16, 2018  Great little flashlight, very bright, will buy...
# 5       on April 15, 2018  Nice well made little flashlight, they work go...
# 6       on April 15, 2018  It's exactly as described and I received it qu...
# 7       on April 14, 2018  Very small and very bright. These fit easy int...
# 8       on April 14, 2018                  Good flashlights at a good price.
# 9       on April 14, 2018  Received 2 flashlights. One worked fine, the o...
# 10      on April 14, 2018  These lights are alot nicer than I expected fo...
# 11      on April 14, 2018  Well made, solid aluminum.  Was tough to figur...
# 12      on April 13, 2018  Not what i got as advertised. When you zoom in...
# 13      on April 13, 2018                          Junk junk junk sums it up
# 14      on April 13, 2018                         Really good for the price.
# 15      on April 12, 2018  They both work great. Can adjust beam very eas...
# 16      on April 12, 2018  The 1st flashlight I used at work fell apart i...
# 17      on April 12, 2018  I ordered these to put in our camper for a lig...
# 18      on April 12, 2018          This flashlight is exactly what I wanted.
# 19      on April 12, 2018  Really great flashlights. Well made, bright li...
# 20      on April 11, 2018                 This is great of camping, cycling.
# 21      on April 11, 2018  Good little well made flashlight. Can't beat t...
# 22      on April 11, 2018  Because they were $4 each that got them one st...
# 23      on April 11, 2018  I loaded each flashlight with a with an AA 2,8...
# 24      on April 11, 2018  We were looking for a decent flashlight for ou...
# 25      on April 11, 2018                             Very nice, works great
# 26      on April 11, 2018  These are sturdy little flashlights that we pl...
# 27      on April 10, 2018  EXCELLENT FLASHLIGHT ! Not sure exactly what p...
# 28      on April 10, 2018  This is the 2nd set of RockBirds I have purcha...
# 29      on April 10, 2018  It is small but mighty. This little flashlight...
# ..                    ...                                                ...
# 953      on March 2, 2017                                great little lights
# 954      on March 2, 2017  Fantastic mini lights. Very bright . They come...
# 955      on March 1, 2017                                          love them
# 956      on March 1, 2017                        Excellent! These are great!
# 957  on February 24, 2017                                  MUY BUEN PRODUCTO
# 958  on February 23, 2017  Rock solid construction with great beams of li...
# 959  on February 23, 2017  Dropped the light one time. Now the slightest ...
# 960  on February 23, 2017  Really like these flashlights! Work very well....
# 961  on February 19, 2017  Nice little lights. Got one for them glove box...
# 962  on February 19, 2017  These are perfect for when I walk the dog and ...
# 963  on February 18, 2017  bright and compact design. have them all thru ...
# 964  on February 17, 2017  These are great flashlights. They are perfect ...
# 965  on February 16, 2017  Wow these were a lot brighter than I expected....
# 966  on February 16, 2017          Great for the price.No complaints so far.
# 967  on February 15, 2017  When turning these on, you get a different mod...
# 968  on February 13, 2017  After getting screwed by the seller Vaya I bou...
# 969   on February 6, 2017                                   These are GREAT!
# 970   on January 21, 2017  The lights are  Nice.  Several others are simi...
# 971   on January 20, 2017                             They work as expected.
# 972   on January 17, 2017  Don't use to often very bright.Broken spring n...
# 973   on January 17, 2017  Wish they were smaller, but very good light so...
# 974   on January 15, 2017  WOW are these bright. Theyre small but they pa...
# 975   on January 10, 2017  Loved it at first, but after dropping it once,...
# 976    on January 6, 2017  These are very small flashlights. They feel ve...
# 977    on January 5, 2017  These flashlights are awesome. They are very s...
# 978    on January 3, 2017  All of them are working great. Bought some fro...
# 979    on January 3, 2017                              5 out of 6 were good.
# 980    on January 2, 2017                               better than expected
# 981    on January 2, 2017            Product as described, shipped promptly.
# 982    on January 1, 2017  great flash lights, 3 modes low light, bright ...
#
# [983 rows x 4 columns]

# %%
df.to_json("reviews.json")

# %%
df.describe()
# Out:
#        review_title        review_stars       review_date    review_body
# count           990                 990               990            990
# unique          656                   5               357            972
# top      Five Stars  5.0 out of 5 stars  on April 9, 2018  Great product
# freq            230                 644                23              4

# %%
df.columns
# Out:
# Index(['review_title', 'review_stars', 'review_date', 'review_body'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=990, step=1)

# %%
df.set_index('review_stars')
# Out:
#                                                          review_title  \
# review_stars
# 5.0 out of 5 stars  It isn't very bright but it's small and will e...
# 5.0 out of 5 stars                         Bright, but eats batteries
# 4.0 out of 5 stars         They work pretty good. Didn't blow me away
# 4.0 out of 5 stars                                         Four Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars  Works good on 1.2 volt Rechargeable Ni-Mh Batt...
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                   Dependable light
# 4.0 out of 5 stars                                         Four Stars
# 2.0 out of 5 stars          One worked fine, the other would not turn
# 5.0 out of 5 stars                                         Five Stars
# 4.0 out of 5 stars                          Well made, solid aluminum
# 1.0 out of 5 stars  When you zoom in it doesnt even look like the ...
# 1.0 out of 5 stars                            Do not waste your money
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 1.0 out of 5 stars                                       Flash lights
# 5.0 out of 5 stars                                Perfect for camping
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                        A GREAT BUY
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                       Good Quality
# 2.0 out of 5 stars                          Not worth a 3star review.
# 5.0 out of 5 stars   I loaded each flashlight with a with an AA 2 ...
# 5.0 out of 5 stars                    Great range for a small package
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                               Sturdy little lights
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                  Love this product
# 5.0 out of 5 stars                                   Light but bright
# ...                                                               ...
# 5.0 out of 5 stars           Bright and Tough with only 1 AA Battery!
# 5.0 out of 5 stars                                         Five Stars
# 4.0 out of 5 stars                       Great Pint Size Flashlight!!
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                         Great sporting flashlights
# 5.0 out of 5 stars                             Brighter Than Expected
# 4.0 out of 5 stars                                         Four Stars
# 2.0 out of 5 stars  When turning these on, you get a different mod...
# 4.0 out of 5 stars               Best $4.00 dollar light we have had.
# 5.0 out of 5 stars                                        GREAT VALUE
# 4.0 out of 5 stars                                Santa Flew right by
# 5.0 out of 5 stars                                         Five Stars
# 1.0 out of 5 stars                    Changed battery stopped working
# 4.0 out of 5 stars                         but very good light source
# 5.0 out of 5 stars  They feel nice and hefty feel like theyre powe...
# 1.0 out of 5 stars                                        Not durable
# 5.0 out of 5 stars         and the illumination is great for the size
# 5.0 out of 5 stars                              Excellent Flashlights
# 5.0 out of 5 stars  All of them are working great. Bought some fro...
# 4.0 out of 5 stars                                 Nice compact light
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                               Good
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 3.0 out of 5 stars                                        Ehh...Cheap
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                            Perfect
# 5.0 out of 5 stars                                  Like it very much
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
#
#                              review_date  \
# review_stars
# 5.0 out of 5 stars     on April 17, 2018
# 5.0 out of 5 stars     on April 16, 2018
# 4.0 out of 5 stars     on April 16, 2018
# 4.0 out of 5 stars     on April 16, 2018
# 5.0 out of 5 stars     on April 16, 2018
# 5.0 out of 5 stars     on April 15, 2018
# 5.0 out of 5 stars     on April 15, 2018
# 5.0 out of 5 stars     on April 14, 2018
# 4.0 out of 5 stars     on April 14, 2018
# 2.0 out of 5 stars     on April 14, 2018
# 5.0 out of 5 stars     on April 14, 2018
# 4.0 out of 5 stars     on April 14, 2018
# 1.0 out of 5 stars     on April 13, 2018
# 1.0 out of 5 stars     on April 13, 2018
# 5.0 out of 5 stars     on April 13, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 1.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 2.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# ...                                  ...
# 5.0 out of 5 stars  on February 23, 2017
# 5.0 out of 5 stars  on February 19, 2017
# 4.0 out of 5 stars  on February 19, 2017
# 5.0 out of 5 stars  on February 18, 2017
# 5.0 out of 5 stars  on February 17, 2017
# 5.0 out of 5 stars  on February 16, 2017
# 4.0 out of 5 stars  on February 16, 2017
# 2.0 out of 5 stars  on February 15, 2017
# 4.0 out of 5 stars  on February 13, 2017
# 5.0 out of 5 stars   on February 6, 2017
# 4.0 out of 5 stars   on January 21, 2017
# 5.0 out of 5 stars   on January 20, 2017
# 1.0 out of 5 stars   on January 17, 2017
# 4.0 out of 5 stars   on January 17, 2017
# 5.0 out of 5 stars   on January 15, 2017
# 1.0 out of 5 stars   on January 10, 2017
# 5.0 out of 5 stars    on January 6, 2017
# 5.0 out of 5 stars    on January 5, 2017
# 5.0 out of 5 stars    on January 3, 2017
# 4.0 out of 5 stars    on January 3, 2017
# 5.0 out of 5 stars    on January 2, 2017
# 5.0 out of 5 stars    on January 2, 2017
# 5.0 out of 5 stars    on January 1, 2017
# 5.0 out of 5 stars  on December 30, 2016
# 3.0 out of 5 stars  on December 29, 2016
# 5.0 out of 5 stars  on December 20, 2016
# 5.0 out of 5 stars  on December 20, 2016
# 5.0 out of 5 stars  on December 19, 2016
# 5.0 out of 5 stars  on December 19, 2016
# 5.0 out of 5 stars  on December 18, 2016
#
#                                                           review_body
# review_stars
# 5.0 out of 5 stars  It isn't very bright but it's small and will e...
# 5.0 out of 5 stars  Very bright, I work in a run down steel mill a...
# 4.0 out of 5 stars  They work pretty good. Didn't blow me away, an...
# 4.0 out of 5 stars  I will only say for now so far so good, will s...
# 5.0 out of 5 stars  Great little flashlight, very bright, will buy...
# 5.0 out of 5 stars  Nice well made little flashlight, they work go...
# 5.0 out of 5 stars  It's exactly as described and I received it qu...
# 5.0 out of 5 stars  Very small and very bright. These fit easy int...
# 4.0 out of 5 stars                  Good flashlights at a good price.
# 2.0 out of 5 stars  Received 2 flashlights. One worked fine, the o...
# 5.0 out of 5 stars  These lights are alot nicer than I expected fo...
# 4.0 out of 5 stars  Well made, solid aluminum.  Was tough to figur...
# 1.0 out of 5 stars  Not what i got as advertised. When you zoom in...
# 1.0 out of 5 stars                          Junk junk junk sums it up
# 5.0 out of 5 stars                         Really good for the price.
# 5.0 out of 5 stars  They both work great. Can adjust beam very eas...
# 1.0 out of 5 stars  The 1st flashlight I used at work fell apart i...
# 5.0 out of 5 stars  I ordered these to put in our camper for a lig...
# 5.0 out of 5 stars          This flashlight is exactly what I wanted.
# 5.0 out of 5 stars  Really great flashlights. Well made, bright li...
# 5.0 out of 5 stars                 This is great of camping, cycling.
# 5.0 out of 5 stars  Good little well made flashlight. Can't beat t...
# 2.0 out of 5 stars  Because they were $4 each that got them one st...
# 5.0 out of 5 stars  I loaded each flashlight with a with an AA 2,8...
# 5.0 out of 5 stars  We were looking for a decent flashlight for ou...
# 5.0 out of 5 stars                             Very nice, works great
# 5.0 out of 5 stars  These are sturdy little flashlights that we pl...
# 5.0 out of 5 stars  EXCELLENT FLASHLIGHT ! Not sure exactly what p...
# 5.0 out of 5 stars  This is the 2nd set of RockBirds I have purcha...
# 5.0 out of 5 stars  It is small but mighty. This little flashlight...
# ...                                                               ...
# 5.0 out of 5 stars  Really like these flashlights! Work very well....
# 5.0 out of 5 stars  Nice little lights. Got one for them glove box...
# 4.0 out of 5 stars  These are perfect for when I walk the dog and ...
# 5.0 out of 5 stars  bright and compact design. have them all thru ...
# 5.0 out of 5 stars  These are great flashlights. They are perfect ...
# 5.0 out of 5 stars  Wow these were a lot brighter than I expected....
# 4.0 out of 5 stars          Great for the price.No complaints so far.
# 2.0 out of 5 stars  When turning these on, you get a different mod...
# 4.0 out of 5 stars  After getting screwed by the seller Vaya I bou...
# 5.0 out of 5 stars                                   These are GREAT!
# 4.0 out of 5 stars  The lights are  Nice.  Several others are simi...
# 5.0 out of 5 stars                             They work as expected.
# 1.0 out of 5 stars  Don't use to often very bright.Broken spring n...
# 4.0 out of 5 stars  Wish they were smaller, but very good light so...
# 5.0 out of 5 stars  WOW are these bright. Theyre small but they pa...
# 1.0 out of 5 stars  Loved it at first, but after dropping it once,...
# 5.0 out of 5 stars  These are very small flashlights. They feel ve...
# 5.0 out of 5 stars  These flashlights are awesome. They are very s...
# 5.0 out of 5 stars  All of them are working great. Bought some fro...
# 4.0 out of 5 stars                              5 out of 6 were good.
# 5.0 out of 5 stars                               better than expected
# 5.0 out of 5 stars            Product as described, shipped promptly.
# 5.0 out of 5 stars  great flash lights, 3 modes low light, bright ...
# 5.0 out of 5 stars  The best! Love that it uses 1 AA cell. Bought ...
# 3.0 out of 5 stars  They're cheap, but you knew that already. They...
# 5.0 out of 5 stars  I use these for security and they are perfect....
# 5.0 out of 5 stars  Great product! These things are amazingly brig...
# 5.0 out of 5 stars  Nice flashlights. Carry in your pocket. Simple...
# 5.0 out of 5 stars                                          very nice
# 5.0 out of 5 stars  Great mini flashlight that packs a punch in br...
#
# [990 rows x 3 columns]

# %%
df_stars = df.set_index('review_stars')

# %%
df_stars.loc['1.0 out of 5 stars']
# Out:
#                                                          review_title  \
# review_stars
# 1.0 out of 5 stars  When you zoom in it doesnt even look like the ...
# 1.0 out of 5 stars                            Do not waste your money
# 1.0 out of 5 stars                                       Flash lights
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars             The one that does is mediocre at best.
# 1.0 out of 5 stars                                       Poor quality
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                               Total waste of money
# 1.0 out of 5 stars                                  Waste of my money
# 1.0 out of 5 stars                            Flashlight cop material
# 1.0 out of 5 stars        0/2 working flashlights.  complete garbage.
# 1.0 out of 5 stars                            one works the ot doesnt
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars  I bought 2 and they worked great for 2-3 weeks...
# 1.0 out of 5 stars                                Faulty, low quality
# 1.0 out of 5 stars  I I did not like the flashlight because the on...
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars  I have had excellent service life from other L...
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                                        Total JUNK!
# 1.0 out of 5 stars                                       Did not work
# 1.0 out of 5 stars                        NOT SUITABLE AS BIKE LIGHT!
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                               Defective. Don’t buy
# 1.0 out of 5 stars                               Only lasted 45 days.
# 1.0 out of 5 stars  Absolutely terrible trash. Have yet to work pr...
# 1.0 out of 5 stars  Do Not Buy!!!!  Very Poor Quality & short life...
# 1.0 out of 5 stars                         Complete Junk! Do not buy!
# ...                                                               ...
# 1.0 out of 5 stars                                        DONT BUY!!!
# 1.0 out of 5 stars                             Don't waste your money
# 1.0 out of 5 stars                                   Absolute Garbage
# 1.0 out of 5 stars                                          Dangerous
# 1.0 out of 5 stars                                 Very sad bout this
# 1.0 out of 5 stars                                         Don't work
# 1.0 out of 5 stars  Got both light and was excited about them (fro...
# 1.0 out of 5 stars                                           one star
# 1.0 out of 5 stars  came as a 2 pack one flashlight only turns on ...
# 1.0 out of 5 stars                              Don't buy. Unreliable
# 1.0 out of 5 stars                                     Danger!Danger!
# 1.0 out of 5 stars                                           TERRIBLE
# 1.0 out of 5 stars                                  Terrible product.
# 1.0 out of 5 stars                   ONLY ONE WORKS LIKE IT SHOULD...
# 1.0 out of 5 stars                                            Rip off
# 1.0 out of 5 stars  Quick shipping. Flash light is week compared t...
# 1.0 out of 5 stars                                       50/50 chance
# 1.0 out of 5 stars  I did not expect much from this light at this ...
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars                                     Disappointing.
# 1.0 out of 5 stars                        Very Dim and Disappointing.
# 1.0 out of 5 stars                                           One Star
# 1.0 out of 5 stars  One unit works great. It will be good for my t...
# 1.0 out of 5 stars                                       Disappointed
# 1.0 out of 5 stars                          Piece of Crap - Don't Buy
# 1.0 out of 5 stars             they dont cost much but now i know why
# 1.0 out of 5 stars           One out of the two works. It did not ...
# 1.0 out of 5 stars                         A cimplete waste of money.
# 1.0 out of 5 stars                    Changed battery stopped working
# 1.0 out of 5 stars                                        Not durable
#
#                              review_date  \
# review_stars
# 1.0 out of 5 stars     on April 13, 2018
# 1.0 out of 5 stars     on April 13, 2018
# 1.0 out of 5 stars     on April 12, 2018
# 1.0 out of 5 stars     on April 10, 2018
# 1.0 out of 5 stars      on April 9, 2018
# 1.0 out of 5 stars      on April 9, 2018
# 1.0 out of 5 stars      on April 9, 2018
# 1.0 out of 5 stars      on April 8, 2018
# 1.0 out of 5 stars      on April 5, 2018
# 1.0 out of 5 stars      on April 5, 2018
# 1.0 out of 5 stars      on April 5, 2018
# 1.0 out of 5 stars      on April 4, 2018
# 1.0 out of 5 stars      on April 4, 2018
# 1.0 out of 5 stars     on March 17, 2018
# 1.0 out of 5 stars     on March 11, 2018
# 1.0 out of 5 stars      on March 9, 2018
# 1.0 out of 5 stars  on February 17, 2018
# 1.0 out of 5 stars   on February 5, 2018
# 1.0 out of 5 stars   on February 2, 2018
# 1.0 out of 5 stars   on January 16, 2018
# 1.0 out of 5 stars   on January 10, 2018
# 1.0 out of 5 stars    on January 9, 2018
# 1.0 out of 5 stars    on January 4, 2018
# 1.0 out of 5 stars    on January 3, 2018
# 1.0 out of 5 stars  on December 29, 2017
# 1.0 out of 5 stars  on December 29, 2017
# 1.0 out of 5 stars  on December 24, 2017
# 1.0 out of 5 stars  on December 23, 2017
# 1.0 out of 5 stars  on December 22, 2017
# 1.0 out of 5 stars  on December 19, 2017
# ...                                  ...
# 1.0 out of 5 stars    on August 29, 2017
# 1.0 out of 5 stars    on August 18, 2017
# 1.0 out of 5 stars    on August 14, 2017
# 1.0 out of 5 stars    on August 14, 2017
# 1.0 out of 5 stars     on August 9, 2017
# 1.0 out of 5 stars      on July 28, 2017
# 1.0 out of 5 stars      on July 26, 2017
# 1.0 out of 5 stars      on July 26, 2017
# 1.0 out of 5 stars      on July 24, 2017
# 1.0 out of 5 stars      on July 22, 2017
# 1.0 out of 5 stars      on July 18, 2017
# 1.0 out of 5 stars      on July 12, 2017
# 1.0 out of 5 stars      on July 12, 2017
# 1.0 out of 5 stars       on July 6, 2017
# 1.0 out of 5 stars       on July 6, 2017
# 1.0 out of 5 stars       on July 1, 2017
# 1.0 out of 5 stars      on June 30, 2017
# 1.0 out of 5 stars      on June 29, 2017
# 1.0 out of 5 stars      on June 27, 2017
# 1.0 out of 5 stars      on June 26, 2017
# 1.0 out of 5 stars      on June 26, 2017
# 1.0 out of 5 stars      on June 25, 2017
# 1.0 out of 5 stars      on June 25, 2017
# 1.0 out of 5 stars       on May 20, 2017
# 1.0 out of 5 stars       on May 12, 2017
# 1.0 out of 5 stars        on May 4, 2017
# 1.0 out of 5 stars        on May 1, 2017
# 1.0 out of 5 stars     on April 13, 2017
# 1.0 out of 5 stars   on January 17, 2017
# 1.0 out of 5 stars   on January 10, 2017
#
#                                                           review_body
# review_stars
# 1.0 out of 5 stars  Not what i got as advertised. When you zoom in...
# 1.0 out of 5 stars                          Junk junk junk sums it up
# 1.0 out of 5 stars  The 1st flashlight I used at work fell apart i...
# 1.0 out of 5 stars  These are very cheaply made. Once of these bro...
# 1.0 out of 5 stars  Ridiculously small. You are mislead by the pic...
# 1.0 out of 5 stars  Only one works. The one that does is mediocre ...
# 1.0 out of 5 stars  The button doesn't seem to have an actuation p...
# 1.0 out of 5 stars                i have to buy batteries  china junk
# 1.0 out of 5 stars      DOA and this item is not eligible for return!
# 1.0 out of 5 stars  Can’t even get a battery in it. And it’s not b...
# 1.0 out of 5 stars  1 of the 2 flashlights work. but not as advert...
# 1.0 out of 5 stars                                      Ok for  a kid
# 1.0 out of 5 stars  So the one I could open to put a battery works...
# 1.0 out of 5 stars    1 works fine .  the other blinks intermittently
# 1.0 out of 5 stars       Already no longer working after minimal use.
# 1.0 out of 5 stars  I bought 2 and they worked great for 2-3 weeks...
# 1.0 out of 5 stars  Price is too good to be true. Don’t expect the...
# 1.0 out of 5 stars  I I did not like the flashlight because the on...
# 1.0 out of 5 stars                                        terrible！！！
# 1.0 out of 5 stars  BOTH flash lights stopped operating in less th...
# 1.0 out of 5 stars                                 1.0 out of 5 stars
# 1.0 out of 5 stars                                 1.0 out of 5 stars
# 1.0 out of 5 stars  Did not work and wouldn't let me return the item.
# 1.0 out of 5 stars  I bought these to use as a bike headlight. My ...
# 1.0 out of 5 stars           Didn’t work even tried several batteries
# 1.0 out of 5 stars  I was VERY disappointed with these flashlights...
# 1.0 out of 5 stars  Stopped working just after return period. Save...
# 1.0 out of 5 stars  If i could give this product a zero i would. A...
# 1.0 out of 5 stars  What a waste of money! These things looked lik...
# 1.0 out of 5 stars  These are complete junk. Worst flashlights I'v...
# ...                                                               ...
# 1.0 out of 5 stars  Don't buy these little flashlights. When I got...
# 1.0 out of 5 stars  These things are junk. They work for about 2 m...
# 1.0 out of 5 stars  I bought these  flashlights to keep in the glo...
# 1.0 out of 5 stars  One worked fine but the other heated up to an ...
# 1.0 out of 5 stars  Was really excited for these lights. Poor qual...
# 1.0 out of 5 stars  They don't work.  I bought them for a trip and...
# 1.0 out of 5 stars  Got both light and was excited about them (fro...
# 1.0 out of 5 stars  Received July 1, 2017 & worked fine.  Now one ...
# 1.0 out of 5 stars  came as a 2 pack one flashlight only turns on ...
# 1.0 out of 5 stars                                 One does not work.
# 1.0 out of 5 stars  Flashlight would not turn off and almost burne...
# 1.0 out of 5 stars              Complete junk.  Worked for like a day
# 1.0 out of 5 stars  As arrived, upon inserting the battery, the fl...
# 1.0 out of 5 stars  only one of the two i received works correctly...
# 1.0 out of 5 stars  This didn't work at all when I got them and th...
# 1.0 out of 5 stars  Quick shipping.Flash light is week compared to...
# 1.0 out of 5 stars                  One works fine, the other was DOA
# 1.0 out of 5 stars  I did not expect much from this light at this ...
# 1.0 out of 5 stars                little rust inside and poor quality
# 1.0 out of 5 stars  Does not return to bright after powering off, ...
# 1.0 out of 5 stars  Incredibly dim. The rubber on the button is wa...
# 1.0 out of 5 stars  The flashlights were defective when received. ...
# 1.0 out of 5 stars  I know they were not expensive. One unit works...
# 1.0 out of 5 stars  Delivery and packaging was great but the item ...
# 1.0 out of 5 stars  I wasn't able to open one of them to insert a ...
# 1.0 out of 5 stars  save your money if you drop them they don't sh...
# 1.0 out of 5 stars  One out of the two works. It did not light up ...
# 1.0 out of 5 stars  Absolute junk..Received the 2 lights today : 1...
# 1.0 out of 5 stars  Don't use to often very bright.Broken spring n...
# 1.0 out of 5 stars  Loved it at first, but after dropping it once,...
#
# [90 rows x 3 columns]

# %%
df_stars.loc['5.0 out of 5 stars']
# Out:
#                                                          review_title  \
# review_stars
# 5.0 out of 5 stars  It isn't very bright but it's small and will e...
# 5.0 out of 5 stars                         Bright, but eats batteries
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars  Works good on 1.2 volt Rechargeable Ni-Mh Batt...
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                   Dependable light
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                Perfect for camping
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                        A GREAT BUY
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                       Good Quality
# 5.0 out of 5 stars   I loaded each flashlight with a with an AA 2 ...
# 5.0 out of 5 stars                    Great range for a small package
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                               Sturdy little lights
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                  Love this product
# 5.0 out of 5 stars                                   Light but bright
# 5.0 out of 5 stars                                     You cant lose.
# 5.0 out of 5 stars                              Love the daily dealz.
# 5.0 out of 5 stars                                            Love em
# 5.0 out of 5 stars       Sturdy little lights that work every time as
# 5.0 out of 5 stars                  Well-made, bright, and good deal.
# 5.0 out of 5 stars                        Nice flashlight, Good value
# 5.0 out of 5 stars      They work.  Inexpensive but don't feel cheap.
# 5.0 out of 5 stars                                              Great
# 5.0 out of 5 stars                                         Five Stars
# ...                                                               ...
# 5.0 out of 5 stars                                  Great flashlight.
# 5.0 out of 5 stars                     A nice LED (small) flashlight!
# 5.0 out of 5 stars                                Very fast shipping!
# 5.0 out of 5 stars  Quality made and a fantastic deal!  Let me sho...
# 5.0 out of 5 stars                                              great
# 5.0 out of 5 stars                              Fantastic mini lights
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                   It's rock solid!
# 5.0 out of 5 stars           Bright and Tough with only 1 AA Battery!
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                         Great sporting flashlights
# 5.0 out of 5 stars                             Brighter Than Expected
# 5.0 out of 5 stars                                        GREAT VALUE
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars  They feel nice and hefty feel like theyre powe...
# 5.0 out of 5 stars         and the illumination is great for the size
# 5.0 out of 5 stars                              Excellent Flashlights
# 5.0 out of 5 stars  All of them are working great. Bought some fro...
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                               Good
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                            Perfect
# 5.0 out of 5 stars                                  Like it very much
# 5.0 out of 5 stars                                         Five Stars
# 5.0 out of 5 stars                                         Five Stars
#
#                              review_date  \
# review_stars
# 5.0 out of 5 stars     on April 17, 2018
# 5.0 out of 5 stars     on April 16, 2018
# 5.0 out of 5 stars     on April 16, 2018
# 5.0 out of 5 stars     on April 15, 2018
# 5.0 out of 5 stars     on April 15, 2018
# 5.0 out of 5 stars     on April 14, 2018
# 5.0 out of 5 stars     on April 14, 2018
# 5.0 out of 5 stars     on April 13, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 12, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 11, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars     on April 10, 2018
# 5.0 out of 5 stars      on April 9, 2018
# 5.0 out of 5 stars      on April 9, 2018
# ...                                  ...
# 5.0 out of 5 stars      on March 5, 2017
# 5.0 out of 5 stars      on March 5, 2017
# 5.0 out of 5 stars      on March 4, 2017
# 5.0 out of 5 stars      on March 4, 2017
# 5.0 out of 5 stars      on March 2, 2017
# 5.0 out of 5 stars      on March 2, 2017
# 5.0 out of 5 stars      on March 1, 2017
# 5.0 out of 5 stars      on March 1, 2017
# 5.0 out of 5 stars  on February 24, 2017
# 5.0 out of 5 stars  on February 23, 2017
# 5.0 out of 5 stars  on February 23, 2017
# 5.0 out of 5 stars  on February 19, 2017
# 5.0 out of 5 stars  on February 18, 2017
# 5.0 out of 5 stars  on February 17, 2017
# 5.0 out of 5 stars  on February 16, 2017
# 5.0 out of 5 stars   on February 6, 2017
# 5.0 out of 5 stars   on January 20, 2017
# 5.0 out of 5 stars   on January 15, 2017
# 5.0 out of 5 stars    on January 6, 2017
# 5.0 out of 5 stars    on January 5, 2017
# 5.0 out of 5 stars    on January 3, 2017
# 5.0 out of 5 stars    on January 2, 2017
# 5.0 out of 5 stars    on January 2, 2017
# 5.0 out of 5 stars    on January 1, 2017
# 5.0 out of 5 stars  on December 30, 2016
# 5.0 out of 5 stars  on December 20, 2016
# 5.0 out of 5 stars  on December 20, 2016
# 5.0 out of 5 stars  on December 19, 2016
# 5.0 out of 5 stars  on December 19, 2016
# 5.0 out of 5 stars  on December 18, 2016
#
#                                                           review_body
# review_stars
# 5.0 out of 5 stars  It isn't very bright but it's small and will e...
# 5.0 out of 5 stars  Very bright, I work in a run down steel mill a...
# 5.0 out of 5 stars  Great little flashlight, very bright, will buy...
# 5.0 out of 5 stars  Nice well made little flashlight, they work go...
# 5.0 out of 5 stars  It's exactly as described and I received it qu...
# 5.0 out of 5 stars  Very small and very bright. These fit easy int...
# 5.0 out of 5 stars  These lights are alot nicer than I expected fo...
# 5.0 out of 5 stars                         Really good for the price.
# 5.0 out of 5 stars  They both work great. Can adjust beam very eas...
# 5.0 out of 5 stars  I ordered these to put in our camper for a lig...
# 5.0 out of 5 stars          This flashlight is exactly what I wanted.
# 5.0 out of 5 stars  Really great flashlights. Well made, bright li...
# 5.0 out of 5 stars                 This is great of camping, cycling.
# 5.0 out of 5 stars  Good little well made flashlight. Can't beat t...
# 5.0 out of 5 stars  I loaded each flashlight with a with an AA 2,8...
# 5.0 out of 5 stars  We were looking for a decent flashlight for ou...
# 5.0 out of 5 stars                             Very nice, works great
# 5.0 out of 5 stars  These are sturdy little flashlights that we pl...
# 5.0 out of 5 stars  EXCELLENT FLASHLIGHT ! Not sure exactly what p...
# 5.0 out of 5 stars  This is the 2nd set of RockBirds I have purcha...
# 5.0 out of 5 stars  It is small but mighty. This little flashlight...
# 5.0 out of 5 stars  Just the right size for pocket, good light ,va...
# 5.0 out of 5 stars  I purchased some larger flashlights recently b...
# 5.0 out of 5 stars         What a great price you just can't beat it.
# 5.0 out of 5 stars  Sturdy little lights that work every time as a...
# 5.0 out of 5 stars  Wow.  Nicely made.  Work very well with Li Ion...
# 5.0 out of 5 stars                        Nice flashlight, Good value
# 5.0 out of 5 stars  Bright little flashlights that feel very subst...
# 5.0 out of 5 stars                                 Small and powerful
# 5.0 out of 5 stars  Love these flashlights! It does everything it ...
# ...                                                               ...
# 5.0 out of 5 stars  I use this flashlight for work. It has awesome...
# 5.0 out of 5 stars  I purchased the LED Flashlight by Rockbirds be...
# 5.0 out of 5 stars  This is probably the best and most compact set...
# 5.0 out of 5 stars  These Rockbirds LED Flashlights I bought came ...
# 5.0 out of 5 stars                                great little lights
# 5.0 out of 5 stars  Fantastic mini lights. Very bright . They come...
# 5.0 out of 5 stars                                          love them
# 5.0 out of 5 stars                        Excellent! These are great!
# 5.0 out of 5 stars                                  MUY BUEN PRODUCTO
# 5.0 out of 5 stars  Rock solid construction with great beams of li...
# 5.0 out of 5 stars  Really like these flashlights! Work very well....
# 5.0 out of 5 stars  Nice little lights. Got one for them glove box...
# 5.0 out of 5 stars  bright and compact design. have them all thru ...
# 5.0 out of 5 stars  These are great flashlights. They are perfect ...
# 5.0 out of 5 stars  Wow these were a lot brighter than I expected....
# 5.0 out of 5 stars                                   These are GREAT!
# 5.0 out of 5 stars                             They work as expected.
# 5.0 out of 5 stars  WOW are these bright. Theyre small but they pa...
# 5.0 out of 5 stars  These are very small flashlights. They feel ve...
# 5.0 out of 5 stars  These flashlights are awesome. They are very s...
# 5.0 out of 5 stars  All of them are working great. Bought some fro...
# 5.0 out of 5 stars                               better than expected
# 5.0 out of 5 stars            Product as described, shipped promptly.
# 5.0 out of 5 stars  great flash lights, 3 modes low light, bright ...
# 5.0 out of 5 stars  The best! Love that it uses 1 AA cell. Bought ...
# 5.0 out of 5 stars  I use these for security and they are perfect....
# 5.0 out of 5 stars  Great product! These things are amazingly brig...
# 5.0 out of 5 stars  Nice flashlights. Carry in your pocket. Simple...
# 5.0 out of 5 stars                                          very nice
# 5.0 out of 5 stars  Great mini flashlight that packs a punch in br...
#
# [644 rows x 3 columns]

# %%
del df["review_body"]
df.isnull().sum()
# Out:
# review_title    0
# review_stars    0
# review_date     0
# dtype: int64
